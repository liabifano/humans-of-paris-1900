# %%
# !wget https://raw.githubusercontent.com/opencv/opencv/master/data/haarcascades/haarcascade_frontalface_default.xml

# %%
import json
import pandas as pd

from PIL import Image
import requests
from io import BytesIO

# %%
image_dataframe = pd.read_pickle('data/named_subjects.pkl')

# %%
import os

# %%
all_images = os.listdir('../humans_of_paris/app/static/img_full/')

# %%
all_images = [pic[:-len('.png')] for pic in all_images]

# %%
images_df = image_dataframe.id.map(lambda x: x.split('/')[-1]).tolist()

# %%
never_used_images = set(all_images).difference(images_df)

# %%
image_we_need = set(images_df).difference(set(all_images))

# %%
image_dataframe['img'] = images_df

# %%
image_dataframe[image_dataframe.img.isin(image_we_need)].id.to_csv('../../ndl-crop/identifiers.csv')
# Out:
# /Users/lguillain/opt/anaconda3/envs/fdh/lib/python3.7/site-packages/ipykernel_launcher.py:1: FutureWarning: The signature of `Series.to_csv` was aligned to that of `DataFrame.to_csv`, and argument 'header' will change its default value from False to True: please pass an explicit value to suppress this warning.
#   """Entry point for launching an IPython kernel.

# %%
len(never_used_images)
# Out:
# 1

# %%
len(image_we_need)
# Out:
# 1209

# %%
never_used_images
# Out:
# {'.DS_S'}

# %%
from os import listdir
import cv2
from numpy import asarray
import numpy as np

 
# extract a single face from a given photograph
def extract_face_show(image, required_size=(160, 160)):
    face_cascade = cv2.CascadeClassifier('haarcascade_frontalface_default.xml')
    img = cv2.cvtColor(np.array(image), cv2.COLOR_BGR2GRAY)
    faces = face_cascade.detectMultiScale(img, 1.1, 4)

    for (x, y, w, h) in faces:
        cv2.rectangle(img, (x, y), (x+w, y+h), (255, 0, 0), 2)
    # Display the output
    cv2.imshow('img', img)
    cv2.waitKey()
    cv2.destroyAllWindows()

# %%
def extract_face(image, required_size=(160, 160), idf=0):
    face_cascade = cv2.CascadeClassifier('haarcascade_frontalface_default.xml')
    # Read the input image
    img = cv2.cvtColor(np.array(image), cv2.COLOR_BGR2GRAY)
    # Detect faces
    faces = face_cascade.detectMultiScale(img, 1.03, 5) #play with parameters for better detection
    # Draw rectangle around the faces
    i=0
    for (x, y, w, h) in faces:
        r = max(w, h) / 2
        centerx = x + w / 2
        centery = y + h / 2
        nx = int(centerx - r)
        ny = int(centery - r)
        nr = int(r * 2)

        faceimg = img[ny:ny+nr, nx:nx+nr]
        lastimg = cv2.resize(faceimg, (32, 32))
        i += 1
        print(x, y, w, h)
        cv2.imwrite(f"images/image{i}_{idf}.jpg", lastimg)
        print(f'write {idf}')

# %% [markdown]
# Haar gives a lot of false positives, better methods exit. we can get slightly improved results by adapting resizing the image and adapting the thresold

# %%
sample = image_dataframe.identifier.sample(100)
sample.to_csv('images/sample.csv')
for doc in sample:
    url = doc+'/f1.highres.jpg'
    response = requests.get(url)
    img = Image.open(BytesIO(response.content))
    width, height = img.size
    factor = 500/width
    #extract_face(img.resize((int(width*factor), int(factor*height))), idf=doc[-len('btv1b53134455m'):])
# Out:
# /anaconda3/envs/fdh/lib/python3.7/site-packages/ipykernel_launcher.py:6: FutureWarning: The signature of `Series.to_csv` was aligned to that of `DataFrame.to_csv`, and argument 'header' will change its default value from False to True: please pass an explicit value to suppress this warning.
# 454 263 106 106
# write btv1b53170703n
# 174 412 68 68
# write btv1b53170703n
# 619 458 51 51
# write btv1b53170703n
# 740 603 34 34
# write btv1b53170703n
# 707 527 67 67
# write btv1b53170703n
# 301 672 45 45
# write btv1b53170703n
# 363 695 30 30
# write btv1b53170703n
# 511 1024 53 53
# write btv1b53170703n
# 458 405 153 153
# write btv1b531448273
# 195 582 617 617
# write btv1b531448273
# 897 735 57 57
# write btv1b531448273
# 330 147 331 331
# write btv1b53191447x
# 462 255 92 92
# write btv1b53191447x
# 484 237 97 97
# write btv1b531810473
# 22 381 30 30
# write btv1b531810473
# 659 883 70 70
# write btv1b531810473
# 32 422 68 68
# write btv1b530507241
# 414 469 159 159
# write btv1b530507241
# 529 768 69 69
# write btv1b530507241
# 208 1213 31 31
# write btv1b530507241
# 216 136 597 597
# 769 1105 58 58
# write btv1b531689350
# 532 981 62 62
# write btv1b531689350
# 523 1082 55 55
# write btv1b531689350
# 369 1156 26 26
# write btv1b531689350
# 400 411 71 71
# write btv1b530818326
# 323 599 45 45
# write btv1b530818326
# 321 615 44 44
# write btv1b530818326
# 299 670 66 66
# write btv1b530818326
# 810 832 35 35
# write btv1b530818326
# 807 1039 56 56
# write btv1b530818326
# 921 462 32 32
# write btv1b53082328x
# 420 512 221 221
# write btv1b53082328x
# 20 1268 52 52
# write btv1b53082328x
# 528 1430 56 56
# write btv1b53082328x
# 308 76 28 28
# write btv1b531395548
# 348 418 46 46
# write btv1b531395548
# 645 572 65 65
# write btv1b531395548
# 318 377 329 329
# write btv1b531716349
# 589 942 63 63
# write btv1b531716349
# 216 911 229 229
# write btv1b531716349
# 706 1101 44 44
# write btv1b531716349
# 335 379 392 392
# write btv1b53157462b
# 99 866 234 234
# write btv1b53157462b
# 500 1188 60 60
# write btv1b53157462b
# 915 1220 81 81
# write btv1b53157462b
# 335 331 237 237
# write btv1b53117396r
# 118 387 662 662
# write btv1b53117396r
# 597 682 71 71
# write btv1b53117396r
# 278 722 98 98
# write btv1b53117396r
# 738 944 55 55
# write btv1b53117396r
# 486 784 121 121
# write btv1b53117396r
# 579 909 80 80
# write btv1b53117396r
# 114 958 56 56
# write btv1b53117396r
# 373 283 322 322
# write btv1b53112011b
# 551 892 64 64
# write btv1b53112011b
# 88 1119 54 54
# write btv1b53112011b
# 460 336 193 193
# write btv1b531875633
# 398 401 82 82
# write btv1b531875633
# 27 1258 33 33
# write btv1b531875633
# 150 1206 37 37
# write btv1b531875633
# 315 351 318 318
# write btv1b530979626
# 364 238 82 82
# write btv1b53092345q
# 333 485 260 260
# write btv1b53092345q
# 386 1066 32 32
# write btv1b53092345q
# 600 1081 62 62
# write btv1b53092345q
# 32 1390 57 57
# write btv1b53092345q
# 558 462 33 33
# write btv1b531310463
# 406 449 85 85
# write btv1b531310463
# 450 607 79 79
# write btv1b531310463
# 252 681 63 63
# write btv1b531310463
# 86 966 173 173
# write btv1b531310463
# 363 1147 47 47
# write btv1b531310463
# 734 1060 86 86
# write btv1b531310463
# 360 487 255 255
# write btv1b530916086
# 490 878 29 29
# write btv1b530916086
# 308 888 54 54
# write btv1b530916086
# 942 1323 28 28
# write btv1b530916086
# 188 434 55 55
# write btv1b53171063t
# 495 397 94 94
# write btv1b53171063t
# 365 378 285 285
# write btv1b53171063t
# 371 653 353 353
# write btv1b53171063t
# 430 752 51 51
# write btv1b53171063t
# 696 872 45 45
# write btv1b53171063t
# 373 821 59 59
# write btv1b53171063t
# 566 907 51 51
# write btv1b53171063t
# 618 1026 48 48
# write btv1b53171063t
# 445 1082 34 34
# write btv1b53171063t
# 417 497 177 177
# write btv1b53071723j
# 783 760 40 40
# write btv1b53071723j
# 892 1440 36 36
# write btv1b53071723j
# 19 1321 52 52
# write btv1b53071723j
# 342 309 90 90
# write btv1b53159934k
# 837 440 81 81
# write btv1b53159934k
# 647 1009 62 62
# write btv1b53149320s

# %% [markdown]
# look at MTCNN which is a state of the art model for face detection (and related tasks). Install the module mtcnn but make sure to have a tensorflow version older than 2.0, so for instance 1.13.1

# %% [markdown]
# still some false positives but markedly better, need to check for false negatives

# %%
from mtcnn.mtcnn import MTCNN
# Out:
# Using TensorFlow backend.

# %%
model = MTCNN()

def extract_face_cnn(img, idf=0):
    img = np.array(img)
    faces = model.detect_faces(img)
    i=0
    for face in faces:
        box = face['box']
        (x, y, w, h) = (box[0], box[1], box[2], box[3])
        r = max(w, h) / 2
        centerx = x + w / 2
        centery = y + h / 2
        nx = int(centerx - r)
        ny = int(centery - r)
        nr = int(r * 2)

        faceimg = img[ny:ny+nr, nx:nx+nr]
        lastimg = cv2.resize(faceimg, (32, 32))
        i += 1
        print(x, y, w, h)
        cv2.imwrite(f"images/image{i}_{idf}.jpg", lastimg)
        print(f'write {idf}')
# Out:
# WARNING:tensorflow:From /Users/lguillain/opt/anaconda3/envs/fdh/lib/python3.7/site-packages/tensorflow/python/framework/op_def_library.py:263: colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.

# %%
from PIL import Image
import requests
from io import BytesIO

sample = pd.read_csv('images/sample.csv', header=None, index_col=0)[1]
for doc in sample:
    url = doc+'/f1.highres.jpg'
    response = requests.get(url)
    img = Image.open(BytesIO(response.content))
    width, height = img.size
    factor = 500/width
    extract_face_cnn(img,  idf=doc[-len('btv1b53134455m'):])

# %% [markdown]
# Analyzing facial vectors & clustering

# %% [markdown]
# # cropping images

# %%
def crop(img, minx, miny, maxx, maxy):
    return img[miny:maxy, minx:maxx]


def get_image(doc):
    url = doc+'/f1.highres.jpg'
    response = requests.get(url)
    img = Image.open(BytesIO(response.content))
    img = Image.open(BytesIO(response.content)).convert('RGB')
    img = np.array(img)
    return img

# %%
def get_face_image(doc):
    output_file = '../humans_of_paris/app/static/images/'+doc.id.split('/')[-1]+'.jpg'
    img = get_image(doc.id)
    cropped = crop(img, int(doc.left), int(doc.top), int(doc.right), int(doc.bottom))
    cv2.imwrite(output_file,  cv2.cvtColor(cropped, cv2.COLOR_RGB2BGR))

# %%
age_gender_lables
# Out:
#        left    top  right  bottom  width  height    gender        age  number  \
# 0     269.0  268.0  748.0   747.0  479.0   479.0  0.116277  47.741472     1.0
# 1     433.0  316.0  580.0   463.0  147.0   147.0  0.585720  27.465579     2.0
# 2     250.0  718.0  403.0   871.0  153.0   153.0  0.377803  40.358822     3.0
# 3     155.0  134.0  872.0   851.0  717.0   717.0  0.104841  44.487285     1.0
# 4     415.0  184.0  615.0   384.0  200.0   200.0  0.389818  27.194442     1.0
# ...     ...    ...    ...     ...    ...     ...       ...        ...     ...
# 1881  292.0  351.0  658.0   717.0  366.0   366.0  0.025766  47.032899     1.0
# 1882  355.0  310.0  596.0   551.0  241.0   241.0  0.033713  45.716630     1.0
# 1883  288.0  437.0  583.0   732.0  295.0   295.0  0.358721  26.078685     1.0
# 1884  310.0  214.0  739.0   643.0  429.0   429.0  0.108013  47.732863     1.0
# 1885  448.0  284.0  601.0   437.0  153.0   153.0  0.081239  31.406526     1.0
#
#                                                     id  \
# 0     https://gallica.bnf.fr/ark:/12148/btv1b53071608k
# 1     https://gallica.bnf.fr/ark:/12148/btv1b531622212
# 2     https://gallica.bnf.fr/ark:/12148/btv1b53071525p
# 3     https://gallica.bnf.fr/ark:/12148/btv1b53165139q
# 4     https://gallica.bnf.fr/ark:/12148/btv1b53117510h
# ...                                                ...
# 1881  https://gallica.bnf.fr/ark:/12148/btv1b53098072j
# 1882  https://gallica.bnf.fr/ark:/12148/btv1b53065399p
# 1883  https://gallica.bnf.fr/ark:/12148/btv1b530664193
# 1884  https://gallica.bnf.fr/ark:/12148/btv1b531271467
# 1885  https://gallica.bnf.fr/ark:/12148/btv1b53111936g
#
#                               name
# 0               Abbatucci, Séverin
# 1                     Abbott, Emma
# 2                   Abbéma, Louise
# 3     Abney, William de Wiveleslie
# 4                    Abott, Bessie
# ...                            ...
# 1881                   Édouard VII
# 1882                 Énault, Louis
# 1883   Éon, Charles de Beaumont d'
# 1884                 Étex, Antoine
# 1885               Étiévant, Henri
#
# [1886 rows x 11 columns]

# %%
import os

# %%
collected = set([x[:-len('.jpg')] for x in os.listdir('./images')])

# %%
len(os.listdir('./images'))
# Out:
# 1739

# %%
age_gender_lables = pd.read_json('age_gender_labeles.json')

# %%
to_collect = set(age_gender_lables.dropna().id.map(lambda x: x.split('/')[-1]).tolist()).difference(collected)

# %%
import numpy as np

# %%
age_gender_lables.dropna()[400:].apply(lambda x: get_face_image(x), axis=1)
# Out:
# 421     None
# 422     None
# 423     None
# 424     None
# 425     None
#         ...
# 1881    None
# 1882    None
# 1883    None
# 1884    None
# 1885    None
# Length: 1411, dtype: object

# %% [markdown]
# # Alternative face map clustering

# %%
import matplotlib.pyplot as plt

# %%
import numpy as np

# %%
with open('faces.json') as f:
    d = f.read()
    
face = pd.DataFrame(json.loads(d))

# %%
age_gender_lables = pd.read_json('data/age_gender_labeles_augmented.json')

# %%
age_gender_lables
# Out:
#                                           name gender_true   left    top  \
# 0               Abbatucci, Séverin (1821-1888)    masculin  269.0  268.0
# 1                     Abbott, Emma (1850-1891)     féminin  433.0  316.0
# 2                   Abbéma, Louise (1858-1927)     féminin  250.0  718.0
# 3     Abney, William de Wiveleslie (1843-1920)    masculin  155.0  134.0
# 4                    Abott, Bessie (1878-1919)     féminin  415.0  184.0
# ...                                        ...         ...    ...    ...
# 1869                 Énault, Louis (1824-1900)    masculin  355.0  310.0
# 1870   Éon, Charles de Beaumont d' (1728-1810)    masculin  288.0  437.0
# 1871                 Étex, Antoine (1808-1888)    masculin  310.0  214.0
# 1872               Étiévant, Henri (1870-1953)    masculin  448.0  284.0
# 1873    Č̌ebyšev, Pafnutij Lʹvovič (1821-1894)    masculin  160.0   69.0
#
#       right  bottom  width  height  gender_estimated        age  number  \
# 0     748.0   747.0  479.0   479.0          0.116277  47.741472     1.0
# 1     580.0   463.0  147.0   147.0          0.585720  27.465579     2.0
# 2     403.0   871.0  153.0   153.0          0.377803  40.358822     3.0
# 3     872.0   851.0  717.0   717.0          0.104841  44.487285     1.0
# 4     615.0   384.0  200.0   200.0          0.389818  27.194442     1.0
# ...     ...     ...    ...     ...               ...        ...     ...
# 1869  596.0   551.0  241.0   241.0          0.033713  45.716630     1.0
# 1870  583.0   732.0  295.0   295.0          0.358721  26.078685     1.0
# 1871  739.0   643.0  429.0   429.0          0.108013  47.732863     1.0
# 1872  601.0   437.0  153.0   153.0          0.081239  31.406526     1.0
# 1873  950.0   859.0  790.0   790.0          0.180912  64.070084     1.0
#
#                                                     id gender_estimates_binary
# 0     https://gallica.bnf.fr/ark:/12148/btv1b53071608k                masculin
# 1     https://gallica.bnf.fr/ark:/12148/btv1b531622212                 féminin
# 2     https://gallica.bnf.fr/ark:/12148/btv1b53071525p                masculin
# 3     https://gallica.bnf.fr/ark:/12148/btv1b53165139q                masculin
# 4     https://gallica.bnf.fr/ark:/12148/btv1b53117510h                masculin
# ...                                                ...                     ...
# 1869  https://gallica.bnf.fr/ark:/12148/btv1b53065399p                masculin
# 1870  https://gallica.bnf.fr/ark:/12148/btv1b530664193                masculin
# 1871  https://gallica.bnf.fr/ark:/12148/btv1b531271467                masculin
# 1872  https://gallica.bnf.fr/ark:/12148/btv1b53111936g                masculin
# 1873  https://gallica.bnf.fr/ark:/12148/btv1b531813331                masculin
#
# [1874 rows x 13 columns]

# %%
face = pd.merge(face, age_gender_lables, on='id')

# %%
references = face.iloc[:100].id.map(lambda x:  x.split('/')[-1]+'.jpg').tolist()
matrix = face.iloc[:100].face.tolist()

# %%
face_json = {'users': references, 'mat': matrix}

# %%
gender_lables = face.gender_true

# %%
matrix = face.face.tolist()

# %%
matrix = np.array(matrix)

# %%
from sklearn.decomposition import PCA
pca = PCA(n_components=2)

# %%
x_pca = pca.fit_transform(matrix)

# %%
gender_lables = gender_lables.map(lambda x: 0 if x == 'masculin'  else 1)

# %%
plt.scatter(x_pca[:,0], x_pca[:,1], c = gender_lables, cmap=plt.cm.bwr)

# %%
x_pca = (x_pca - x_pca.min())*200+100

# %%
from sklearn import random_projection

# %%
import numpy as np

# %%
transformer = random_projection.SparseRandomProjection(n_components=2, density=.99)
X_new = transformer.fit_transform(matrix)

# %%
plt.scatter(X_new[:,1], X_new[:,0], c = gender_lables, cmap=plt.cm.bwr)

# %%
from sklearn.manifold import TSNE

X_embedded = TSNE(n_components=2).fit_transform(matrix)

# %%
plt.scatter(X_embedded[:,1], X_embedded[:,0], c = gender_lables, cmap=plt.cm.bwr)

# %% [markdown]
# # importance of faces

# %%
fame = pd.read_pickle('data/merged_dataframe.pkl')#.rank_fr.plot(kind='hist', bins=100)

# %%
fame.sort_values(by='rank_fr')[['name', 'rank_fr', 'id']].dropna()[:100]
# Out:
#                                         name  rank_fr  \
# 235          Bouguereau, William (1825-1905)      1.0
# 580             Dieterle, Amélie (1870-1941)      2.0
# 1629                Sand, George (1804-1876)      3.0
# 1171              Manet, Édouard (1832-1883)      4.0
# 1573  Robespierre, Maximilien de (1758-1794)      5.0
# ...                                      ...      ...
# 1599          Rousseau, Théodore (1812-1867)    109.0
# 1133               Loubet, Émile (1838-1929)    109.0
# 1448     Picot, François Édouard (1786-1868)    109.0
# 549                 Derré, Emile (1867-1938)    109.0
# 577    Diaz de la Peña, Narcisse (1807-1876)    109.0
#
#                                                     id
# 235   https://gallica.bnf.fr/ark:/12148/btv1b53050879q
# 580   https://gallica.bnf.fr/ark:/12148/btv1b53111808r
# 1629  https://gallica.bnf.fr/ark:/12148/btv1b53066110x
# 1171  https://gallica.bnf.fr/ark:/12148/btv1b53066421x
# 1573  https://gallica.bnf.fr/ark:/12148/btv1b53187673w
# ...                                                ...
# 1599  https://gallica.bnf.fr/ark:/12148/btv1b53120269c
# 1133  https://gallica.bnf.fr/ark:/12148/btv1b53117467b
# 1448  https://gallica.bnf.fr/ark:/12148/btv1b53050696f
# 549   https://gallica.bnf.fr/ark:/12148/btv1b53118812w
# 577   https://gallica.bnf.fr/ark:/12148/btv1b531706898
#
# [100 rows x 3 columns]

# %%
famous_id = fame.sort_values(by='rank_fr')[['name', 'rank_fr', 'id']].dropna()[:250].id.tolist()

# %%
cond = face.id.isin(famous_id)

# %%
references = face[cond].id.map(lambda x: x.split('/')[-1]+'.jpg').tolist()

# %%
names = face[cond].name.tolist()

# %%
matrix = face[cond].face.tolist()
matrix = np.array(matrix)

# %%
x_pca = pca.fit_transform(matrix)
x_pca = (x_pca - x_pca.min())*200+100

# %%
gender_lables = face[cond].gender_true
gender_lables = gender_lables.map(lambda x: 0 if x == 'masculin'  else 1)

plt.scatter(x_pca[:,0], x_pca[:,1], c = gender_lables, cmap=plt.cm.bwr)

# %%
X_embedded = TSNE(n_components=2).fit_transform(matrix)
X_embedded = (X_embedded - X_embedded.min())*2+100
plt.scatter(X_embedded[:,1], X_embedded[:,0], c = gender_lables, cmap=plt.cm.bwr)

# %%
tuples = list(zip(references, names, X_embedded.tolist()))

face_json = {'users': tuples}

with open('../humans_of_paris/app/static/clustered.json', 'w') as outfile:
    json.dump(face_json, outfile)

# %%
face_json
# Out:
# {'users': [('btv1b53050602x.jpg',
#    'Lazerges, Hippolyte (1817-1887)',
#    [109.77900695800781, 137.37374877929688]),
#   ('btv1b53104347s.jpg',
#    'Leleux, Adolphe (1812-1891)',
#    [142.18692016601562, 141.94090270996094]),
#   ('btv1b53169003s.jpg',
#    'Lemaire, Madeleine (1845-1928)',
#    [111.15914916992188, 119.83828735351562]),
#   ('btv1b53081619r.jpg',
#    'Lepère, Charles (1823-1885)',
#    [136.90219116210938, 132.0115509033203]),
#   ('btv1b53107167w.jpg',
#    'Leriche, Augustine (1860-1938)',
#    [110.86641693115234, 112.79524993896484]),
#   ('btv1b53081576h.jpg',
#    'Lesseps, Ferdinand de (1805-1894)',
#    [137.99063110351562, 129.90960693359375]),
#   ('btv1b53118945v.jpg',
#    'Balzac, Honoré de (1799-1850)',
#    [126.79301452636719, 147.35684204101562]),
#   ('btv1b53118904r.jpg',
#    'Lhermitte, Léon (1844-1925)',
#    [145.07369995117188, 125.1622543334961]),
#   ('btv1b53107869f.jpg',
#    'Liszt, Franz (1811-1886)',
#    [146.54876708984375, 126.87544250488281]),
#   ('btv1b53139302j.jpg',
#    'Littré, Émile (1801-1881)',
#    [145.39691162109375, 118.13784790039062]),
#   ('btv1b53071953j.jpg',
#    'Banville, Théodore de (1823-1891)',
#    [123.95085144042969, 123.6466064453125]),
#   ('btv1b53104358n.jpg',
#    'Livry, Emma (1842-1863)',
#    [106.0652847290039, 118.84820556640625]),
#   ('btv1b53117467b.jpg',
#    'Loubet, Émile (1838-1929)',
#    [106.64911651611328, 134.02621459960938]),
#   ('btv1b53173251z.jpg',
#    'Forain, Jean-Louis (1852-1931)',
#    [122.15421295166016, 150.77273559570312]),
#   ('btv1b53187665c.jpg',
#    'Faure, Jean-Baptiste (1830-1914)',
#    [138.91531372070312, 141.6898651123047]),
#   ('btv1b530660758.jpg',
#    'Macé, Jean (1815-1894)',
#    [123.87345886230469, 131.9722442626953]),
#   ('btv1b531378053.jpg',
#    'Magnin, Joseph (1824-1910)',
#    [131.96823120117188, 136.71841430664062]),
#   ('btv1b531079562.jpg',
#    'Mallarmé, Stéphane (1842-1898)',
#    [129.58023071289062, 118.72636413574219]),
#   ('btv1b53066421x.jpg',
#    'Manet, Édouard (1832-1883)',
#    [113.306396484375, 137.09312438964844]),
#   ('btv1b530820636.jpg',
#    'Marcère, Émile de (1828-1918)',
#    [107.32062530517578, 139.05886840820312]),
#   ('btv1b531204069.jpg',
#    'Delarue-Mardrus, Lucie (1874-1945)',
#    [104.76177215576172, 112.67363739013672]),
#   ('btv1b53120421w.jpg',
#    'Mariani, Angelo (1838-1914)',
#    [123.62398529052734, 142.41256713867188]),
#   ('btv1b53163494d.jpg',
#    'Charcot, Jean-Martin (1825-1893)',
#    [144.1470947265625, 121.79248809814453]),
#   ('btv1b53187754w.jpg',
#    'Massenet, Jules (1842-1912)',
#    [123.6175308227539, 151.49977111816406]),
#   ('btv1b53097844w.jpg',
#    'Maupassant, Guy de (1850-1893)',
#    [121.00267791748047, 145.59716796875]),
#   ('btv1b53081874r.jpg',
#    'Mauri, Rosita (1856-1923)',
#    [110.39846801757812, 117.38715362548828]),
#   ('btv1b53065901n.jpg',
#    'Meissonier, Ernest (1815-1891)',
#    [126.02041625976562, 134.41786193847656]),
#   ('btv1b53159750v.jpg',
#    'Melba, Nellie (1861-1931)',
#    [108.99989318847656, 113.3287124633789]),
#   ('btv1b530664354.jpg',
#    'Mendès, Catulle (1841-1909)',
#    [122.61937713623047, 135.22598266601562]),
#   ('btv1b53137698d.jpg',
#    'Meyerbeer, Giacomo (1791-1864)',
#    [135.063720703125, 112.67997741699219]),
#   ('btv1b53104374p.jpg',
#    'Michelet, Jules (1798-1874)',
#    [131.4224090576172, 135.37225341796875]),
#   ('btv1b53050342f.jpg',
#    'Millet, Aimé (1819-1891)',
#    [132.14431762695312, 126.2374267578125]),
#   ('btv1b53118947r.jpg',
#    'Mistinguett (1875-1956)',
#    [105.32772064208984, 114.10731506347656]),
#   ('btv1b530658967.jpg',
#    'Monnier, Henry (1799-1877)',
#    [140.88504028320312, 118.34541320800781]),
#   ('btv1b53120447d.jpg',
#    'Barrès, Maurice (1862-1923)',
#    [131.87779235839844, 123.79022216796875]),
#   ('btv1b531188157.jpg',
#    'Monzie, Anatole de (1876-1947)',
#    [117.69548034667969, 121.64484405517578]),
#   ('btv1b531377332.jpg',
#    'Munkácsy, Mihály (1844-1900)',
#    [127.8092041015625, 148.99127197265625]),
#   ('btv1b53117321m.jpg',
#    'Barthe, Adrien (1828-1898)',
#    [143.1287841796875, 123.28903198242188]),
#   ('btv1b53050768g.jpg',
#    'Nerval, Gérard de (1808-1855)',
#    [132.8861083984375, 117.0320816040039]),
#   ('btv1b530978420.jpg',
#    'Bartholdi, Auguste (1834-1904)',
#    [126.23377990722656, 119.74638366699219]),
#   ('btv1b53118972r.jpg',
#    'Niépce, Nicéphore (1765-1833)',
#    [107.53390502929688, 123.64867401123047]),
#   ('btv1b53137892g.jpg',
#    'Lecomte Du Noüy, Jean Jules Antoine (1842-1923)',
#    [117.04330444335938, 136.88856506347656]),
#   ('btv1b53065796v.jpg',
#    'Palizzi, Giuseppe (1812-1888)',
#    [131.08181762695312, 141.15194702148438]),
#   ('btv1b53082299w.jpg',
#    'Parfait, Noël (1813-1896)',
#    [134.91421508789062, 138.94822692871094]),
#   ('btv1b53097697j.jpg',
#    'Pasteur, Louis (1822-1895)',
#    [141.8308563232422, 127.05656433105469]),
#   ('btv1b53066314g.jpg',
#    'Patti, Adelina (1843-1919)',
#    [106.58113098144531, 113.94085693359375]),
#   ('btv1b531203348.jpg',
#    'Peary, Robert Edwin (1856-1920)',
#    [142.89891052246094, 114.17325592041016]),
#   ('btv1b53117382j.jpg',
#    'Pelletan, Camille (1846-1915)',
#    [121.75946044921875, 129.72679138183594]),
#   ('btv1b53065834v.jpg',
#    'Pelletan, Eugène (1813-1884)',
#    [145.01121520996094, 138.17723083496094]),
#   ('btv1b53118918z.jpg',
#    'Pelliot, Paul (1878-1945)',
#    [115.1989517211914, 124.93638610839844]),
#   ('btv1b53100776q.jpg',
#    'Baudry, Paul (1828-1886)',
#    [113.37081909179688, 130.3264923095703]),
#   ('btv1b531706898.jpg',
#    'Diaz de la Peña, Narcisse (1807-1876)',
#    [123.30394744873047, 137.52479553222656]),
#   ('btv1b53104423j.jpg',
#    'Philipon, Charles (1800-1862)',
#    [135.8426513671875, 123.75384521484375]),
#   ('btv1b53050606q.jpg',
#    'Philippoteaux, Félix (1815-1884)',
#    [133.26304626464844, 128.378173828125]),
#   ('btv1b53050696f.jpg',
#    'Picot, François Édouard (1786-1868)',
#    [139.59434509277344, 117.9078369140625]),
#   ('btv1b53050601g.jpg',
#    'Baugniet, Charles (1814-1886)',
#    [130.82852172851562, 128.84994506835938]),
#   ('btv1b53193387w.jpg',
#    'Bauër, Henry (1851-1915)',
#    [130.9430694580078, 131.53378295898438]),
#   ('btv1b531189501.jpg',
#    'Poincaré, Raymond (1860-1934)',
#    [125.89875793457031, 151.60736083984375]),
#   ('btv1b53193717h.jpg',
#    'Bayard, Émile (1868-1937)',
#    [145.1385498046875, 143.22390747070312]),
#   ('btv1b530655874.jpg',
#    'Prim, Juan (1814-1870)',
#    [130.27691650390625, 124.58000183105469]),
#   ('btv1b53050771r.jpg',
#    'Préault, Auguste (1809-1879)',
#    [132.43777465820312, 130.31515502929688]),
#   ('btv1b531044223.jpg',
#    'Péreire, Isaac (1806-1880)',
#    [128.53182983398438, 127.4651870727539]),
#   ('btv1b53100742p.jpg',
#    'Péreire, Émile (1800-1875)',
#    [133.14974975585938, 120.46711730957031]),
#   ('btv1b530924364.jpg',
#    'Richepin, Jean (1849-1926)',
#    [123.28008270263672, 139.0732879638672]),
#   ('btv1b531521416.jpg',
#    'Becquerel, Antoine Henri (1852-1908)',
#    [118.29629516601562, 129.70045471191406]),
#   ('btv1b53117411k.jpg',
#    'Rivière, Théodore (1857-1912)',
#    [121.06912231445312, 121.03082275390625]),
#   ('btv1b53187673w.jpg',
#    'Robespierre, Maximilien de (1758-1794)',
#    [111.06925964355469, 122.78507995605469]),
#   ('btv1b53107958z.jpg',
#    'Rodin, Auguste (1840-1917)',
#    [141.70257568359375, 139.24395751953125]),
#   ('btv1b53098148c.jpg',
#    'Roll, Alfred Philippe (1846-1919)',
#    [111.867431640625, 136.82106018066406]),
#   ('btv1b53104453s.jpg',
#    'Rossini, Gioachino (1792-1868)',
#    [129.45294189453125, 127.49053955078125]),
#   ('btv1b530657494.jpg',
#    'Rothschild, Alphonse de (1827-1905)',
#    [116.93659973144531, 140.30255126953125]),
#   ('btv1b53117425s.jpg',
#    'Roty, Oscar (1846-1911)',
#    [132.90444946289062, 124.1120376586914]),
#   ('btv1b53104455p.jpg',
#    'Rousseau, Jean Baptiste (1829-1891)',
#    [119.27626037597656, 136.69528198242188]),
#   ('btv1b53120269c.jpg',
#    'Rousseau, Théodore (1812-1867)',
#    [121.61712646484375, 127.71736145019531]),
#   ('btv1b531174858.jpg',
#    'Le Roux, Hugues (1860-1925)',
#    [125.20154571533203, 128.72149658203125]),
#   ('btv1b530976891.jpg',
#    'Roybet, Ferdinand (1840-1920)',
#    [134.7118682861328, 141.66189575195312]),
#   ('btv1b531717337.jpg',
#    'Salis, Rodolphe (1851-1897)',
#    [127.66465759277344, 141.34927368164062]),
#   ('btv1b53163726j.jpg',
#    'Samuel, Fernand (1862-1914)',
#    [123.74032592773438, 133.69956970214844]),
#   ('btv1b53066110x.jpg',
#    'Sand, George (1804-1876)',
#    [103.39039611816406, 116.51228332519531]),
#   ('btv1b53065822j.jpg',
#    'Sardou, Victorien (1831-1908)',
#    [105.37896728515625, 124.53778076171875]),
#   ('btv1b531415039.jpg',
#    'Schoelcher, Victor (1804-1893)',
#    [135.3555908203125, 120.11067199707031]),
#   ('btv1b530507889.jpg',
#    'Schopin, Frédéric Henri (1804-1880)',
#    [135.26028442382812, 120.77377319335938]),
#   ('btv1b53141540m.jpg',
#    'Scribe, Eugène (1791-1861)',
#    [148.41925048828125, 133.67196655273438]),
#   ('btv1b53118954t.jpg',
#    'Galliéni, Joseph-Simon (1849-1916)',
#    [140.68463134765625, 121.22187805175781]),
#   ('btv1b53161928h.jpg',
#    'Sorel, Cécile (1873-1966)',
#    [107.45783233642578, 118.04039001464844]),
#   ('btv1b531071472.jpg',
#    'Stewart, Julius Leblanc (1855-1919)',
#    [115.86572265625, 134.5442657470703]),
#   ('btv1b53097969b.jpg',
#    'Séverine (1855-1929)',
#    [100.20066833496094, 118.89335632324219]),
#   ('btv1b53104484g.jpg',
#    'Thalberg, Sigismond (1812-1871)',
#    [126.63565063476562, 122.44730377197266]),
#   ('btv1b531139632.jpg',
#    'Thomas, Ambroise (1811-1896)',
#    [139.42904663085938, 116.88932800292969]),
#   ('btv1b53148623x.jpg',
#    'Tissandier, Albert (1839-1906)',
#    [122.83226013183594, 151.92828369140625]),
#   ('btv1b53141659f.jpg',
#    'Toulmouche, Auguste (1829-1890)',
#    [122.28514099121094, 137.6500244140625]),
#   ('btv1b530508017.jpg',
#    'Trousseau, Armand (1801-1867)',
#    [141.62294006347656, 116.9813232421875]),
#   ('btv1b53169280h.jpg',
#    'Uzanne, Octave (1851-1931)',
#    [128.19488525390625, 144.24453735351562]),
#   ('btv1b530921271.jpg',
#    'Chevandier de Valdrôme, Eugène (1810-1878)',
#    [116.28681945800781, 145.32479858398438]),
#   ('btv1b53050849g.jpg',
#    'Valerio, Théodore (1819-1879)',
#    [137.2025604248047, 128.48843383789062]),
#   ('btv1b530716163.jpg',
#    'Aicard, Jean (1848-1921)',
#    [119.67090606689453, 127.73416137695312]),
#   ('btv1b53050489m.jpg',
#    'Vallès, Jules (1832-1885)',
#    [117.0391845703125, 121.6102294921875]),
#   ('btv1b53066306z.jpg',
#    'Berlioz, Hector (1803-1869)',
#    [144.26373291015625, 117.90109252929688]),
#   ('btv1b53120281m.jpg',
#    'Vernet, Horace (1789-1863)',
#    [146.29710388183594, 126.13333129882812]),
#   ('btv1b530505604.jpg',
#    'Veuillot, Louis (1813-1883)',
#    [138.95883178710938, 131.1212158203125]),
#   ('btv1b53118862z.jpg',
#    'Bernard, Tristan (1866-1947)',
#    [126.67927551269531, 141.48532104492188]),
#   ('btv1b530656309.jpg',
#    'Wallace, Richard (1818-1890)',
#    [112.08342742919922, 143.72459411621094]),
#   ('btv1b53162160w.jpg',
#    'Bernhardt, Sarah (1844-1923)',
#    [101.71318054199219, 113.7820816040039]),
#   ('btv1b53104498p.jpg',
#    'Whitworth, Joseph (1803-1887 ; sir)',
#    [137.29202270507812, 123.78324890136719]),
#   ('btv1b530503717.jpg',
#    'Wolff, Albert (1825-1891)',
#    [100.0, 119.1964111328125]),
#   ('btv1b530504561.jpg',
#    'Wyld, William (1806-1889)',
#    [138.2678680419922, 125.96456909179688]),
#   ('btv1b53092121b.jpg',
#    'Zola, Émile (1840-1902)',
#    [125.01228332519531, 145.0936279296875]),
#   ('btv1b53066129c.jpg',
#    "Barbey d'Aurevilly, Jules (1808-1889)",
#    [145.2354736328125, 134.4697265625]),
#   ('btv1b530664193.jpg',
#    "Éon, Charles de Beaumont d' (1728-1810)",
#    [105.64755249023438, 119.11123657226562]),
#   ('btv1b53100801z.jpg',
#    'Bertall (1820-1882)',
#    [116.86152648925781, 137.35694885253906]),
#   ('btv1b531511463.jpg',
#    'Berthelot, Marcellin (1827-1907)',
#    [129.09902954101562, 131.49864196777344]),
#   ('btv1b53107953q.jpg',
#    'Bertillon, Alphonse (1853-1914)',
#    [144.08551025390625, 140.297607421875]),
#   ('btv1b530508820.jpg',
#    'Bethmont, Eugène (1804-1860)',
#    [143.27523803710938, 118.15399169921875]),
#   ('btv1b53071525p.jpg',
#    'Abbéma, Louise (1858-1927)',
#    [105.9452133178711, 127.05850219726562]),
#   ('btv1b531341452.jpg',
#    'Bodmer, Karl (1809-1893)',
#    [116.48191833496094, 145.17538452148438]),
#   ('btv1b53050824d.jpg',
#    'Bonheur, Rosa (1822-1899)',
#    [111.55877685546875, 119.77389526367188]),
#   ('btv1b53071980f.jpg',
#    'Bonvin, François (1817-1887)',
#    [136.03875732421875, 126.8150405883789]),
#   ('btv1b53107942v.jpg',
#    'Albert Ier (1848-1922 ; prince de Monaco)',
#    [131.10223388671875, 142.78485107421875]),
#   ('btv1b53050879q.jpg',
#    'Bouguereau, William (1825-1905)',
#    [129.66500854492188, 122.57221984863281]),
#   ('btv1b531515650.jpg',
#    'Boulanger, Georges (1837-1891)',
#    [125.59318542480469, 142.0608673095703]),
#   ('btv1b53050753t.jpg',
#    'Bracquemond, Félix (1833-1914)',
#    [116.38300323486328, 123.03936004638672]),
#   ('btv1b531651494.jpg',
#    'Brasseur, Albert (1862-1932)',
#    [120.89925384521484, 125.13788604736328]),
#   ('btv1b53159810k.jpg',
#    'Brazza, Pierre Savorgnan de (1852-1905)',
#    [113.32424926757812, 133.17465209960938]),
#   ('btv1b530719273.jpg',
#    'Breton, Jules (1827-1906)',
#    [134.5974884033203, 122.2210464477539]),
#   ('btv1b53171770j.jpg',
#    'Bruant, Aristide (1851-1925)',
#    [124.19078826904297, 125.5434799194336]),
#   ('btv1b531119601.jpg',
#    'Bréval, Lucienne (1869-1935)',
#    [106.62351989746094, 111.34396362304688]),
#   ('btv1b531188676.jpg',
#    'Bérenger, Henry (1867-1952)',
#    [122.97512817382812, 118.23976135253906]),
#   ('btv1b53066317t.jpg',
#    'Cadart, Alfred (1828-1875 ; éditeur)',
#    [117.9017333984375, 116.59841918945312]),
#   ('btv1b53072189s.jpg',
#    'Carlos (1848-1909 ; prince de Bourbon)',
#    [144.4136962890625, 135.6207275390625]),
#   ('btv1b530664784.jpg',
#    'Cham (1818-1879)',
#    [109.18214416503906, 136.86732482910156]),
#   ('btv1b531008066.jpg',
#    'Chenavard, Paul (1807-1895)',
#    [130.96389770507812, 115.68556213378906]),
#   ('btv1b53149477c.jpg',
#    'Chevreul, Eugène (1786-1889)',
#    [141.50717163085938, 111.80126953125]),
#   ('btv1b531494311.jpg',
#    'Churchill, Jeanette (1854-1921)',
#    [108.38800048828125, 114.00618743896484]),
#   ('btv1b53097877g.jpg',
#    'Chéret, Jules (1836-1932)',
#    [120.11105346679688, 120.57342529296875]),
#   ('btv1b53072195d.jpg',
#    'Clairin, Georges (1843-1919)',
#    [114.93798065185547, 131.56126403808594]),
#   ('btv1b53072132k.jpg',
#    'Clemenceau, Georges (1841-1929)',
#    [135.32151794433594, 146.51510620117188]),
#   ('btv1b53152129z.jpg',
#    'Cloué, Georges (1817-1889)',
#    [149.505126953125, 123.10481262207031]),
#   ('btv1b530506861.jpg',
#    'Clésinger, Auguste (1814-1883)',
#    [128.72256469726562, 132.60694885253906]),
#   ('btv1b53144772j.jpg',
#    'Cochery, Adolphe (1819-1900)',
#    [131.51632690429688, 138.90565490722656]),
#   ('btv1b53124183h.jpg',
#    'Cochery, Georges (1855-1914)',
#    [130.875244140625, 138.16552734375]),
#   ('btv1b53100832n.jpg',
#    'Coppée, François (1842-1908)',
#    [104.11952209472656, 112.30487060546875]),
#   ('btv1b530720862.jpg',
#    'Coquelin, Constant (1841-1909)',
#    [117.80682373046875, 114.01148223876953]),
#   ('btv1b53050555z.jpg',
#    'Couder, Auguste (1789-1873)',
#    [141.4478759765625, 113.49172973632812]),
#   ('btv1b53050548w.jpg',
#    'Courbet, Gustave (1819-1877)',
#    [119.64354705810547, 132.70916748046875]),
#   ('btv1b53050505w.jpg',
#    'Cousin, Victor (1792-1867)',
#    [128.15660095214844, 125.59052276611328]),
#   ('btv1b53117332g.jpg',
#    'Crosti, Eugène (1833-1908)',
#    [127.97821044921875, 139.61700439453125]),
#   ('btv1b531008138.jpg',
#    'Crémieux, Adolphe (1796-1880)',
#    [142.1943359375, 128.54554748535156]),
#   ('btv1b53100834j.jpg',
#    'Darboy, Georges (1813-1871)',
#    [136.38092041015625, 112.53168487548828]),
#   ('btv1b53100861f.jpg',
#    'Daudet, Alphonse (1840-1897)',
#    [115.13763427734375, 125.64633178710938]),
#   ('btv1b53120224g.jpg',
#    'Daumier, Honoré (1808-1879)',
#    [138.37203979492188, 134.03573608398438]),
#   ('btv1b53100870d.jpg',
#    'Dauzats, Adrien (1804-1868)',
#    [137.6199188232422, 116.39881896972656]),
#   ('btv1b53065619h.jpg',
#    'Davis, Jefferson (1808-1889)',
#    [111.06343078613281, 127.24281311035156]),
#   ('btv1b53118843k.jpg',
#    'Debussy, Claude (1862-1918)',
#    [120.62663269042969, 143.85760498046875]),
#   ('btv1b53065973f.jpg',
#    'About, Edmond (1828-1885)',
#    [123.55430603027344, 128.45962524414062]),
#   ('btv1b53104547j.jpg',
#    'Delacroix, Eugène (1798-1863)',
#    [130.0677947998047, 113.24214172363281]),
#   ('btv1b53118812w.jpg',
#    'Derré, Emile (1867-1938)',
#    [117.7576904296875, 115.30567169189453]),
#   ('btv1b53107899p.jpg',
#    'Desboutin, Marcellin (1823-1902)',
#    [131.1599884033203, 148.59616088867188]),
#   ('btv1b53111808r.jpg',
#    'Dieterle, Amélie (1870-1941)',
#    [103.68058013916016, 114.07504272460938]),
#   ('btv1b530977845.jpg',
#    'Dieulafoy, Georges (1839-1911)',
#    [124.44363403320312, 135.39854431152344]),
#   ('btv1b530979984.jpg',
#    'Drumont, Édouard (1844-1917)',
#    [126.3183364868164, 146.12411499023438]),
#   ('btv1b53111741w.jpg',
#    'Dubois, Théodore (1837-1924)',
#    [129.3963165283203, 119.6387939453125]),
#   ('btv1b53050884w.jpg',
#    'Dubufe, Édouard (1820-1883)',
#    [126.28257751464844, 127.67906951904297]),
#   ('btv1b53100850k.jpg',
#    'Duchâtel, Tanneguy (1803-1867)',
#    [126.03304290771484, 122.72999572753906]),
#   ('btv1b531204086.jpg',
#    'Dumesnil, Charles (1868-1946)',
#    [127.04291534423828, 135.34149169921875]),
#   ('btv1b53100845d.jpg',
#    'Duprez, Gilbert (1806-1896)',
#    [133.3511962890625, 130.8245849609375]),
#   ('btv1b531595683.jpg',
#    'Duruy, Victor (1811-1894)',
#    [141.20953369140625, 129.17303466796875]),
#   ('btv1b53104379x.jpg',
#    'Eiffel, Gustave (1832-1923)',
#    [136.2366943359375, 128.95376586914062]),
#   ('btv1b531445180.jpg',
#    'Viollet-le-Duc, Eugène-Emmanuel (1814-1879)',
#    [127.33891296386719, 136.20306396484375]),
#   ('btv1b53117555d.jpg',
#    'Faivre, Abel (1867-1945)',
#    [118.08350372314453, 117.82369995117188]),
#   ('btv1b53117456g.jpg',
#    'Faure, Sébastien (1858-1942)',
#    [128.9311981201172, 129.562744140625]),
#   ('btv1b53118864v.jpg',
#    'Fauré, Gabriel (1845-1924)',
#    [142.45838928222656, 125.44760131835938]),
#   ('btv1b531760462.jpg',
#    'Feydeau, Georges (1862-1921)',
#    [112.56712341308594, 132.14576721191406]),
#   ('btv1b53148510s.jpg',
#    'Flaubert, Gustave (1821-1880)',
#    [124.53134155273438, 132.82241821289062]),
#   ('btv1b53065903j.jpg',
#    'Le Flo, Adolphe (1804-1887)',
#    [136.64559936523438, 114.03659057617188]),
#   ('btv1b53097771d.jpg',
#    'Floquet, Charles (1828-1896)',
#    [138.23655700683594, 119.64878845214844]),
#   ('btv1b53181016d.jpg',
#    'France, Anatole (1844-1924)',
#    [128.2144775390625, 116.8892822265625]),
#   ('btv1b53079823p.jpg',
#    'Freycinet, Charles Louis de Saulces de (1828-1923)',
#    [135.36956787109375, 113.79857635498047]),
#   ('btv1b530655338.jpg',
#    'Frémiet, Emmanuel (1824-1910)',
#    [128.14166259765625, 117.40086364746094]),
#   ('btv1b53079820b.jpg',
#    'Fugère, Lucien (1848-1935)',
#    [116.27090454101562, 127.74871063232422]),
#   ('btv1b530980033.jpg',
#    'Guyon, Jean-Casimir-Félix (1831-1920)',
#    [134.67575073242188, 132.4002227783203]),
#   ('btv1b53100889v.jpg',
#    'Féval, Paul (1816-1887)',
#    [144.5842742919922, 142.6837158203125]),
#   ('btv1b53065737t.jpg',
#    'Gabrielli, Nicolò (1814-1891)',
#    [149.1268768310547, 129.94281005859375]),
#   ('btv1b531689244.jpg',
#    'Gallet, Louis (1835-1898)',
#    [118.87396240234375, 144.71165466308594]),
#   ('btv1b530800444.jpg',
#    'Gautier, Théophile (1811-1872)',
#    [132.87435913085938, 149.20245361328125]),
#   ('btv1b530979302.jpg',
#    'Giffard, Pierre (1853-1922)',
#    [120.00154876708984, 132.66908264160156]),
#   ('btv1b53080131r.jpg',
#    'Gill, André (1840-1885)',
#    [128.6109619140625, 137.1259002685547]),
#   ('btv1b530800800.jpg',
#    'Girardin, Émile de (1806-1881)',
#    [105.49066925048828, 129.183349609375]),
#   ('btv1b53165010g.jpg',
#    'Gobin, Charles Constant (1843-1907)',
#    [120.91993713378906, 110.15091705322266]),
#   ('btv1b53117430z.jpg',
#    'Goblet, René (1828-1905)',
#    [139.91207885742188, 122.6865234375]),
#   ('btv1b53080133n.jpg',
#    'Goncourt, Edmond de (1822-1896)',
#    [135.14927673339844, 136.1782684326172]),
#   ('btv1b531072354.jpg',
#    'Gounod, Charles (1818-1893)',
#    [134.1901092529297, 132.39395141601562]),
#   ('btv1b53107908w.jpg',
#    'Gramme, Zénobe Théophile (1826-1901)',
#    [124.25047302246094, 147.167724609375]),
#   ('btv1b531446045.jpg',
#    'Granier, Jeanne (1852-1939)',
#    [106.15992736816406, 109.85890197753906]),
#   ('btv1b53066441r.jpg',
#    'Grant, Ulysses Simpson (1822-1885)',
#    [142.09307861328125, 139.409423828125]),
#   ('btv1b530663220.jpg',
#    'Grisi, Carlotta (1819-1899)',
#    [106.75859832763672, 123.76162719726562]),
#   ('btv1b531471496.jpg',
#    'Grévy, Jules (1807-1891)',
#    [121.99846649169922, 111.65804290771484]),
#   ('btv1b53117380n.jpg',
#    'Guerne, Jules de (1855-1931)',
#    [128.75531005859375, 131.03919982910156]),
#   ('btv1b53117503f.jpg',
#    'Guitry, Sacha (1885-1957)',
#    [108.22882843017578, 111.32475280761719]),
#   ('btv1b53120436j.jpg',
#    'Guynemer, Georges (1894-1917)',
#    [134.62179565429688, 142.30393981933594]),
#   ('btv1b53050325z.jpg',
#    'Home, Daniel Dunglas (1833-1886)',
#    [121.3807601928711, 112.05001068115234]),
#   ('btv1b53050566t.jpg',
#    'Huet, Paul (1803-1869)',
#    [133.72303771972656, 117.45362854003906]),
#   ('btv1b531073147.jpg',
#    'Hugues, Clovis (1851-1907)',
#    [132.5286407470703, 144.0731201171875]),
#   ('btv1b53100938q.jpg',
#    'Isabey, Eugène (1803-1886)',
#    [139.9386749267578, 131.58938598632812]),
#   ('btv1b53050502j.jpg',
#    'Jackson, Stonewall (1824-1863)',
#    [112.44625091552734, 128.21156311035156]),
#   ('btv1b53050820m.jpg',
#    'Jouffroy, François (1806-1882)',
#    [131.0449676513672, 112.72916412353516]),
#   ('btv1b530663008.jpg',
#    'Marey, Étienne-Jules (1830-1904)',
#    [145.40469360351562, 139.81317138671875]),
#   ('btv1b53104428s.jpg',
#    "Penguilly L'Haridon, Octave (1811-1870)",
#    [119.10767364501953, 141.7810821533203]),
#   ('btv1b531078216.jpg',
#    'Lachenal, Edmond (1855-1948)',
#    [119.90958404541016, 141.12266540527344]),
#   ('btv1b530506844.jpg',
#    'Lalanne, Maxime François Antoine (1827-1886)',
#    [106.5865478515625, 132.20950317382812])]}

# %%
pd.read
