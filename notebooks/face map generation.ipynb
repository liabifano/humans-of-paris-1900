# %%
# !wget https://raw.githubusercontent.com/opencv/opencv/master/data/haarcascades/haarcascade_frontalface_default.xml

# %%
import json
import pandas as pd

from PIL import Image
import requests
from io import BytesIO

# %%
image_dataframe = pd.read_pickle('data/named_subjects.pkl')

# %%
import os

# %%
all_images = os.listdir('../humans_of_paris/app/static/img_full/')

# %%
all_images = [pic[:-len('.png')] for pic in all_images]

# %%
images_df = image_dataframe.id.map(lambda x: x.split('/')[-1]).tolist()

# %%
never_used_images = set(all_images).difference(images_df)

# %%
image_we_need = set(images_df).difference(set(all_images))

# %%
image_dataframe['img'] = images_df

# %%
image_dataframe[image_dataframe.img.isin(image_we_need)].id.to_csv('../../ndl-crop/identifiers.csv')
# Out:
# /Users/lguillain/opt/anaconda3/envs/fdh/lib/python3.7/site-packages/ipykernel_launcher.py:1: FutureWarning: The signature of `Series.to_csv` was aligned to that of `DataFrame.to_csv`, and argument 'header' will change its default value from False to True: please pass an explicit value to suppress this warning.
#   """Entry point for launching an IPython kernel.

# %%
len(never_used_images)
# Out:
# 1

# %%
len(image_we_need)
# Out:
# 1209

# %%
never_used_images
# Out:
# {'.DS_S'}

# %%
from os import listdir
import cv2
from numpy import asarray
import numpy as np

 
# extract a single face from a given photograph
def extract_face_show(image, required_size=(160, 160)):
    face_cascade = cv2.CascadeClassifier('haarcascade_frontalface_default.xml')
    img = cv2.cvtColor(np.array(image), cv2.COLOR_BGR2GRAY)
    faces = face_cascade.detectMultiScale(img, 1.1, 4)

    for (x, y, w, h) in faces:
        cv2.rectangle(img, (x, y), (x+w, y+h), (255, 0, 0), 2)
    # Display the output
    cv2.imshow('img', img)
    cv2.waitKey()
    cv2.destroyAllWindows()

# %%
def extract_face(image, required_size=(160, 160), idf=0):
    face_cascade = cv2.CascadeClassifier('haarcascade_frontalface_default.xml')
    # Read the input image
    img = cv2.cvtColor(np.array(image), cv2.COLOR_BGR2GRAY)
    # Detect faces
    faces = face_cascade.detectMultiScale(img, 1.03, 5) #play with parameters for better detection
    # Draw rectangle around the faces
    i=0
    for (x, y, w, h) in faces:
        r = max(w, h) / 2
        centerx = x + w / 2
        centery = y + h / 2
        nx = int(centerx - r)
        ny = int(centery - r)
        nr = int(r * 2)

        faceimg = img[ny:ny+nr, nx:nx+nr]
        lastimg = cv2.resize(faceimg, (32, 32))
        i += 1
        print(x, y, w, h)
        cv2.imwrite(f"images/image{i}_{idf}.jpg", lastimg)
        print(f'write {idf}')

# %% [markdown]
# Haar gives a lot of false positives, better methods exit. we can get slightly improved results by adapting resizing the image and adapting the thresold

# %%
sample = image_dataframe.identifier.sample(100)
sample.to_csv('images/sample.csv')
for doc in sample:
    url = doc+'/f1.highres.jpg'
    response = requests.get(url)
    img = Image.open(BytesIO(response.content))
    width, height = img.size
    factor = 500/width
    #extract_face(img.resize((int(width*factor), int(factor*height))), idf=doc[-len('btv1b53134455m'):])
# Out:
# /anaconda3/envs/fdh/lib/python3.7/site-packages/ipykernel_launcher.py:6: FutureWarning: The signature of `Series.to_csv` was aligned to that of `DataFrame.to_csv`, and argument 'header' will change its default value from False to True: please pass an explicit value to suppress this warning.
# 454 263 106 106
# write btv1b53170703n
# 174 412 68 68
# write btv1b53170703n
# 619 458 51 51
# write btv1b53170703n
# 740 603 34 34
# write btv1b53170703n
# 707 527 67 67
# write btv1b53170703n
# 301 672 45 45
# write btv1b53170703n
# 363 695 30 30
# write btv1b53170703n
# 511 1024 53 53
# write btv1b53170703n
# 458 405 153 153
# write btv1b531448273
# 195 582 617 617
# write btv1b531448273
# 897 735 57 57
# write btv1b531448273
# 330 147 331 331
# write btv1b53191447x
# 462 255 92 92
# write btv1b53191447x
# 484 237 97 97
# write btv1b531810473
# 22 381 30 30
# write btv1b531810473
# 659 883 70 70
# write btv1b531810473
# 32 422 68 68
# write btv1b530507241
# 414 469 159 159
# write btv1b530507241
# 529 768 69 69
# write btv1b530507241
# 208 1213 31 31
# write btv1b531689350
# 769 1105 58 58
# write btv1b531689350
# 532 981 62 62
# write btv1b531689350
# 523 1082 55 55
# write btv1b531689350
# 369 1156 26 26
# write btv1b531689350
# 400 411 71 71
# write btv1b530818326
# 323 599 45 45
# write btv1b530818326
# 321 615 44 44
# write btv1b530818326
# 299 670 66 66
# write btv1b530818326
# 810 832 35 35
# write btv1b530818326
# 807 1039 56 56
# write btv1b530818326
# 921 462 32 32
# write btv1b53082328x
# 420 512 221 221
# write btv1b53082328x
# 20 1268 52 52
# write btv1b53082328x
# 528 1430 56 56
# write btv1b53082328x
# 308 76 28 28
# write btv1b531395548
# 348 418 46 46
# write btv1b531395548
# 645 572 65 65
# write btv1b531395548
# 318 377 329 329
# write btv1b531716349
# 589 942 63 63
# write btv1b531716349
# 216 911 229 229
# write btv1b531716349
# 706 1101 44 44
# write btv1b531716349
# 335 379 392 392
# write btv1b53157462b
# 99 866 234 234
# write btv1b53157462b
# 500 1188 60 60
# write btv1b53157462b
# 915 1220 81 81
# write btv1b53157462b
# 335 331 237 237
# write btv1b53117396r
# 118 387 662 662
# write btv1b53117396r
# 597 682 71 71
# write btv1b53117396r
# 278 722 98 98
# write btv1b53117396r
# 738 944 55 55
# write btv1b53117396r
# 486 784 121 121
# write btv1b53117396r
# 579 909 80 80
# write btv1b53117396r
# 114 958 56 56
# write btv1b53117396r
# 373 283 322 322
# write btv1b53112011b
# 551 892 64 64
# write btv1b53112011b
# 88 1119 54 54
# write btv1b53112011b
# 460 336 193 193
# write btv1b531875633
# 398 401 82 82
# write btv1b531875633
# 27 1258 33 33
# write btv1b531875633
# 150 1206 37 37
# write btv1b531875633
# 315 351 318 318
# write btv1b530979626
# 364 238 82 82
# write btv1b53092345q
# 333 485 260 260
# write btv1b53092345q
# 386 1066 32 32
# write btv1b53092345q
# 600 1081 62 62
# write btv1b53092345q
# 32 1390 57 57
# write btv1b53092345q
# 558 462 33 33
# write btv1b531310463
# 406 449 85 85
# write btv1b531310463
# 450 607 79 79
# write btv1b531310463
# 252 681 63 63
# write btv1b531310463
# 86 966 173 173
# write btv1b531310463
# 363 1147 47 47
# write btv1b531310463
# 734 1060 86 86
# write btv1b531310463
# 360 487 255 255
# write btv1b530916086
# 490 878 29 29
# write btv1b530916086
# 308 888 54 54
# write btv1b530916086
# 942 1323 28 28
# write btv1b530916086
# 188 434 55 55
# write btv1b53171063t
# 495 397 94 94
# write btv1b53171063t
# 365 378 285 285
# write btv1b53171063t
# 371 653 353 353
# write btv1b53171063t
# 430 752 51 51
# write btv1b53171063t
# 696 872 45 45
# write btv1b53171063t
# 373 821 59 59
# write btv1b53171063t
# 566 907 51 51
# write btv1b53171063t
# 618 1026 48 48
# write btv1b53171063t
# 445 1082 34 34
# write btv1b53171063t
# 417 497 177 177
# write btv1b53071723j
# 783 760 40 40
# write btv1b53071723j
# 892 1440 36 36
# write btv1b53071723j
# 19 1321 52 52
# write btv1b53071723j
# 342 309 90 90
# write btv1b53149320s
# 696 676 170 170
# write btv1b53149320s
# 647 1009 62 62
# write btv1b53149320s

# %% [markdown]
# look at MTCNN which is a state of the art model for face detection (and related tasks). Install the module mtcnn but make sure to have a tensorflow version older than 2.0, so for instance 1.13.1

# %% [markdown]
# still some false positives but markedly better, need to check for false negatives

# %%
from mtcnn.mtcnn import MTCNN
# Out:
# Using TensorFlow backend.

# %%
model = MTCNN()

def extract_face_cnn(img, idf=0):
    img = np.array(img)
    faces = model.detect_faces(img)
    i=0
    for face in faces:
        box = face['box']
        (x, y, w, h) = (box[0], box[1], box[2], box[3])
        r = max(w, h) / 2
        centerx = x + w / 2
        centery = y + h / 2
        nx = int(centerx - r)
        ny = int(centery - r)
        nr = int(r * 2)

        faceimg = img[ny:ny+nr, nx:nx+nr]
        lastimg = cv2.resize(faceimg, (32, 32))
        i += 1
        print(x, y, w, h)
        cv2.imwrite(f"images/image{i}_{idf}.jpg", lastimg)
        print(f'write {idf}')
# Out:
# WARNING:tensorflow:From /Users/lguillain/opt/anaconda3/envs/fdh/lib/python3.7/site-packages/tensorflow/python/framework/op_def_library.py:263: colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.

# %%
from PIL import Image
import requests
from io import BytesIO

sample = pd.read_csv('images/sample.csv', header=None, index_col=0)[1]
for doc in sample:
    url = doc+'/f1.highres.jpg'
    response = requests.get(url)
    img = Image.open(BytesIO(response.content))
    width, height = img.size
    factor = 500/width
    extract_face_cnn(img,  idf=doc[-len('btv1b53134455m'):])

# %% [markdown]
# Analyzing facial vectors & clustering

# %% [markdown]
# # cropping images

# %%
def crop(img, minx, miny, maxx, maxy):
    return img[miny:maxy, minx:maxx]


def get_image(doc):
    url = doc+'/f1.highres.jpg'
    response = requests.get(url)
    img = Image.open(BytesIO(response.content))
    img = Image.open(BytesIO(response.content)).convert('RGB')
    img = np.array(img)
    return img

# %%
def get_face_image(doc):
    output_file = '../humans_of_paris/app/static/images/'+doc.id.split('/')[-1]+'.jpg'
    img = get_image(doc.id)
    cropped = crop(img, int(doc.left), int(doc.top), int(doc.right), int(doc.bottom))
    cv2.imwrite(output_file,  cv2.cvtColor(cropped, cv2.COLOR_RGB2BGR))

# %%
age_gender_lables
# Out:
#        left    top  right  bottom  width  height    gender        age  number  \
# 0     269.0  268.0  748.0   747.0  479.0   479.0  0.116277  47.741472     1.0
# 1     433.0  316.0  580.0   463.0  147.0   147.0  0.585720  27.465579     2.0
# 2     250.0  718.0  403.0   871.0  153.0   153.0  0.377803  40.358822     3.0
# 3     155.0  134.0  872.0   851.0  717.0   717.0  0.104841  44.487285     1.0
# 4     415.0  184.0  615.0   384.0  200.0   200.0  0.389818  27.194442     1.0
# ...     ...    ...    ...     ...    ...     ...       ...        ...     ...
# 1881  292.0  351.0  658.0   717.0  366.0   366.0  0.025766  47.032899     1.0
# 1882  355.0  310.0  596.0   551.0  241.0   241.0  0.033713  45.716630     1.0
# 1883  288.0  437.0  583.0   732.0  295.0   295.0  0.358721  26.078685     1.0
# 1884  310.0  214.0  739.0   643.0  429.0   429.0  0.108013  47.732863     1.0
# 1885  448.0  284.0  601.0   437.0  153.0   153.0  0.081239  31.406526     1.0
#
#                                                     id  \
# 0     https://gallica.bnf.fr/ark:/12148/btv1b53071608k
# 1     https://gallica.bnf.fr/ark:/12148/btv1b531622212
# 2     https://gallica.bnf.fr/ark:/12148/btv1b53071525p
# 3     https://gallica.bnf.fr/ark:/12148/btv1b53165139q
# 4     https://gallica.bnf.fr/ark:/12148/btv1b53117510h
# ...                                                ...
# 1881  https://gallica.bnf.fr/ark:/12148/btv1b53098072j
# 1882  https://gallica.bnf.fr/ark:/12148/btv1b53065399p
# 1883  https://gallica.bnf.fr/ark:/12148/btv1b530664193
# 1884  https://gallica.bnf.fr/ark:/12148/btv1b531271467
# 1885  https://gallica.bnf.fr/ark:/12148/btv1b53111936g
#
#                               name
# 0               Abbatucci, Séverin
# 1                     Abbott, Emma
# 2                   Abbéma, Louise
# 3     Abney, William de Wiveleslie
# 4                    Abott, Bessie
# ...                            ...
# 1881                   Édouard VII
# 1882                 Énault, Louis
# 1883   Éon, Charles de Beaumont d'
# 1884                 Étex, Antoine
# 1885               Étiévant, Henri
#
# [1886 rows x 11 columns]

# %%
import os

# %%
collected = set([x[:-len('.jpg')] for x in os.listdir('./images')])

# %%
len(os.listdir('./images'))
# Out:
# 1739

# %%
age_gender_lables = pd.read_json('age_gender_labeles.json')

# %%
to_collect = set(age_gender_lables.dropna().id.map(lambda x: x.split('/')[-1]).tolist()).difference(collected)

# %%
import numpy as np

# %%
age_gender_lables.dropna()[400:].apply(lambda x: get_face_image(x), axis=1)
# Out:
# 421     None
# 422     None
# 423     None
# 424     None
# 425     None
#         ...
# 1881    None
# 1882    None
# 1883    None
# 1884    None
# 1885    None
# Length: 1411, dtype: object

# %% [markdown]
# # Alternative face map clustering

# %%
import matplotlib.pyplot as plt

# %%
import numpy as np

# %%
with open('faces.json') as f:
    d = f.read()
    
face = pd.DataFrame(json.loads(d))

# %%
age_gender_lables = pd.read_json('data/age_gender_labeles_augmented.json')

# %%
age_gender_lables
# Out:
#                                           name gender_true   left    top  \
# 0               Abbatucci, Séverin (1821-1888)    masculin  269.0  268.0
# 1                     Abbott, Emma (1850-1891)     féminin  433.0  316.0
# 2                   Abbéma, Louise (1858-1927)     féminin  250.0  718.0
# 3     Abney, William de Wiveleslie (1843-1920)    masculin  155.0  134.0
# 4                    Abott, Bessie (1878-1919)     féminin  415.0  184.0
# ...                                        ...         ...    ...    ...
# 1869                 Énault, Louis (1824-1900)    masculin  355.0  310.0
# 1870   Éon, Charles de Beaumont d' (1728-1810)    masculin  288.0  437.0
# 1871                 Étex, Antoine (1808-1888)    masculin  310.0  214.0
# 1872               Étiévant, Henri (1870-1953)    masculin  448.0  284.0
# 1873    Č̌ebyšev, Pafnutij Lʹvovič (1821-1894)    masculin  160.0   69.0
#
#       right  bottom  width  height  gender_estimated        age  number  \
# 0     748.0   747.0  479.0   479.0          0.116277  47.741472     1.0
# 1     580.0   463.0  147.0   147.0          0.585720  27.465579     2.0
# 2     403.0   871.0  153.0   153.0          0.377803  40.358822     3.0
# 3     872.0   851.0  717.0   717.0          0.104841  44.487285     1.0
# 4     615.0   384.0  200.0   200.0          0.389818  27.194442     1.0
# ...     ...     ...    ...     ...               ...        ...     ...
# 1869  596.0   551.0  241.0   241.0          0.033713  45.716630     1.0
# 1870  583.0   732.0  295.0   295.0          0.358721  26.078685     1.0
# 1871  739.0   643.0  429.0   429.0          0.108013  47.732863     1.0
# 1872  601.0   437.0  153.0   153.0          0.081239  31.406526     1.0
# 1873  950.0   859.0  790.0   790.0          0.180912  64.070084     1.0
#
#                                                     id gender_estimates_binary
# 0     https://gallica.bnf.fr/ark:/12148/btv1b53071608k                masculin
# 1     https://gallica.bnf.fr/ark:/12148/btv1b531622212                 féminin
# 2     https://gallica.bnf.fr/ark:/12148/btv1b53071525p                masculin
# 3     https://gallica.bnf.fr/ark:/12148/btv1b53165139q                masculin
# 4     https://gallica.bnf.fr/ark:/12148/btv1b53117510h                masculin
# ...                                                ...                     ...
# 1869  https://gallica.bnf.fr/ark:/12148/btv1b53065399p                masculin
# 1870  https://gallica.bnf.fr/ark:/12148/btv1b530664193                masculin
# 1871  https://gallica.bnf.fr/ark:/12148/btv1b531271467                masculin
# 1872  https://gallica.bnf.fr/ark:/12148/btv1b53111936g                masculin
# 1873  https://gallica.bnf.fr/ark:/12148/btv1b531813331                masculin
#
# [1874 rows x 13 columns]

# %%
face = pd.merge(face, age_gender_lables, on='id')

# %%
references = face.iloc[:100].id.map(lambda x:  x.split('/')[-1]+'.jpg').tolist()
matrix = face.iloc[:100].face.tolist()

# %%
face_json = {'users': references, 'mat': matrix}

# %%
gender_lables = face.gender_true

# %%
matrix = face.face.tolist()

# %%
matrix = np.array(matrix)

# %%
from sklearn.decomposition import PCA
pca = PCA(n_components=2)

# %%
x_pca = pca.fit_transform(matrix)

# %%
gender_lables = gender_lables.map(lambda x: 0 if x == 'masculin'  else 1)

# %%
plt.scatter(x_pca[:,0], x_pca[:,1], c = gender_lables, cmap=plt.cm.bwr)

# %%
x_pca = (x_pca - x_pca.min())*200+100

# %%
from sklearn import random_projection

# %%
import numpy as np

# %%
transformer = random_projection.SparseRandomProjection(n_components=2, density=.99)
X_new = transformer.fit_transform(matrix)

# %%
plt.scatter(X_new[:,1], X_new[:,0], c = gender_lables, cmap=plt.cm.bwr)

# %%
from sklearn.manifold import TSNE

X_embedded = TSNE(n_components=2).fit_transform(matrix)

# %%
plt.scatter(X_embedded[:,1], X_embedded[:,0], c = gender_lables, cmap=plt.cm.bwr)

# %% [markdown]
# # importance of faces

# %%
fame = pd.read_pickle('data/merged_dataframe.pkl')#.rank_fr.plot(kind='hist', bins=100)

# %%
fame.columns
# Out:
# Index(['id', 'name', 'gender', 'id_list', 'weight', 'note', 'bnf_link',
#        'wiki_en_text', 'wiki_en_link', 'wiki_fr_text', 'url_fr',
#        'age_estimate', 'gender_estimate', 'tags'],
#       dtype='object')

# %%
fame.sort_values(by='weight', ascending=False)[['name', 'weight', 'id']].dropna()[:100]
# Out:
#                                                    name  weight  \
# 235                     Bouguereau, William (1825-1905)   237.0
# 521                       Delacroix, Eugène (1798-1863)    69.5
# 580                        Dieterle, Amélie (1870-1941)    64.0
# 451                        Courbet, Gustave (1819-1877)    62.5
# 1629                           Sand, George (1804-1876)    62.0
# ...                                                 ...     ...
# 1601                      Roybet, Ferdinand (1840-1920)    14.5
# 1636                      Sardou, Victorien (1831-1908)    14.0
# 1770                          Vallès, Jules (1832-1885)    14.0
# 727   Freycinet, Charles Louis de Saulces de (1828-1...    14.0
# 820                Gramme, Zénobe Théophile (1826-1901)    14.0
#
#                                                     id
# 235   https://gallica.bnf.fr/ark:/12148/btv1b53050879q
# 521   https://gallica.bnf.fr/ark:/12148/btv1b53104547j
# 580   https://gallica.bnf.fr/ark:/12148/btv1b53111808r
# 451   https://gallica.bnf.fr/ark:/12148/btv1b53050548w
# 1629  https://gallica.bnf.fr/ark:/12148/btv1b53066110x
# ...                                                ...
# 1601  https://gallica.bnf.fr/ark:/12148/btv1b530976891
# 1636  https://gallica.bnf.fr/ark:/12148/btv1b53065822j
# 1770  https://gallica.bnf.fr/ark:/12148/btv1b53050489m
# 727   https://gallica.bnf.fr/ark:/12148/btv1b53079823p
# 820   https://gallica.bnf.fr/ark:/12148/btv1b53107908w
#
# [100 rows x 3 columns]

# %%
famous_id = fame.sort_values(by='weight', ascending=False)[['name', 'weight', 'id']].dropna()[:250].id.tolist()

# %%
cond = face.id.isin(famous_id)

# %%
references = face[cond].id.map(lambda x: x.split('/')[-1]+'.jpg').tolist()

# %%
names = face[cond].name.tolist()

# %%
matrix = face[cond].face.tolist()
matrix = np.array(matrix)

# %%
x_pca = pca.fit_transform(matrix)
x_pca = (x_pca - x_pca.min())*200+100

# %%
gender_lables = face[cond].gender_true
gender_lables = gender_lables.map(lambda x: 0 if x == 'masculin'  else 1)

plt.scatter(x_pca[:,0], x_pca[:,1], c = gender_lables, cmap=plt.cm.bwr)

# %%
X_embedded = TSNE(n_components=2).fit_transform(matrix)
X_embedded = ((X_embedded - X_embedded.min()))*20
plt.scatter(X_embedded[:,1], X_embedded[:,0], c = gender_lables, cmap=plt.cm.bwr)

# %%
X_embedded
# Out:
# array([[372.9285   , 193.69196  ],
#        [339.9997   , 267.1669   ],
#        [  6.551647 , 170.80492  ],
#        [127.52083  , 147.23827  ],
#        [165.30606  , 344.45734  ],
#        [278.2642   ,  60.078907 ],
#        [276.53082  ,  79.4777   ],
#        [279.16208  , 106.01567  ],
#        [203.51535  , 181.57758  ],
#        [443.3429   , 421.98605  ],
#        [349.56516  , 155.53911  ],
#        [120.684784 , 295.67944  ],
#        [326.306    , 223.72775  ],
#        [120.09035  , 276.01062  ],
#        [256.79416  , 167.40889  ],
#        [102.70455  , 221.86978  ],
#        [268.25592  , 385.10056  ],
#        [390.78384  , 167.96375  ],
#        [199.40805  , 284.35052  ],
#        [285.78625  , 446.799    ],
#        [121.74338  , 306.5692   ],
#        [193.98163  , 388.7172   ],
#        [107.58267  , 157.69731  ],
#        [245.62317  , 219.328    ],
#        [409.47107  , 432.0903   ],
#        [323.7546   , 251.80692  ],
#        [197.99255  ,  14.662819 ],
#        [175.32974  , 205.41559  ],
#        [201.33109  , 217.303    ],
#        [451.35162  , 475.47668  ],
#        [196.22496  , 146.90396  ],
#        [375.09247  , 285.8469   ],
#        [150.54953  , 354.31216  ],
face_json = {'users': tuples}

with open('../humans_of_paris/app/static/clustered.json', 'w') as outfile:
    json.dump(face_json, outfile)

# %%
face_json
# Out:
# {'users': [('btv1b53050602x.jpg',
#    'Lazerges, Hippolyte (1817-1887)',
#    [372.9284973144531, 193.69195556640625]),
#   ('btv1b530508625.jpg',
#    'Lee, Robert Edward (1807-1870)',
#    [339.99969482421875, 267.1669006347656]),
#   ('btv1b53169003s.jpg',
#    'Lemaire, Madeleine (1845-1928)',
#    [6.551647186279297, 170.80491638183594]),
#   ('btv1b53081576h.jpg',
#    'Lesseps, Ferdinand de (1805-1894)',
#    [127.52082824707031, 147.23826599121094]),
#   ('btv1b53118945v.jpg',
#    'Balzac, Honoré de (1799-1850)',
#    [165.30606079101562, 344.45733642578125]),
#   ('btv1b53118904r.jpg',
#    'Lhermitte, Léon (1844-1925)',
#    [278.2641906738281, 60.07890701293945]),
#   ('btv1b53107869f.jpg',
#    'Liszt, Franz (1811-1886)',
#    [276.53082275390625, 79.47769927978516]),
#   ('btv1b53139302j.jpg',
#    'Littré, Émile (1801-1881)',
#    [279.1620788574219, 106.01567077636719]),
#   ('btv1b53071953j.jpg',
#    'Banville, Théodore de (1823-1891)',
#    [203.51535034179688, 181.57757568359375]),
#   ('btv1b53104358n.jpg',
#    'Livry, Emma (1842-1863)',
#    [443.3428955078125, 421.9860534667969]),
#   ('btv1b53117467b.jpg',
#    'Loubet, Émile (1838-1929)',
#    [349.5651550292969, 155.5391082763672]),
#   ('btv1b53173251z.jpg',
#    'Forain, Jean-Louis (1852-1931)',
#    [120.68478393554688, 295.679443359375]),
#   ('btv1b53187665c.jpg',
#    'Faure, Jean-Baptiste (1830-1914)',
#    [326.3059997558594, 223.72775268554688]),
#   ('btv1b53104352z.jpg',
#    'Léopold II (1835-1909 ; roi des Belges)',
#    [120.09034729003906, 276.0106201171875]),
#   ('btv1b531079562.jpg',
#    'Mallarmé, Stéphane (1842-1898)',
#    [256.7941589355469, 167.4088897705078]),
#   ('btv1b531079115.jpg',
#    'Daguerre, Louis-Jacques-Mandé (1787-1851)',
#    [102.70455169677734, 221.86978149414062]),
#   ('btv1b53066421x.jpg',
#    'Manet, Édouard (1832-1883)',
#    [268.25592041015625, 385.1005554199219]),
#   ('btv1b530820636.jpg',
#    'Marcère, Émile de (1828-1918)',
#    [390.7838439941406, 167.9637451171875]),
#   ('btv1b53120421w.jpg',
#    'Mariani, Angelo (1838-1914)',
#    [199.40805053710938, 284.35052490234375]),
#   ('btv1b53163494d.jpg',
#    'Charcot, Jean-Martin (1825-1893)',
#    [285.7862548828125, 446.79901123046875]),
#   ('btv1b53187754w.jpg',
#    'Massenet, Jules (1842-1912)',
#    [121.74337768554688, 306.5692138671875]),
#   ('btv1b53097844w.jpg',
#    'Maupassant, Guy de (1850-1893)',
#    [193.98162841796875, 388.7171936035156]),
#   ('btv1b53154290w.jpg',
#    'Milligan McLane, Robert (1815-1898)',
#    [107.58267211914062, 157.6973114013672]),
#   ('btv1b53065901n.jpg',
#    'Meissonier, Ernest (1815-1891)',
#    [245.6231689453125, 219.3280029296875]),
#   ('btv1b53159750v.jpg',
#    'Melba, Nellie (1861-1931)',
#    [409.4710693359375, 432.0903015136719]),
#   ('btv1b530664354.jpg',
#    'Mendès, Catulle (1841-1909)',
#    [323.7546081542969, 251.80691528320312]),
#   ('btv1b53137698d.jpg',
#    'Meyerbeer, Giacomo (1791-1864)',
#    [197.9925537109375, 14.662818908691406]),
#   ('btv1b53104374p.jpg',
#    'Michelet, Jules (1798-1874)',
#    [175.32974243164062, 205.41558837890625]),
#   ('btv1b53050342f.jpg',
#    'Millet, Aimé (1819-1891)',
#    [201.33108520507812, 217.30299377441406]),
#   ('btv1b53118947r.jpg',
#    'Mistinguett (1875-1956)',
#    [451.35162353515625, 475.4766845703125]),
#   ('btv1b53120447d.jpg',
#    'Barrès, Maurice (1862-1923)',
#    [196.22496032714844, 146.90396118164062]),
#   ('btv1b531188157.jpg',
#    'Monzie, Anatole de (1876-1947)',
#    [375.09246826171875, 285.8468933105469]),
#   ('btv1b531377332.jpg',
#    'Munkácsy, Mihály (1844-1900)',
#    [150.54953002929688, 354.3121643066406]),
#   ('btv1b530663438.jpg',
#    'Nadar (1820-1910)',
#    [139.23306274414062, 200.3828125]),
#   ('btv1b53050768g.jpg',
#    'Nerval, Gérard de (1808-1855)',
#    [137.2896270751953, 70.61819458007812]),
#   ('btv1b53071541q.jpg',
#    'Adam, Juliette (1836-1936)',
#    [454.78082275390625, 403.8681640625]),
#   ('btv1b530978420.jpg',
#    'Bartholdi, Auguste (1834-1904)',
#    [280.80419921875, 146.37271118164062]),
#   ('btv1b53137892g.jpg',
#    'Lecomte Du Noüy, Jean Jules Antoine (1842-1923)',
#    [270.83392333984375, 337.8213806152344]),
#   ('btv1b530658895.jpg',
#    'Nélaton, Auguste (1807-1873)',
#    [125.75849914550781, 29.004650115966797]),
#   ('btv1b53065796v.jpg',
#    'Palizzi, Giuseppe (1812-1888)',
#    [185.9077606201172, 321.9443359375]),
#   ('btv1b53097697j.jpg',
#    'Pasteur, Louis (1822-1895)',
#    [255.20150756835938, 31.918354034423828]),
#   ('btv1b53066314g.jpg',
#    'Patti, Adelina (1843-1919)',
#    [426.59765625, 457.40179443359375]),
#   ('btv1b531203348.jpg',
#    'Peary, Robert Edwin (1856-1920)',
#    [202.51553344726562, 83.25013732910156]),
#   ('btv1b53117382j.jpg',
#    'Pelletan, Camille (1846-1915)',
#    [141.5092010498047, 279.3792419433594]),
#   ('btv1b53065834v.jpg',
#    'Pelletan, Eugène (1813-1884)',
#    [285.16986083984375, 280.4659729003906]),
#   ('btv1b53118918z.jpg',
#    'Pelliot, Paul (1878-1945)',
#    [351.630615234375, 365.9068298339844]),
#   ('btv1b53100776q.jpg',
#    'Baudry, Paul (1828-1886)',
#    [322.945556640625, 356.12066650390625]),
#   ('btv1b53104423j.jpg',
#    'Philipon, Charles (1800-1862)',
#    [85.92512512207031, 148.32965087890625]),
#   ('btv1b531189501.jpg',
#    'Poincaré, Raymond (1860-1934)',
#    [346.66033935546875, 60.17240524291992]),
#   ('btv1b53104433z.jpg',
#    'Ponsard, François (1814-1867)',
#    [105.04354858398438, 193.6165008544922]),
#   ('btv1b53050493b.jpg',
#    'Pottier, Eugène (1816-1887)',
#    [295.253662109375, 205.36695861816406]),
#   ('btv1b53181166v.jpg',
#    'Pozzi, Samuel (1846-1918)',
#    [310.1584167480469, 272.1077880859375]),
#   ('btv1b530655874.jpg',
#    'Prim, Juan (1814-1870)',
#    [183.53060913085938, 153.1788787841797]),
#   ('btv1b53065572g.jpg',
#    'Ratisbonne, Louis (1827-1900)',
#    [216.64651489257812, 223.45567321777344]),
#   ('btv1b53107957h.jpg',
#    'Reid, Whitelaw (1837-1912)',
#    [247.04751586914062, 400.01226806640625]),
#   ('btv1b530924364.jpg',
#    'Richepin, Jean (1849-1926)',
#    [190.9532928466797, 329.7525634765625]),
#   ('btv1b531521416.jpg',
#    'Becquerel, Antoine Henri (1852-1908)',
#    [238.50425720214844, 331.05401611328125]),
#   ('btv1b53066038z.jpg',
#    'Rigault, Raoul (1846-1871)',
#    [259.8552551269531, 317.5169677734375]),
#   ('btv1b53117364m.jpg',
#    'Rodenbach, Georges (1855-1898)',
#    [299.23565673828125, 422.2885437011719]),
#   ('btv1b53107958z.jpg',
#    'Rodin, Auguste (1840-1917)',
#    [279.46337890625, 224.00086975097656]),
#   ('btv1b53098148c.jpg',
#    'Roll, Alfred Philippe (1846-1919)',
#    [362.00238037109375, 210.5261993408203]),
#   ('btv1b530977756.jpg',
#    'Van Beers, Jan (1852-1927)',
#    [345.701416015625, 417.33953857421875]),
#   ('btv1b530657494.jpg',
#    'Rothschild, Alphonse de (1827-1905)',
#    [246.52374267578125, 362.8576354980469]),
#   ('btv1b53117425s.jpg',
#    'Roty, Oscar (1846-1911)',
#    [290.2925720214844, 427.9720764160156]),
#   ('btv1b53120269c.jpg',
#    'Rousseau, Théodore (1812-1867)',
#    [151.33053588867188, 267.2142028808594]),
#   ('btv1b530976891.jpg',
#    'Roybet, Ferdinand (1840-1920)',
#    [412.84210205078125, 341.0123291015625]),
#   ('btv1b53091611g.jpg',
#    'Réjane (1856-1920)',
#    [375.04296875, 390.3103942871094]),
#   ('btv1b531717337.jpg',
#    'Salis, Rodolphe (1851-1897)',
#    [243.09280395507812, 275.9996337890625]),
#   ('btv1b53066110x.jpg',
#    'Sand, George (1804-1876)',
#    [413.11029052734375, 499.3240051269531]),
#   ('btv1b53050476v.jpg',
#    'Sarasate, Pablo de (1844-1908)',
#    [366.72119140625, 307.32550048828125]),
#   ('btv1b53065822j.jpg',
#    'Sardou, Victorien (1831-1908)',
#    [33.570003509521484, 117.62446594238281]),
#   ('btv1b531415039.jpg',
#    'Schoelcher, Victor (1804-1893)',
#    [182.82791137695312, 115.25291442871094]),
#   ('btv1b53141540m.jpg',
#    'Scribe, Eugène (1791-1861)',
#    [0.0, 253.3958282470703]),
#   ('btv1b53118954t.jpg',
#    'Galliéni, Joseph-Simon (1849-1916)',
#    [220.54830932617188, 52.08179473876953]),
#   ('btv1b53161928h.jpg',
#    'Sorel, Cécile (1873-1966)',
#    [447.258056640625, 427.0987548828125]),
#   ('btv1b53050893v.jpg',
#    'Belly, Léon (1827-1877)',
#    [67.21286010742188, 326.9878845214844]),
#   ('btv1b531071472.jpg',
#    'Stewart, Julius Leblanc (1855-1919)',
#    [294.2119445800781, 339.3459777832031]),
#   ('btv1b53104484g.jpg',
#    'Thalberg, Sigismond (1812-1871)',
#    [224.6171417236328, 169.93392944335938]),
#   ('btv1b53141675g.jpg',
#    'Thiers, Adolphe (1797-1877)',
#    [135.68429565429688, 163.2505645751953]),
#   ('btv1b531139632.jpg',
#    'Thomas, Ambroise (1811-1896)',
#    [234.2393798828125, 97.84142303466797]),
#   ('btv1b53148623x.jpg',
#    'Tissandier, Albert (1839-1906)',
#    [118.16546630859375, 314.4620361328125]),
#   ('btv1b53141659f.jpg',
#    'Toulmouche, Auguste (1829-1890)',
#    [219.5814666748047, 297.260009765625]),
#   ('btv1b530508017.jpg',
#    'Trousseau, Armand (1801-1867)',
#    [247.30430603027344, 111.78274536132812]),
#   ('btv1b53169280h.jpg',
#    'Uzanne, Octave (1851-1931)',
#    [163.30752563476562, 379.3733215332031]),
#   ('btv1b530921271.jpg',
#    'Chevandier de Valdrôme, Eugène (1810-1878)',
#    [75.021728515625, 213.59788513183594]),
#   ('btv1b530716163.jpg',
#    'Aicard, Jean (1848-1921)',
#    [221.1682891845703, 328.701171875]),
#   ('btv1b53050489m.jpg',
#    'Vallès, Jules (1832-1885)',
#    [372.57049560546875, 290.191162109375]),
#   ('btv1b53066306z.jpg',
#    'Berlioz, Hector (1803-1869)',
#    [273.53875732421875, 116.86517333984375]),
#   ('btv1b53120281m.jpg',
#    'Vernet, Horace (1789-1863)',
#    [288.5743713378906, 76.77855682373047]),
#   ('btv1b530505604.jpg',
#    'Veuillot, Louis (1813-1883)',
#    [115.18765258789062, 145.8550262451172]),
#   ('btv1b53118862z.jpg',
#    'Bernard, Tristan (1866-1947)',
#    [231.2001190185547, 280.7206726074219]),
#   ('btv1b530656309.jpg',
#    'Wallace, Richard (1818-1890)',
#    [42.42292404174805, 265.0841064453125]),
#   ('btv1b53162160w.jpg',
#    'Bernhardt, Sarah (1844-1923)',
#    [482.7818298339844, 472.71673583984375]),
#   ('btv1b530921076.jpg',
#    'Wheatstone, Charles (1802-1875)',
#    [91.99526977539062, 162.33230590820312]),
#   ('btv1b53104498p.jpg',
#    'Whitworth, Joseph (1803-1887 ; sir)',
#    [155.20974731445312, 109.08076477050781]),
#   ('btv1b530503717.jpg',
#    'Wolff, Albert (1825-1891)',
#    [417.03582763671875, 271.73626708984375]),
#   ('btv1b530504561.jpg',
#    'Wyld, William (1806-1889)',
#    [175.27174377441406, 82.15394592285156]),
#   ('btv1b53092121b.jpg',
#    'Zola, Émile (1840-1902)',
#    [183.41336059570312, 274.61505126953125]),
#   ('btv1b53066129c.jpg',
#    "Barbey d'Aurevilly, Jules (1808-1889)",
#    [264.543701171875, 207.86659240722656]),
#   ('btv1b53100801z.jpg',
#    'Bertall (1820-1882)',
#    [271.3198547363281, 333.01007080078125]),
#   ('btv1b531511463.jpg',
#    'Berthelot, Marcellin (1827-1907)',
#    [127.01114654541016, 224.0098876953125]),
#   ('btv1b53107953q.jpg',
#    'Bertillon, Alphonse (1853-1914)',
#    [291.86492919921875, 260.593017578125]),
#   ('btv1b530508820.jpg',
#    'Bethmont, Eugène (1804-1860)',
#    [262.5787658691406, 123.36241912841797]),
#   ('btv1b53071509n.jpg',
#    'Albani, Emma (1847-1930)',
#    [466.1453857421875, 455.48101806640625]),
#   ('btv1b531341452.jpg',
#    'Bodmer, Karl (1809-1893)',
#    [81.9788818359375, 214.62966918945312]),
#   ('btv1b53050824d.jpg',
#    'Bonheur, Rosa (1822-1899)',
#    [6.895084381103516, 170.03057861328125]),
#   ('btv1b53071980f.jpg',
#    'Bonvin, François (1817-1887)',
#    [155.5557098388672, 121.76748657226562]),
#   ('btv1b53169109v.jpg',
#    'Booth, Catherine (1829-1890)',
#    [436.57513427734375, 472.067626953125]),
#   ('btv1b53107942v.jpg',
#    'Albert Ier (1848-1922 ; prince de Monaco)',
#    [174.56192016601562, 302.82073974609375]),
#   ('btv1b53050879q.jpg',
#    'Bouguereau, William (1825-1905)',
#    [108.49471282958984, 255.37611389160156]),
#   ('btv1b531515650.jpg',
#    'Boulanger, Georges (1837-1891)',
#    [214.7697296142578, 264.0472106933594]),
#   ('btv1b53159810k.jpg',
#    'Brazza, Pierre Savorgnan de (1852-1905)',
#    [300.8138732910156, 365.44219970703125]),
#   ('btv1b530719273.jpg',
#    'Breton, Jules (1827-1906)',
#    [182.49472045898438, 131.42254638671875]),
#   ('btv1b53120317s.jpg',
#    'Broglie, Albert de (1821-1901)',
#    [163.86322021484375, 90.5685043334961]),
#   ('btv1b53171770j.jpg',
#    'Bruant, Aristide (1851-1925)',
#    [201.74383544921875, 197.95530700683594]),
#   ('btv1b531078161.jpg',
#    'Calvé, Emma (1858-1942)',
#    [423.89898681640625, 452.0585632324219]),
#   ('btv1b53072189s.jpg',
#    'Carlos (1848-1909 ; prince de Bourbon)',
#    [292.5233154296875, 302.2002868652344]),
#   ('btv1b530664784.jpg',
#    'Cham (1818-1879)',
#    [364.36041259765625, 185.30014038085938]),
#   ('btv1b531732727.jpg',
#    'Chaminade, Cécile (1857-1944)',
#    [424.8372802734375, 491.2640075683594]),
#   ('btv1b531008066.jpg',
#    'Chenavard, Paul (1807-1895)',
#    [159.14576721191406, 68.38059997558594]),
#   ('btv1b53097877g.jpg',
#    'Chéret, Jules (1836-1932)',
#    [76.96700286865234, 318.50994873046875]),
#   ('btv1b53072195d.jpg',
#    'Clairin, Georges (1843-1919)',
#    [316.1688232421875, 345.28363037109375]),
#   ('btv1b53072132k.jpg',
#    'Clemenceau, Georges (1841-1929)',
#    [137.734130859375, 406.2950134277344]),
#   ('btv1b530506861.jpg',
#    'Clésinger, Auguste (1814-1883)',
#    [116.70825958251953, 225.44573974609375]),
#   ('btv1b53072208d.jpg',
#    'Comte, Charles',
#    [400.2671813964844, 355.46240234375]),
#   ('btv1b53100832n.jpg',
#    'Coppée, François (1842-1908)',
#    [402.15179443359375, 465.71539306640625]),
#   ('btv1b530720862.jpg',
#    'Coquelin, Constant (1841-1909)',
#    [30.218734741210938, 273.9204406738281]),
#   ('btv1b53066447f.jpg',
#    'Corot, Camille (1796-1875)',
#    [170.27906799316406, 176.19432067871094]),
#   ('btv1b53050555z.jpg',
#    'Couder, Auguste (1789-1873)',
#    [195.48240661621094, 69.23565673828125]),
#   ('btv1b53050548w.jpg',
#    'Courbet, Gustave (1819-1877)',
#    [207.6378173828125, 349.60772705078125]),
#   ('btv1b53050505w.jpg',
#    'Cousin, Victor (1792-1867)',
#    [55.21921157836914, 138.2431640625]),
#   ('btv1b53117332g.jpg',
#    'Crosti, Eugène (1833-1908)',
#    [246.72412109375, 262.0794982910156]),
#   ('btv1b531008138.jpg',
#    'Crémieux, Adolphe (1796-1880)',
#    [241.34579467773438, 22.90264129638672]),
#   ('btv1b53100834j.jpg',
#    'Darboy, Georges (1813-1871)',
#    [196.95127868652344, 8.363876342773438]),
#   ('btv1b53100861f.jpg',
#    'Daudet, Alphonse (1840-1897)',
#    [361.9941711425781, 383.1739807128906]),
#   ('btv1b53120224g.jpg',
#    'Daumier, Honoré (1808-1879)',
#    [95.28204345703125, 115.21604919433594]),
#   ('btv1b53100870d.jpg',
#    'Dauzats, Adrien (1804-1868)',
#    [224.0367889404297, 76.40953063964844]),
#   ('btv1b53065619h.jpg',
#    'Davis, Jefferson (1808-1889)',
#    [357.828857421875, 333.01580810546875]),
#   ('btv1b53118843k.jpg',
#    'Debussy, Claude (1862-1918)',
#    [202.14181518554688, 373.7327575683594]),
#   ('btv1b53065973f.jpg',
#    'About, Edmond (1828-1885)',
#    [153.03652954101562, 254.3170166015625]),
#   ('btv1b53104547j.jpg',
#    'Delacroix, Eugène (1798-1863)',
#    [313.1017150878906, 136.25360107421875]),
#   ('btv1b531077675.jpg',
#    'Duez, Ernest-Ange (1843-1896)',
#    [214.31246948242188, 295.5277099609375]),
#   ('btv1b53107899p.jpg',
#    'Desboutin, Marcellin (1823-1902)',
#    [122.9163818359375, 360.1666564941406]),
#   ('btv1b53120250x.jpg',
#    'Dierx, Léon (1838-1912)',
#    [235.76162719726562, 71.50435638427734]),
#   ('btv1b53111808r.jpg',
#    'Dieterle, Amélie (1870-1941)',
#    [415.2261047363281, 479.63909912109375]),
#   ('btv1b53072650d.jpg',
#    'Diéterle, Jules (1811-1889)',
#    [220.25067138671875, 108.2169189453125]),
#   ('btv1b530979984.jpg',
#    'Drumont, Édouard (1844-1917)',
#    [131.00790405273438, 177.17164611816406]),
#   ('btv1b53111741w.jpg',
#    'Dubois, Théodore (1837-1924)',
#    [251.96417236328125, 165.17144775390625]),
#   ('btv1b53050884w.jpg',
#    'Dubufe, Édouard (1820-1883)',
#    [179.4295654296875, 227.47772216796875]),
#   ('btv1b53100850k.jpg',
#    'Duchâtel, Tanneguy (1803-1867)',
#    [223.00848388671875, 176.84425354003906]),
#   ('btv1b531484682.jpg',
#    'Carolus-Duran (1837-1917)',
#    [126.43948364257812, 215.53848266601562]),
#   ('btv1b531595683.jpg',
#    'Duruy, Victor (1811-1894)',
#    [227.59136962890625, 41.29264831542969]),
#   ('btv1b53050699s.jpg',
#    'Amaury-Duval (1808-1885)',
#    [142.17556762695312, 39.77428436279297]),
#   ('btv1b53164942p.jpg',
#    'Eames, Emma (1865-1952)',
#    [477.4136962890625, 466.2894287109375]),
#   ('btv1b53104379x.jpg',
#    'Eiffel, Gustave (1832-1923)',
#    [151.3268280029297, 152.7767791748047]),
#   ('btv1b531445180.jpg',
#    'Viollet-le-Duc, Eugène-Emmanuel (1814-1879)',
#    [225.52198791503906, 244.7710418701172]),
#   ('btv1b53117555d.jpg',
#    'Faivre, Abel (1867-1945)',
#    [348.7475891113281, 400.9056396484375]),
#   ('btv1b53117456g.jpg',
#    'Faure, Sébastien (1858-1942)',
#    [142.74359130859375, 209.74380493164062]),
#   ('btv1b53118864v.jpg',
#    'Fauré, Gabriel (1845-1924)',
#    [264.313232421875, 41.91120147705078]),
#   ('btv1b531760462.jpg',
#    'Feydeau, Georges (1862-1921)',
#    [308.5390625, 373.38201904296875]),
#   ('btv1b53148510s.jpg',
#    'Flaubert, Gustave (1821-1880)',
#    [223.78030395507812, 212.58360290527344]),
#   ('btv1b53097771d.jpg',
#    'Floquet, Charles (1828-1896)',
#    [118.61109924316406, 55.6230354309082]),
#   ('btv1b53092388q.jpg',
#    'Fraipont, Gustave (1849-1923)',
#    [209.0933837890625, 363.27984619140625]),
#   ('btv1b53181016d.jpg',
#    'France, Anatole (1844-1924)',
#    [282.64398193359375, 177.68646240234375]),
#   ('btv1b53079823p.jpg',
#    'Freycinet, Charles Louis de Saulces de (1828-1923)',
#    [196.68133544921875, 23.77105712890625]),
#   ('btv1b530655338.jpg',
#    'Frémiet, Emmanuel (1824-1910)',
#    [276.78289794921875, 173.82437133789062]),
#   ('btv1b53079820b.jpg',
#    'Fugère, Lucien (1848-1935)',
#    [334.9544982910156, 312.51165771484375]),
#   ('btv1b53100889v.jpg',
#    'Féval, Paul (1816-1887)',
#    [284.49945068359375, 258.828857421875]),
#   ('btv1b53065570k.jpg',
#    'Gautier, Judith (1845-1917)',
#    [435.556396484375, 437.026611328125]),
#   ('btv1b530800444.jpg',
#    'Gautier, Théophile (1811-1872)',
#    [107.44644165039062, 367.53631591796875]),
#   ('btv1b531811696.jpg',
#    'Geffroy, Gustave (1855-1926)',
#    [132.2635040283203, 399.230712890625]),
#   ('btv1b53080131r.jpg',
#    'Gill, André (1840-1885)',
#    [197.84378051757812, 244.00650024414062]),
#   ('btv1b530800800.jpg',
#    'Girardin, Émile de (1806-1881)',
#    [116.44157409667969, 15.888633728027344]),
#   ('btv1b53117430z.jpg',
#    'Goblet, René (1828-1905)',
#    [208.18231201171875, 135.33526611328125]),
#   ('btv1b53080133n.jpg',
#    'Goncourt, Edmond de (1822-1896)',
#    [93.73985290527344, 92.01180267333984]),
#   ('btv1b531072354.jpg',
#    'Gounod, Charles (1818-1893)',
#    [92.0899658203125, 185.07568359375]),
#   ('btv1b53107908w.jpg',
#    'Gramme, Zénobe Théophile (1826-1901)',
#    [131.15277099609375, 120.88803100585938]),
#   ('btv1b53066441r.jpg',
#    'Grant, Ulysses Simpson (1822-1885)',
#    [283.8165283203125, 225.71246337890625]),
#   ('btv1b530663220.jpg',
#    'Grisi, Carlotta (1819-1899)',
#    [35.82277297973633, 117.22438049316406]),
#   ('btv1b531471496.jpg',
#    'Grévy, Jules (1807-1891)',
#    [27.677593231201172, 315.1214904785156]),
#   ('btv1b53117503f.jpg',
#    'Guitry, Sacha (1885-1957)',
#    [418.45166015625, 409.21295166015625]),
#   ('btv1b53080120w.jpg',
#    'Guizot, Guillaume (1833-1892)',
#    [327.13555908203125, 227.5113525390625]),
#   ('btv1b53120436j.jpg',
#    'Guynemer, Georges (1894-1917)',
#    [402.82623291015625, 358.927490234375]),
#   ('btv1b53117389p.jpg',
#    'Harpignies, Henri (1819-1916)',
#    [225.70236206054688, 91.25357055664062]),
#   ('btv1b53187866k.jpg',
#    'Hervieu, Paul (1857-1915)',
#    [246.45458984375, 359.7637939453125]),
#   ('btv1b53050325z.jpg',
#    'Home, Daniel Dunglas (1833-1886)',
#    [27.379074096679688, 310.734619140625]),
#   ('btv1b53050566t.jpg',
#    'Huet, Paul (1803-1869)',
#    [133.78192138671875, 78.01727294921875]),
#   ('btv1b53100938q.jpg',
#    'Isabey, Eugène (1803-1886)',
#    [101.84347534179688, 136.35752868652344]),
#   ('btv1b53050502j.jpg',
#    'Jackson, Stonewall (1824-1863)',
#    [343.78607177734375, 341.61444091796875]),
#   ('btv1b53107901r.jpg',
#    'Henner, Jean-Jacques (1829-1905)',
#    [57.291603088378906, 193.78839111328125]),
#   ('btv1b53050820m.jpg',
#    'Jouffroy, François (1806-1882)',
#    [159.53916931152344, 39.0730094909668]),
#   ('btv1b530663008.jpg',
#    'Marey, Étienne-Jules (1830-1904)',
#    [302.68560791015625, 272.141357421875]),
#   ('btv1b53104428s.jpg',
#    "Penguilly L'Haridon, Octave (1811-1870)",
#    [227.97415161132812, 381.4735412597656]),
#   ('btv1b531078216.jpg',
#    'Lachenal, Edmond (1855-1948)',
#    [232.52792358398438, 390.876708984375]),
#   ('btv1b530506844.jpg',
#    'Lalanne, Maxime François Antoine (1827-1886)',
#    [329.8150634765625, 143.1060333251953]),
#   ('btv1b531634751.jpg',
#    'Langtry, Lillie (1853-1929)',
#    [416.81591796875, 404.3203125])]}

# %%
pd.read
