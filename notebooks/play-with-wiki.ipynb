# %%
import wikipedia
import fdh_gallica
import collections

wikipedia.set_lang('en')

from fdh_gallica import Search

# %%
# search = Search(all_fields="atelier nadar", dc_type="image", dc_creator='atelier nadar')
# search.execute()
# search.total_records
# df = json_normalize(json.loads(json.dumps(obj.records)))
# Out:
# ...
# 23550

# %%
df.shape
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-16-633337079cd0> in <module>()
# ----> 1 df.shape
#
# NameError: name 'df' is not defined

# %%
import json
df = json_normalize(json.loads(json.dumps(obj.records)))
df.shape
# Out:
# (23550, 13)

# %%
re_execute = True
if re_execute:
    obj = Search(all_fields='atelier Nadar', dc_type='image', dc_creator='Atelier Nadar')
    obj.execute()
    obj.retry()

    df = json_normalize(json.loads(json.dumps(obj.records)))
# Out:
# ...
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-15-e9f5f72c5255> in <module>()
#       5     obj.retry()
#       6
# ----> 7     df = json_normalize(json.loads(json.dumps(obj.records)))
#
# NameError: name 'json_normalize' is not defined

# %%
from pandas.io.json import json_normalize

# %%
len(search.records)
# Out:
# 23445

# %%
search.records[1]
# Out:
# OrderedDict([('dc:creator', 'Atelier Nadar. Photographe'),
#              ('dc:date', '1875-1895'),
#              ('dc:format',
#               ["1 photogr. pos. sur papier albuminé : d'après nég. sur verre ; 14,5 x 10,5 cm",
#                'image/jpeg',
#                'Nombre total de vues : 1']),
#              ('dc:identifier',
#               ['https://gallica.bnf.fr/ark:/12148/btv1b531634912',
#                'Numéro commercial : Atelier Nadar 8039 B']),
#              ('dc:language', ['fre', 'français']),
#              ('dc:relation',
#               ["Extrait de : [Album de référence de l'Atelier Nadar. Vol. 36]",
#                'Notice du catalogue : http://catalogue.bnf.fr/ark:/12148/cb454086620']),
#              ('dc:rights', ['domaine public', 'public domain']),
#              ('dc:source',
#               'Bibliothèque nationale de France, département Estampes et photographie, FT 4-NA-238 (22)'),
# ...

# %%
search.records[1]['dc:subject']
# Out:
# 'Portraits du théâtre -- 19e siècle'

# %%
len(search.records)
# Out:
# 23445

# %%
collections.Counter([r['dc:subject'] for r in search.records])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-10-4461cdda6d49> in <module>()
# ----> 1 collections.Counter([r['dc:subject'] for r in search.records])
#
# ~/miniconda3/lib/python3.6/collections/__init__.py in __init__(*args, **kwds)
#     533             raise TypeError('expected at most 1 arguments, got %d' % len(args))
#     534         super(Counter, self).__init__()
# --> 535         self.update(*args, **kwds)
#     536
#     537     def __missing__(self, key):
#
# ~/miniconda3/lib/python3.6/collections/__init__.py in update(*args, **kwds)
#     620                     super(Counter, self).update(iterable) # fast path when counter is empty
#     621             else:
# --> 622                 _count_elements(self, iterable)
#     623         if kwds:
#     624             self.update(kwds)
#
# TypeError: unhashable type: 'list'

# %%
[r for r in search.records]
# Out:
# [OrderedDict([('dc:creator', 'Atelier Nadar. Photographe'),
#               ('dc:date', '1875-1895'),
#               ('dc:format',
#                ["1 photogr. pos. sur papier albuminé : d'après nég. sur verre ; 14,5 x 10,5 cm",
#                 'image/jpeg',
#                 'Nombre total de vues : 1']),
#               ('dc:identifier',
#                ['https://gallica.bnf.fr/ark:/12148/btv1b53163492h',
#                 'Numéro commercial : Atelier Nadar 8040']),
#               ('dc:language', ['fre', 'français']),
#               ('dc:relation',
#                ["Extrait de : [Album de référence de l'Atelier Nadar. Vol. 36]",
#                 'Notice du catalogue : http://catalogue.bnf.fr/ark:/12148/cb45408666c']),
#               ('dc:rights', ['domaine public', 'public domain']),
#               ('dc:source',
#                'Bibliothèque nationale de France, département Estampes et photographie, FT 4-NA-238 (22)'),
# ...

# %%
wikipedia.search('Holda Eldorado')
# Out:
# ['Stars and planetary systems in fiction']

# %%
wikipedia.search('Supra. Opéra')
# Out:
# ['World language',
#  'Joseph Hémard',
#  'Vincenzo Manfredini',
#  'Daniel Spoerri',
#  'Todd Lasance',
#  'Ithu Namma Veedu',
#  'List of Latin words with English derivatives',
#  'Credo quia absurdum',
#  'Cécile Chaminade',
#  'Paul Walker']

# %%
wikipedia.search('Barak')
# Out:
# ['Barak',
#  'Ehud Barak',
#  'Barak 8',
#  'Barak 1',
#  'Barack Obama',
#  'Barak River',
#  'Barak Valley',
#  'Barak (surname)',
#  'Barak (given name)',
#  'Aharon Barak']

# %%
ny = wikipedia.page("New York City")

# %%
ny.content[0:100]
# Out:
# 'The City of New York, usually called either New York City (NYC) or simply New York (NY), is the most'

# %%
wikipedia.summary('Google', sentences=2)
# Out:
# 'Google LLC is an American multinational technology company that specializes in Internet-related services and products, which include online advertising technologies, search engine, cloud computing, software, and hardware. It is considered one of the Big Four technology companies, alongside Amazon, Apple, and Facebook.Google was founded in September 1998 by Larry Page and Sergey Brin while they were Ph.D. students at Stanford University in California.'
