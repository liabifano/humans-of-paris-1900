# %%
from fdh_gallica import Periodical, Search, Document
from fdh_gallica.parallel_process import iiif_urls_for_documents

from tqdm.autonotebook import tqdm

import json
import pandas as pd
from pandas.io.json import json_normalize


from itertools import chain
from itertools import compress
import re

# %%
# %matplotlib inline

# %% [markdown]
# get all images with relevant query

# %%
re_execute = False
if re_execute:
    obj = Search(all_fields='atelier Nadar', dc_type='image', dc_creator='Atelier Nadar')
    obj.execute()
    print(f'number of fetched documents: {len(obj.documents)}')
    print(f'total records {obj.total_records}')
    print('retry fetching ...')
    obj.retry()
    print(f'number of fetched documents: {len(obj.documents)}')

    df = json_normalize(json.loads(json.dumps(obj.records)))
    print('save documents to local')
    # list handling becomes a pain of we save as csv
    df.to_pickle('raw_df.pkl')

# %%
df = pd.read_pickle('raw_df.pkl')

# %% [markdown]
# parse identifier for easier access:

# %%
image_dataframe = pd.DataFrame(df['dc:identifier']\
                               .map(lambda x: x[0] if type(x) == list else x))\
                               .rename(columns={'dc:identifier':'identifier'})

df['id'] = image_dataframe

# %% [markdown]
# ### useless dataframes

# %% [markdown]
# remove them for ease of use, next ones contain all the same content

# %% [markdown]
# ### removing them

# %%
del df['dc:type']
del df['dc:language']
del df['dc:format']
del df['dc:identifier']
del df['dc:rights']
del df['dc:publisher']

# %% [markdown]
# # getting information about subjects

# %%
#some objects are stored as list, others arent, use if else to handle
df['subject_is_list'] = df['dc:subject'].map(lambda x: type(x) == list)

# %%
df['len_list'] = df[df.subject_is_list]['dc:subject'].map(len)

# %% [markdown]
# length is non uniform ... we will have to unnest

# %%
df.len_list.value_counts()
# Out:
# 2.0    12834
# 3.0      748
# 4.0      239
# 5.0      233
# 6.0       10
# 7.0        9
# Name: len_list, dtype: int64

# %%
df[df.subject_is_list]['dc:subject'].map(lambda x: x).value_counts().head()
# Out:
# [Bernhardt, Sarah (1844-1923) -- Portraits, Portraits du théâtre -- 19e siècle]          266
# [Réjane (1856-1920) -- Portraits, Portraits du théâtre -- 19e siècle]                    118
# [Théo, Louise (1854-1922) -- Portraits, Portraits du théâtre -- 19e siècle]              109
# [Simon-Girard, Juliette (1859-1959) -- Portraits, Portraits du théâtre -- 19e siècle]     84
# [Lantelme, Marie -- Portraits, Portraits du théâtre -- 19e siècle]                        83
# Name: dc:subject, dtype: int64

# %%
df2 = df[['id','dc:subject','dc:title','subject_is_list','len_list']]

# %%
subject1 = df2['dc:subject'][~df2.subject_is_list].unique().tolist()

# %%
subject1
# Out:
# ['Portraits du théâtre -- 19e siècle',
#  'Portraits de studio -- 19e siècle',
#  'Portraits collectifs -- 19e siècle',
#  'Scènes théâtrales -- 19e siècle',
#  'Portraits -- 19e siècle',
#  'Portraits équestres -- 19e siècle',
#  'Expositions de photographie',
#  'Tableaux vivants et mises en scène -- 19e siècle',
#  'Portraits de plein air -- 19e siècle',
#  'Portraits après décès -- 19e siècle',
#  'Portraits de studio',
#  "Vues d'intérieur -- 19e siècle",
#  'Luco, François (18..-1882) -- Portraits',
#  'Paysages -- 19e siècle',
#  'Cham (1818-1879) -- Oeuvres -- Dessin',
#  'Carvalho, Léon (1825-1897) -- Tombes',
#  'Sand, George (1804-1876) -- Statues',
#  'Caricatures et dessins humoristiques -- 19e siècle',
#  'Figuet, Gabrielle (1862-1889) -- Portraits',
#  'Delmas, Jean-François (1861-1933) -- Portraits']

# %%
subjects_to_exclude = list(set(subject1) - set(['Luco, François (18..-1882) -- Portraits',
                                                'Figuet, Gabrielle (1862-1889) -- Portraits',
                                                'Cham (1818-1879) -- Oeuvres -- Dessin',
                                                'Delmas, Jean-François (1861-1933) -- Portraits',
                                                'Carvalho, Léon (1825-1897) -- Tombes',
                                                'Sand, George (1804-1876) -- Statues']))

# %%
df2['len_list'][~df2.len_list.isna()].groupby(df2.len_list).size()
# Out:
# len_list
# 2.0    12834
# 3.0      748
# 4.0      239
# 5.0      233
# 6.0       10
# 7.0        9
# Name: len_list, dtype: int64

# %%
df2['dc:subject'][df2.len_list == 7].tolist()
# Out:
# [['Larnaudie, Louis François (1819-1899) -- Portraits',
#   'Narong, Phra (1836?-18..) -- Portraits',
#   'Navaï, Phra (1828?-18..) -- Portraits',
#   'Rajikosa Thipusi (1818?-18..?) -- Portraits',
#   'Sarb Vijisy -- Portraits',
#   'Xai, Pho (1849?-19..?) -- Portraits',
#   'Portraits collectifs -- 19e siècle'],
#  ['Mary-Albert, Madame (1855-....) -- Portraits',
#   'Duhamel, Biana (1870-1910) -- Portraits',
#   'Christian (1821-1890) -- Portraits',
#   'Scipion (18..-19.. ; acteur) -- Portraits',
#   'Portraits du théâtre -- 19e siècle',
#   'Portraits collectifs -- 19e siècle',
#   'Scènes théâtrales -- 19e siècle'],
#  ['Mary-Albert, Madame (1855-....) -- Portraits',
#   'Duhamel, Biana (1870-1910) -- Portraits',
#   'Christian (1821-1890) -- Portraits',
#   'Scipion (18..-19.. ; acteur) -- Portraits',
#   'Portraits du théâtre -- 19e siècle',
#   'Portraits collectifs -- 19e siècle',
#   'Scènes théâtrales -- 19e siècle'],
#  ['Mary-Albert, Madame (1855-....) -- Portraits',
#   'Duhamel, Biana (1870-1910) -- Portraits',
#   'Christian (1821-1890) -- Portraits',
#   'Scipion (18..-19.. ; acteur) -- Portraits',
#   'Portraits du théâtre -- 19e siècle',
#   'Portraits collectifs -- 19e siècle',
#   'Scènes théâtrales -- 19e siècle'],
#  ['Mary-Albert, Madame (1855-....) -- Portraits',
#   'Duhamel, Biana (1870-1910) -- Portraits',
#   'Christian (1821-1890) -- Portraits',
#   'Scipion (18..-19.. ; acteur) -- Portraits',
#   'Portraits du théâtre -- 19e siècle',
#   'Portraits collectifs -- 19e siècle',
#   'Scènes théâtrales -- 19e siècle'],
#  ['Gélabert, Conchita, Marie (1858-19.. ; actrice) -- Portraits',
#   'Vois, Ernest (1846-1902) -- Portraits',
#   'Milher (1834-1898) -- Portraits',
#   'Luco, François (18..-1882) -- Portraits',
#   'Portraits du théâtre -- 19e siècle',
#   'Portraits collectifs -- 19e siècle',
#   'Scènes théâtrales -- 19e siècle'],
#  ['Gélabert, Conchita, Marie (1858-19.. ; actrice) -- Portraits',
#   'Vois, Ernest (1846-1902) -- Portraits',
#   'Milher (1834-1898) -- Portraits',
#   'Luco, François (18..-1882) -- Portraits',
#   'Portraits du théâtre -- 19e siècle',
#   'Portraits collectifs -- 19e siècle',
#   'Scènes théâtrales -- 19e siècle'],
#  ['Mary-Albert, Madame (1855-....) -- Portraits',
#   'Duhamel, Biana (1870-1910) -- Portraits',
#   'Christian (1821-1890) -- Portraits',
#   'Scipion (18..-19.. ; acteur) -- Portraits',
#   'Portraits du théâtre -- 19e siècle',
#   'Portraits collectifs -- 19e siècle',
#   'Scènes théâtrales -- 19e siècle'],
#  ['Mary-Albert, Madame (1855-....) -- Portraits',
#   'Duhamel, Biana (1870-1910) -- Portraits',
#   'Christian (1821-1890) -- Portraits',
#   'Scipion (18..-19.. ; acteur) -- Portraits',
#   'Portraits du théâtre -- 19e siècle',
#   'Portraits collectifs -- 19e siècle',
#   'Scènes théâtrales -- 19e siècle']]

# %%
def subject_filter(x):
    if type(x) == str:
        if x in subjects_to_exclude:
            result = ''
        else:
            result = [x]
    elif type(x) == list:
        temp = []
        for s in x:
            if s not in subjects_to_exclude:
                #x.remove(s)
                temp.append(s)
        result = temp
    else:
        result = type(x)
    return result

# %%
df2['subjects'] = df2['dc:subject'].apply(subject_filter)
# Out:
# C:\Users\haeeun\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
#df2['subjects'][df2.len_list== 7].tolist()

# %%
df2['number_of_subjects'] = df2['subjects'].apply(len)
# Out:
# C:\Users\haeeun\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
df2.groupby(df2.number_of_subjects).size()
# Out:
# number_of_subjects
# 0     9599
# 1    12881
# 2      853
# 3      189
# 4        9
# 5        3
# 6        1
# dtype: int64

# %%
df2 = df2.drop(['dc:subject', 'subject_is_list','len_list'],axis=1)

# %%
df2 = df2[df2.number_of_subjects != 0]

# %%
df2
# Out:
#                                                      id  \
# 7      https://gallica.bnf.fr/ark:/12148/btv1b53168872x
# 8      https://gallica.bnf.fr/ark:/12148/btv1b531688701
# 9      https://gallica.bnf.fr/ark:/12148/btv1b53171770j
# 10     https://gallica.bnf.fr/ark:/12148/btv1b53168873c
# 13     https://gallica.bnf.fr/ark:/12148/btv1b531651494
# ...                                                 ...
# 23528  https://gallica.bnf.fr/ark:/12148/btv1b531203810
# 23530  https://gallica.bnf.fr/ark:/12148/btv1b53123957r
# 23531  https://gallica.bnf.fr/ark:/12148/btv1b53124037v
# 23533  https://gallica.bnf.fr/ark:/12148/btv1b53124131j
# 23534  https://gallica.bnf.fr/ark:/12148/btv1b53124259b
#
#                                                 dc:title  \
# 7      [Me Auguez] : [photographie, tirage de démonst...
# 8      [Me Auguez] : [photographie, tirage de démonst...
# 9      M. Bruant : [photographie, tirage de démonstra...
# 10     Me Auguez : [photographie, tirage de démonstra...
# 13     M. A. Brasseur : [photographie, tirage de démo...
# ...                                                  ...
# 23528  M. Hignette : [photographie, tirage de démonst...
# 23530  [Brémont] : [photographie, tirage de démonstra...
# 23531  [Caron] : [photographie, tirage de démonstrati...
# 23533  Croizette : [photographie, tirage de démonstra...
# 23534  [Capoul] : [photographie, tirage de démonstrat...
#
#                                            subjects  number_of_subjects
# 7       [Auguez, Mathilde (1868-1955) -- Portraits]                   1
# 8       [Auguez, Mathilde (1868-1955) -- Portraits]                   1
# 9       [Bruant, Aristide (1851-1925) -- Portraits]                   1
# 10      [Auguez, Mathilde (1868-1955) -- Portraits]                   1
# 13      [Brasseur, Albert (1862-1932) -- Portraits]                   1
# ...                                             ...                 ...
# 23528                                [Ombre portée]                   1
# 23530      [Brémont, Léon (1852-1939) -- Portraits]                   1
# 23531      [Caron, Cécile (1852-1923) -- Portraits]                   1
# 23533  [Croizette, Sophie (1847-1901) -- Portraits]                   1
# 23534     [Capoul, Victor (1839-1924) -- Portraits]                   1
#
# [13936 rows x 4 columns]

# %%
def title_filter(x):
    if type(x) == list:
        x = ''.join(x)
    
    if type(x) == str:
        try:
            result = x.split(':')[0].strip().strip('[]')
        except:
            result = x
    else:
        result = x
        
    return result

# %%
df2['title'] = df2['dc:title'].apply(title_filter)
#df2 = df2[df2.number_of_subjects!=0]

# %%
df2
# Out:
#                                                      id  \
# 7      https://gallica.bnf.fr/ark:/12148/btv1b53168872x
# 8      https://gallica.bnf.fr/ark:/12148/btv1b531688701
# 9      https://gallica.bnf.fr/ark:/12148/btv1b53171770j
# 10     https://gallica.bnf.fr/ark:/12148/btv1b53168873c
# 13     https://gallica.bnf.fr/ark:/12148/btv1b531651494
# ...                                                 ...
# 23528  https://gallica.bnf.fr/ark:/12148/btv1b531203810
# 23530  https://gallica.bnf.fr/ark:/12148/btv1b53123957r
# 23531  https://gallica.bnf.fr/ark:/12148/btv1b53124037v
# 23533  https://gallica.bnf.fr/ark:/12148/btv1b53124131j
# 23534  https://gallica.bnf.fr/ark:/12148/btv1b53124259b
#
#                                                 dc:title  \
# 7      [Me Auguez] : [photographie, tirage de démonst...
# 8      [Me Auguez] : [photographie, tirage de démonst...
# 9      M. Bruant : [photographie, tirage de démonstra...
# 10     Me Auguez : [photographie, tirage de démonstra...
# 13     M. A. Brasseur : [photographie, tirage de démo...
# ...                                                  ...
# 23528  M. Hignette : [photographie, tirage de démonst...
# 23530  [Brémont] : [photographie, tirage de démonstra...
# 23531  [Caron] : [photographie, tirage de démonstrati...
# 23533  Croizette : [photographie, tirage de démonstra...
# 23534  [Capoul] : [photographie, tirage de démonstrat...
#
#                                            subjects  number_of_subjects  \
# 7       [Auguez, Mathilde (1868-1955) -- Portraits]                   1
# 8       [Auguez, Mathilde (1868-1955) -- Portraits]                   1
# 9       [Bruant, Aristide (1851-1925) -- Portraits]                   1
# 10      [Auguez, Mathilde (1868-1955) -- Portraits]                   1
# 13      [Brasseur, Albert (1862-1932) -- Portraits]                   1
# ...                                             ...                 ...
# 23528                                [Ombre portée]                   1
# 23530      [Brémont, Léon (1852-1939) -- Portraits]                   1
# 23531      [Caron, Cécile (1852-1923) -- Portraits]                   1
# 23533  [Croizette, Sophie (1847-1901) -- Portraits]                   1
# 23534     [Capoul, Victor (1839-1924) -- Portraits]                   1
#
#                 title
# 7           Me Auguez
# 8           Me Auguez
# 9           M. Bruant
# 10          Me Auguez
# 13     M. A. Brasseur
# ...               ...
# 23528     M. Hignette
# 23530         Brémont
# 23531           Caron
# 23533       Croizette
# 23534          Capoul
#
# [13936 rows x 5 columns]

# %%
def name_filter(x):
    return [s.split('--')[0].strip() for s in x]

# %%
_prenames = df2.subjects.apply(name_filter)

# %%
_prenames
# Out:
# 7         [Auguez, Mathilde (1868-1955)]
# 8         [Auguez, Mathilde (1868-1955)]
# 9         [Bruant, Aristide (1851-1925)]
# 10        [Auguez, Mathilde (1868-1955)]
# 13        [Brasseur, Albert (1862-1932)]
#                       ...
# 23528                     [Ombre portée]
# 23530        [Brémont, Léon (1852-1939)]
# 23531        [Caron, Cécile (1852-1923)]
# 23533    [Croizette, Sophie (1847-1901)]
# 23534       [Capoul, Victor (1839-1924)]
# Name: subjects, Length: 13936, dtype: object

# %%
def is_name(x):
    names = []
    for s in x:
        if '(' not in s and ',' not in s:
            pass
        else:
            names.append(s.split('--')[0].strip())
    return names

def not_name(x):
    words = []
    for s in x:
        if '(' not in s and ',' not in s:
            words.append(s)
        else:
            pass
    return words

# %%
not_names = _prenames.apply(not_name).tolist()
is_names = _prenames.apply(is_name).tolist()

# %%
is_names = list(set(chain.from_iterable(is_names)))
not_names = list(set(chain.from_iterable(not_names)))

# %%
not_names
# Out:
# ['République',
#  'Ambassadeurs chinois',
#  'Haltérophiles',
#  'Alliance franco-russe',
#  'Singes',
#  'Âne',
#  'Sarb Vijisy',
#  'Chien',
#  "Montreurs d'animaux savants",
#  'Oiseaux parleurs',
#  'Franck-Mel',
#  'Cavalières',
#  'Diplomates russes',
#  'Tournée Brasseur',
#  'Présidents',
#  'Animaux de cirque',
#  'Cyclistes',
#  'Chat domestique',
#  'Scènes historiques',
#  'Poupées',
#  'Casseroles',
#  'Aéronautes',
#  'Avocats',
#  'Escrimeurs',
#  'France. Ministère des finances',
#  "Portraits d'intérieur",
#  'Pianistes',
#  'Hôtels particuliers',
#  'Sculpture de figures humaines',
#  'Cornistes',
#  'Hôpitaux',
#  'Vigne',
#  'Mères et nourrissons',
#  'Trapézistes',
#  'Mandoline',
#  'Autobus',
#  'Chasseurs',
#  'Antonine',
#  'Représentations animalières',
#  'Cravaches',
#  'Autoportraits',
#  'Paysages urbains',
#  'Journaux français',
#  'Scènes',
#  "Indiens d'Amérique",
#  'Piano',
#  'Nourrissons',
#  'Dessin',
#  "Ateliers d'artistes",
#  'Cour et courtisans',
#  'Travestis',
#  'Sang',
#  'Ombre portée',
#  'Géants',
#  'Enfants',
#  'Noirs',
#  'Femmes',
#  'Juges',
#  'Violonistes',
#  'Peinture',
#  "Représentations d'objet",
#  'Nageurs',
#  'Bicyclettes',
#  'Religieux',
#  'Généraux',
#  'Ensembles de musique de chambre',
#  'Décorations militaires',
#  'Minstrel shows',
#  'Ballons',
#  'Phénomènes de cirque',
#  'Clowns',
#  'Ambassadeurs portugais',
#  'Actrices travesties',
#  'Hommes',
#  'Costumes',
#  'Danse orientale',
#  'Scènes théâtrales',
#  'Ambassadeurs uruguayens',
#  'Harpistes',
#  'Enfants acteurs',
#  'Ambassadeurs japonais',
#  'Diplomates danois',
#  "Vues d'architecture",
#  'Roues',
#  'Tricycles',
#  'Prêtres',
#  'Acteurs travestis',
#  'Violoncellistes',
#  'Danseuses',
#  'Jumeaux siamois',
#  'Colonisation',
#  'Appareils photographiques',
#  'Statues']

# %%
is_names
# Out:
# ['Turgenev, Ivan Sergeevič (1818-1883)',
#  'Arnoldson, Sigrid (1861-1943)',
#  'Peschard, Marie Blanche (1843-1888)',
#  'Lacressonnière (1819-1893)',
#  'Rajikosa Thipusi (1818?-18..?)',
#  'Grisier, Augustin (1791-1865)',
#  'Tardieu, Ambroise (1818-1879)',
#  'Mareschal, Gabriel (1853-1927)',
#  'Alexandre (1814-1904)',
#  'Feyghine (1863-1882)',
#  'Mondos, Jules (1867-1932)',
#  'Brazza, Pierre Savorgnan de (1852-1905)',
#  'Marey, Étienne-Jules (1830-1904)',
#  'Hagron, Alexis (1845-1909)',
#  'Ponsin, Zélia (1843-1885)',
#  'Montagny, Étienne (1816-1895)',
#  'Renauld, Ernest (1869-1939)',
#  'Desmoulin, Fernand (1853-1914)',
#  'Mistinguett (1875-1956)',
#  'Picard, Ernest (1821-1877)',
#  'Matharel de Fiennes, Charles de (1814-18..?)',
#  'Velpeau, Alfred-Armand-Louis-Marie (1795-1867)',
#  'Laffitte, Charles, Pierre, Eugène (1803-1875)',
#  'Henner, Jean-Jacques (1829-1905)',
#  'Belhomme, Hippolyte (1854-1923)',
#  'Goupil, Léon Lucien (1834-1891)',
#  'Home, Daniel Dunglas (1833-1886)',
#  'Galitzin, Georg (1823-1872)',
#  'Lagasse, Louis (1860-1940)',
#  'Silvestre de Sacy, Samuel Ustazade (1801-1879)',
#  'Bernède, Arthur (1871-1937)',
#  'Heilbronn, Marie (1851-1886)',
#  'Villar de Volpini, Elisa (1835-1887)',
#  'Grenet-Dancourt, Ernest (1859-1913)',
#  'Pages, Herald de (1815?-19..)',
#  'Laurent-Lapp, J. (1836-1904)',
#  'Desbarrolles, Adolphe (1801-1886)',
#  'Cochery, Georges (1855-1914)',
#  'Petitjean, Bernard (1829-1884)',
#  'Breton, Jules (1827-1906)',
#  'Huart, Louis (1813-1865)',
#  'Picot, François Édouard (1786-1868)',
#  'Veuillot, Louis (1813-1883)',
#  'Blanc, Charles (1813-1882)',
#  'Nouguès, Jean (1875-1932)',
#  'Pory-Papy, Pierre-Marie (1805-1874)',
#  'Bruneau, Alfred (1857-1934)',
#  'Bianchi, Bianca (1855?-1947)',
#  'Numa, Paul (1865-19..)',
#  'Carlix, Suzanne (1872-19..)',
#  'Blanchon, Émile Henri (1845-19..)',
#  'Jourdan, Louis (1810-1881)',
#  'Flourens, Émile (1841-1920)',
#  'Delmas, Jean-François (1861-1933)',
#  'Clappier, Félix (1812-1885)',
#  'Bertrand, Eugène (1834-1899)',
#  'Daubray (1837-1892)',
#  'Dreyfus, Abraham (1847-1926)',
#  'Conny, Julien-Édouard (1818-1900 ; baron de)',
#  'Offenbach, Jacques (1819-1880)',
#  'Barbot, Andréa (1852-1923)',
#  'Petit, Léonce (1839-1884)',
#  'Allou, Roger (1855-1911)',
#  'Maubant (1821-1902)',
#  'Mermeix (1859-1930)',
#  'Gavault, Paul (1867-1951)',
#  'Bonaparte, Napoléon-Joseph-Charles-Paul (1822-1891)',
#  'Elven, Suzanne (18..-1906)',
#  'Platel, Félix (1832-1888)',
#  'Cresson, Ernest (1824-1902)',
#  'Sand, Maurice (1823-1889)',
#  'Mitchell, Robert (1839-1916)',
#  'Lachenal, Edmond (1855-1948)',
#  'Gautier, Estelle',
#  'Calzado, Toribio (17..-18.. ; Directeur du théâtre italien de Paris)',
#  'Chagas, João (1863-1925)',
#  'Yvan, Napoléon-Alexandre (1802-18.. ; baron)',
#  'Mendès, Catulle (1841-1909)',
#  'Rigault, Raoul (1846-1871)',
#  'Rivolta (18..-19.. ; danseuse)',
#  'Roggers, Henriette (1881-1950)',
#  'Lordereau, René (18..-1867)',
#  'Jeanron, Philippe-Auguste (1808-1877)',
#  'Georges, Édouard (1829-1903)',
#  "Ennery, Adolphe d' (1811-1899)",
#  'Coquelin, Constant (1841-1909)',
#  'Joncières, Victorin (1839-1903)',
#  'Belloy, Auguste de (1815-1871)',
#  'Tessandier, Aimée Jeanne (1851-1923)',
#  'Lovy, Jules (1801-1863)',
#  'Thibaut, Berthe (18..-19.. ; chanteuse lyrique)',
#  'Plassan, Antoine-Émile (1817-18..)',
#  'Luguet, René (1813?-1904)',
#  'Noël, Lucien (1873-1930)',
#  'Bertin, Édouard (1797-1871)',
#  'Darmont, Albert (1863-1913)',
#  'Got, Edmond (1822-1901)',
#  'Serrano y Domínguez, Francisco (1810-1885 ; duc de la Torre)',
#  'Guillaume, Eugène (1822-1905)',
#  'Horteloup, Paul (1837-1893)',
#  'Bonnaire, Éléonore (1852-1910)',
#  'Deschanel, Émile (1819-1904)',
#  'Mérante, Louis (1828-1887)',
#  'Ducos du Hauron, Alcide (1830-1909)',
#  'Perronnet, Joanni (1855-1900)',
#  'Réjane (1856-1920)',
#  'Murger, Henry (1822-1861)',
#  'Marcère, Émile de (1828-1918)',
#  'Étex, Antoine (1808-1888)',
#  'Gille, Philippe (1831-1901)',
#  'Jacquin, Emile (1861-19..)',
#  'Kropotkin, Petr Alekseevič (1842-1921)',
#  'Tarride, Abel (1865-1951)',
#  'Penne, Olivier de (1831-1897)',
#  'Pugno, Raoul (1852-1914)',
#  'Febvre, Frédéric (1833-1916)',
#  'Lakeman, Stephen Bartlett (1825-1897)',
#  'Bonheur, Rosa (1822-1899)',
#  'Talexy, Adrien (1821-1881)',
#  'Mazerolle, Alexis-Joseph (1826-1889)',
#  'Chevrolat, Auguste (1799-1884)',
#  'Carriès, Joseph (1855-1894)',
#  'Van Beers, Jan (1852-1927)',
#  'Montrouge (1826-1903)',
#  'Thalberg, Sigismond (1812-1871)',
#  'Bréguet, Louis (1804-1883)',
#  'Anderson, Mary Antoinette (1859-1940)',
#  'Vizetelly, Henry',
#  'Despine, Constant (1807-1873)',
#  'Audran, Edmond (1840-1901)',
#  'Cours (architecture)',
#  'Albert Ier (1848-1922 ; prince de Monaco)',
#  'Alexandre (18..-18.. ; acteur)',
#  'Magnier, Marie (1848-1913)',
#  'Brasseur, Jules (1829-1890)',
#  'Legrand, Paul (1816-1898)',
#  'Laurent, Marie (1825-1904)',
#  'Mary-Lafon (1812-1884)',
#  'Lamy, Charles (1857-1940)',
#  'Guérin, Alphonse (1817-1895)',
#  'Milligan McLane, Robert (1815-1898)',
#  "Barbey d'Aurevilly, Jules (1808-1889)",
#  'Duvernoy, Alphonse (1842-1907)',
#  'Tissandier, Gaston (1843-1899)',
#  'Guyon, Charles-Alexandre (1857-1923)',
#  'Pelouze, Jules (1807-1867)',
#  'Lassouche (1828-1915)',
#  'Poniatowski, Józef Michał (1816-1873)',
#  'Deraisy, Carmen',
#  'Philipon, Eugène (18..-1874)',
#  'Georges, Alexandre (1850-1938)',
#  'Charner, Léonard-Victor-Joseph (1797-1869)',
#  'Garcin, Jules (1830-1896)',
#  'Hubans, Charles (1828-1904)',
#  'Mardrus, Joseph Charles (1868-1949)',
#  'Rémy, Adèle, Marie, Joséphine (1859-1...)',
#  'Ziloti, Aleksandr Ilʹič (1863-1945)',
#  'Margueritte, Paul (1860-1918)',
#  'Fériel, Marie-Ange',
#  'Didier, Alexis (1826-1886)',
#  'Leblanc, Léonide (1842-1894)',
#  'Legouvé, Ernest (1807-1903)',
#  'Marquet, Mary (1895-1979)',
#  'Quérette, Marie (18..-19.. ; actrice)',
#  'Langlois, Amédée-Jérôme (1819-1902)',
#  'Chevreul, Eugène (1786-1889)',
#  'Vacquerie, Auguste (1819-1895)',
#  'Charcot, Jean-Martin (1825-1893)',
#  'Songeon, Jacques (1818-1889)',
#  'Hasselmans, Joseph H. (1814-1902)',
#  'Landouzy, Lise (1861-1943)',
#  'Rodenbach, Georges (1855-1898)',
#  'Xai, Pho (1849?-19..?)',
#  'Fournier, Édouard (1819-1880)',
#  'Martens, Charlotte',
#  'Aimée (18..-1887 ; actrice)',
#  'Mangin (18..-19.. ; artiste lyrique)',
#  'Joigneaux, Pierre (1815-1892)',
#  'Meyerbeer, Giacomo (1791-1864)',
#  'Saint-Yves Bax (1829-1897)',
#  'Péreire, Émile (1800-1875)',
#  'Borbón, Blanca de (1868-1949)',
#  'Jouassain, Catherine (1829-1902)',
#  'Callias, Hector de (1841-1887)',
#  'Dartaux, Anna (18..-1887)',
#  'Mirès, Jules Isaac (1809-1871)',
#  'Pierson, Blanche (1842-1919)',
#  'Saussier, Félix Gustave (1828-1905)',
#  'Frédérique (1848-1926 ; princesse de Hanovre)',
#  'Rivière, Théodore (1857-1912)',
#  'Gautier, Théophile (1811-1872)',
#  'Sisos, Raphaële (1860-1939)',
#  'Munkácsy, Mihály (1844-1900)',
#  'Cros, Charles (1842-1888)',
#  'Laboulaye, Édouard (1811-1883)',
#  'Deschamps, Émile (1791-1871)',
#  'Franck, Paul (18..-19.. ; homme de théâtre)',
#  'Pyat, Félix (1810-1889)',
#  'Suys, Léon-Pierre (1823-1887)',
#  'Mussay, Paul (18..-19.. ; directeur de théâtre)',
#  'Martin de Noirlieu, François (1792-1870)',
#  'Gravillon, Arthur (1828-1899)',
#  'Jullien, Marie (18..-19.. ; actrice)',
#  'Dutertre de Véteuil, Félix (1810?-1877)',
#  'André, Blanche (18..-18..)',
#  'Donnet, Ferdinand (1795-1882)',
#  'Daubigny, Charles-François (1817-1878)',
#  "Allonville, Armand, vicomte d' (1809-1867)",
#  'Marx, Adrien (1837-1906)',
#  'Amail, Léopold (1816-1884)',
#  'Torin, Joseph (1859-1907)',
#  'Faivre, Céleste (18..-1... ; actrice)',
#  'Marié, Paola (1851-19..)',
#  'Nisard, Auguste (1809-1892)',
#  'Goudesone, Louis (1843-1917)',
#  'Lamé Fleury, Ernest (1823-1903)',
#  'Courbet, Gustave (1819-1877)',
#  'Bertin, Jean-Louis-Henri (1806-1881)',
#  'Colombier, Marie (1841-1910)',
#  'Calvé, Emma (1858-1942)',
#  'Balathier-Bragelonne, Adolphe de (1811-1888)',
#  "O'Connel, Frédérique Emilie Auguste (1823-1885)",
#  'Millière, Jean-Baptiste (1817-1871)',
#  'Gourgaud, Louis Marie Napoléon Hélène (1823-1873)',
#  'Milher (1834-1898)',
#  'Zidler, Charles Joseph',
#  'Larchey, Lorédan (1831-1902)',
#  'Ricord, Philippe (1800-1889)',
#  'Niboyet, Paulin (1825-1906)',
#  'Rivet, Gustave (1848-1936)',
#  'Lenoir, Albert (1801-1891)',
#  'Desvallières, Maurice (1857-1926)',
#  'Boyer, Rachel (1864-1935)',
#  'Deval, Marguerite (1868-1955)',
#  'Guy, Georges Guillaume (1859-1917)',
#  'Landrin, Paul (18..-19.. ; acteur)',
#  'Bléry, Eugène (1805-1886)',
#  'Roty, Oscar (1846-1911)',
#  'Strauss, Isaac (1806-1888)',
#  'Sully, Mariette (1874-19..)',
#  'Tissandier, Albert (1839-1906)',
#  'Billard, Félix (1829-1901)',
#  'Rochard, Émile (1851-1918)',
#  'Saïn, Paul (1853-1908)',
#  'Judicis, Louis (1816-1893)',
#  'Volsy, Valentine (1853-1888)',
#  'Desnoyers, Louis (1802-1868)',
#  'Arago, Étienne (1802-1892)',
#  'Feydeau, Léocadie (1838-1924)',
#  'Proudhon, Pierre-Joseph (1809-1865)',
#  'Dux, Émilienne (1874-1950)',
#  'Cavaillé-Coll, Cécile (1854-1944)',
#  'Toussenel, Alphonse (1803-1885)',
#  'Caron, Cécile (1852-1923)',
#  'Cornalba, Elena (18..-19.. ; danseuse)',
#  'Salla, Caroline (1852-....)',
#  'Mouton, Eugène (1823-1902)',
#  'Delombre, Paul (1848-1933)',
#  'Walter, Lucien (1866-1945)',
#  'Thomé, Francis (1850-1909)',
#  'Sterckx, Théodore-François (1829-1896)',
#  'Mallarmé, Stéphane (1842-1898)',
#  'Prelly, Madame (1840-19..)',
#  'Mérignac, Louis (1846-1930)',
#  'Boulard, Auguste (1825-1897)',
#  'Villemot, Émile (1846-1883)',
#  'Marinoni, Hippolyte Auguste (1823-1904)',
#  'Hetzel, Pierre-Jules (1814-1886)',
#  'Magnier, Louise (18..-19..)',
#  'Melba, Nellie (1861-1931)',
#  'Hervieu, Paul (1857-1915)',
#  'Dinelli, Mademoiselle (18..-1894)',
#  'Bois, Victor (1813-1870)',
#  'Reichenberg, Suzanne (1853-1924)',
#  'David, Léon (1867-1962)',
#  'Lacour-Gayet, Georges (1856-1935)',
#  'Delannoy, Léopold (1817-1888)',
#  'Gouël, Albert Théodule (1841-19..)',
#  'Méaly, Juliette (1867-19..)',
#  'Rubé, Auguste (1817-1899)',
#  'Gonzàlez-Bravo, Luis (1811-1871)',
#  'Marie de Saint-Georges, Alexandre-Pierre-Thomas-Amable (1795-1870)',
#  'Barrès, Maurice (1862-1923)',
#  'Curés (prêtres)',
#  'Perlet, Adrien (1795-1850)',
#  'Lanvin (Maison de couture)',
#  'Davyl, Louis (1830-1890)',
#  'Durand-Fardel, Maxime (1815-1899)',
#  'Callias, Horace de (1847-1924)',
#  'Becquerel, Antoine Henri (1852-1908)',
#  'Baudry, Paul (1828-1886)',
#  'Palicot, Georges (1863-1921)',
#  'Crémieux, Adolphe (1796-1880)',
#  'Cantin, François (18..-1896?)',
#  'Dupont, Pierre (1821-1870)',
#  'Leys, Henri (1815-1869)',
#  'Clapisson, Antoine-Louis (1808-1866)',
#  'Amaury-Duval (1808-1885)',
#  "David (18..-18.. ; chef de claque à l'Opéra)",
#  'Du Bois-Reymond, Emil (1818-1896)',
#  'Boetzel, Ernest-Philippe (1830-1920?)',
#  'Chapus, Eugène (1800-1877)',
#  'Gautier, Judith (1845-1917)',
#  'Héquet, Gustave (1803-1865)',
#  'Blum, Ernest (1836-1907)',
#  'Cottes, Antony (1871-1913)',
#  'Talazac, Jean-Alexandre (1851-1896)',
#  'Demange, Charles-Gabriel-Edgard (1841-1925)',
#  'Musard, Alfred (1818-1881)',
#  'Becque, Henry (1837-1899)',
#  'Vapereau, Gustave (1819-1906)',
#  'Warot, Victor (1834-1906)',
#  'Pelliot, Paul (1878-1945)',
#  'Coquerel, Athanase-Josué (1820-1875)',
#  'Halévy, Ludovic (1834-1908)',
#  'Fould, Gustave (1836-1884)',
#  'Boyer, Antide (1850-1918)',
#  'Say, Constant (1816-1871)',
#  'Verne, Jules (1828-1905)',
#  'Baillet, Georges (1848-1935)',
#  'Capoul, Victor (1839-1924)',
#  'Armand, Victorin (18..-1896)',
#  'Feydeau, Georges (1862-1921)',
#  "Rochas d'Aiglun, Albert de (1837-1914)",
#  'Heilbuth, Ferdinand (1826-1889)',
#  'Reszke, Joséphine de (1855-1891)',
#  'Tailhade, Laurent (1854-1919)',
#  'Vandal, Édouard (1813-1889)',
#  'Thierret, Felicia (1812?-1873)',
#  'Bureaux (pièces)',
#  'Cogé, Renée (18..-1909)',
#  'Faure, Sébastien (1858-1942)',
#  'Becquerel, Edmond (1820-1891)',
#  'Darcourt, Juliette (1860-1920)',
#  'Lepic, Ludovic Napoléon (1839-1889)',
#  'Manceau, Alexandre (1817-1865)',
#  'Barbot, Joseph Théodore Désiré (1824-1896)',
#  'Véron, Pierre (1833-1900)',
#  'Marcus, Noëmie (18..-1... ; cantatrice)',
#  'Larcher, Eugène (1856-19..)',
#  'Narcillac, Vicomte de (1832-1909)',
#  'Cornélie (1830?-1876)',
#  'Najac, Émile de (1828-1889)',
#  'Nyon, Eugène (1812-1870)',
#  'Magnard, Francis (1837-1894)',
#  'Chen, Jitong (1851-1907)',
#  'Baxone, Ellen (188.-19..)',
#  'Duprez, Gilbert (1806-1896)',
#  'Tallien de Cabarrus, Edouard (1801-1870)',
#  'Plouvier, Édouard (1821-1876)',
#  'Pelletan, Eugène (1813-1884)',
#  'La Bédollière, Émile de (1812-1883)',
#  'Delahaye, Camille (1842-19..)',
#  'Bernard, Tristan (1866-1947)',
#  'Dallet, Léonie',
#  'Delessart, Louis (1840-1883)',
#  'Le Guillois (18..-1886)',
#  'Duflos, Raphaël (1858-1946)',
#  'Saint-Georges, Henri de (1799-1875)',
#  'Duparc, Florence (1853-1924)',
#  'Guynemer, Georges (1894-1917)',
#  'Debussy, Claude (1862-1918)',
#  'Coupier, Théophile (1820-1872)',
#  'Martel, Nancy (1858-1928?)',
#  'Lamarre, Marie Pauline (18..?-1883?)',
#  'Popelin, Claudius (1825-1892)',
#  "Orléans, Henri d' (1867-1901)",
#  'Leterrier, Eugène (1843-1884)',
#  'Müller, Marie (1865-1953)',
#  'Petipa, Marie (1857-1930)',
#  'Grévy, Jules (1807-1891)',
#  'Christophe, Ernest (1827-1892)',
#  'Bertillon, Alphonse (1853-1914)',
#  'Clément, Edmond (1867-1928)',
#  'Dierx, Léon (1838-1912)',
#  'Rocher, Monsieur (18..-19.. ; acteur)',
#  'Dejazet, Virginie (1798-1875)',
#  'Abbéma, Louise (1858-1927)',
#  'Prim, Juan (1814-1870)',
#  'Jacquemart, Henri Alfred Marie (1824-1896)',
#  'De Reszke, Jean (1850-1925)',
#  'Régnier de La Brière, François (1807-1885)',
#  'Armand-Dumaresq, Édouard (1826-1895)',
#  'Déguisements (costume)',
#  'Luchet, Auguste (1806-1872)',
#  'Zucchini, Giovanni (1812-1891)',
#  'Poidevin, Eugène Modeste Edmond (1806-1870)',
#  'Paine, Ira (18..-1...)',
#  'Cruls, Luiz (1848-1908)',
#  'Desprez, Renée',
#  'Kolb, Thérèse (1856-1935)',
#  'Niboyet, Eugénie (1799-1882)',
#  'Lacroix, Jules (1809-1887)',
#  'Delaunay, Rose (1857-194.?)',
#  'Becquerel, Antoine-César (1788-1878)',
#  'Chevreul, Henri (1819-1889)',
#  'Delessert, Eugène (1819-1877)',
#  'Magnan, Bernard-Pierre (1791-1865)',
#  'Dupray, Henry-Louis (1841-1909)',
#  'Boyer, Georges (1850-1931)',
#  'Rousseau, Jean Baptiste (1829-1891)',
#  'Caillaux, Joseph (1863-1944)',
#  'Bourdeau, Adolphe (1838-1911)',
#  'Racine, Jean (1639-1699)',
#  'Muller, Charles-Louis (1815-1892)',
#  'Jean-Paul (1830-1889?)',
#  'Obin, Louis-Henri (1820-1895)',
#  'Marc-Nohel (18..-19..)',
#  'Fabre, Ferdinand (1827-1895)',
#  'Clever de Maldigny, Charles-Auguste (1801-1878)',
#  'Serpette, Gaston (1846-1904)',
#  "Aubel, Henri d' (1830-1899)",
#  'De Max (1869-1924)',
#  'Frémy, Louis (1805-1891)',
#  'Gibert, Etienne (1859-1929 ; ténor)',
#  'Cléry, Léon (1831-1904)',
#  'Chéret, Jules (1836-1932)',
#  'Mariani, Angelo (1838-1914)',
#  'Barbier, Auguste (1805-1882)',
#  'Donvé, Marguerite (1852-19..)',
#  'Acollas, Émile (1826-1891)',
#  'Dumény, Camille (1854-1920)',
#  'Whitworth, Joseph (1803-1887 ; sir)',
#  'Champfleury (1821-1889)',
#  'Lavigne, Alice (1856-1909)',
#  'Perrin, Jules (1839-1911)',
#  'Forain, Jean-Louis (1852-1931)',
#  'Decazes, Louis-Charles-Elie-Amanieu (1819-1886)',
#  'Thiers, Adolphe (1797-1877)',
#  'Eudel, Paul (1837-1911)',
#  'Hadamar, Zélie (1849-1902 ; actrice)',
#  'Ragkavī́s, Aléxandros Rízos (1809-1892)',
#  "Archambaud, Albert d' (18..-19..? ; compositeur)",
#  'Philipon, Charles (1800-1862)',
#  'Vois, Ernest (1846-1902)',
#  'Vattemare, Alexandre (1796-1864)',
#  'Desboutin, Marcellin (1823-1902)',
#  'Lefranc, Victor (1809-1883)',
#  'Ouvrié, Justin (1806-1879)',
#  'Vallot, Philippe Joseph Auguste (1796-1870)',
#  'Ottin, Auguste Louis Marie (1811-1890)',
#  'Larnaudie, Louis François (1819-1899)',
#  'Lassalle, Émile (1813-1871)',
#  'Goupil, Albert (1840-1884)',
#  'Ritter-Ciampi, Cécile (1859-1939)',
#  'Niépce, Nicéphore (1765-1833)',
#  'Naudin, Emilio (1823-1890)',
#  'Forgues, Émile Daurand (1813-1883)',
#  'Neuville, Alphonse de (1836-1885)',
#  'Hennique, Léon (1851-1935)',
#  'Énault, Louis (1824-1900)',
#  'Barenton, Armand de (18..-18..?)',
#  "Irisson d'Hérisson, Maurice d' (1839-1893)",
#  'Duval, Aline Louise (182.-1903)',
#  'Wilder, André (1871-1965)',
#  'Yahne, Léonie (1884-191.)',
#  'Darjou, Henri-Alfred (1832-1874)',
#  'Zambelli, Carlotta (1875-1968)',
#  'Gill, André (1840-1885)',
#  'Cornu, Alfred (1841-1902)',
#  'Midhat Paşa (1822-1884)',
#  'Drumont, Édouard (1844-1917)',
#  'Morny, Auguste de (1811-1865)',
#  'Glaize, Pierre Paul Léon (1842-1932)',
#  'Brésil, Marguerite (1880-1961)',
#  'Lemoinne, John (1815-1892)',
#  'Lemerre, Alphonse (1838-1912)',
#  'Regnault, Alice (1849-1931)',
#  'Antonine, Mademoiselle (18..-18..?)',
#  'Paquin (Firme)',
#  'Nibor, Yann (1857-1947)',
#  'Costa de Beauregard, Charles-Albert (1835-1909)',
#  'Debay, Venulie, Elise (18..-1877)',
#  'Stendhal (1783-1842)',
#  'Jouvin, Benoît (1810-1886)',
#  "Ollone, Henri d' (1868-1945)",
#  'Belly, Léon (1827-1877)',
#  'Topinard, Paul (1830-1911)',
#  'Ben Driss, Mohamed (1839-1...)',
#  'Dulac, Odette (1865-1939)',
#  'Porel, Paul (1843-1917)',
#  'Galliéni, Joseph-Simon (1849-1916)',
#  'Bénédite, Léonce (1859-1925)',
#  'Lecomte, Jules (1810-1864)',
#  'Ceccaldi, Pascal (1876-1918)',
#  'Flan, Alexandre (1827-1870)',
#  'Sédillot, Charles (1804-1883)',
#  'Arnaud, Albert (1853-1915)',
#  'Hanlon Lees, frères',
#  'Milo, Emile (1889-1952)',
#  'Boulanger, Louis (1806-1867)',
#  'Brémond, François (1844-1925)',
#  'Mauri, Rosita (1856-1923)',
#  'Naza, Gil (1825-1899)',
#  'Grant, Ulysses Simpson (1822-1885)',
#  'Divonne, Andrée',
#  'Protais, Alexandre (1826-1890)',
#  'Zamacoïs, Miguel (1866-1955)',
#  'Mills Pilkington, George (1867-1945)',
#  'Simon-Girard, Juliette (1859-1959)',
#  'Moïna-Clément, Anne, Victorine (1845-191. ; actrice)',
#  'Deschamps, Antony (1800-1869)',
#  'Gounod, Charles (1818-1893)',
#  'Berthet, Lucy (1866-19..)',
#  'Decroza, Francine (1868-19..)',
#  'Livry, Emma (1842-1863)',
#  'Chevalier, Esther (1852-19.. ; artiste lyrique)',
#  'Decori, Louis (1858-1909)',
#  'Boncza, Wanda de (1872-1902)',
#  'Ulbach, Louis (1822-1889)',
#  'Marcel, Henry (1854-1926)',
#  'Granier, Irma (18..-18.. ; actrice)',
#  'Dieulafoy, Georges (1839-1911)',
#  "Auriac, Eugène d' (1815-1891)",
#  'Broisat, Emilie (1846-1929)',
#  'Bretonneau, Pierre (1778-1862)',
#  'Giffard, Pierre (1853-1922)',
#  'Cochery, Adolphe (1819-1900)',
#  'Lacroix, Octave (1827-1901)',
#  'Esposito, Vincente, Thérèse, Marie (1857-1...)',
#  'Nefftzer, Auguste (1820-1876)',
#  'Agar, Marie (1832-1891)',
#  'Halévy, Fromental (1799-1862)',
#  'Miot, Paul-Émile (1827-1900)',
#  "Ivry, Paul d' (1829-1903)",
#  'Gozlan, Léon (1803-1866)',
#  'Guitry, Sacha (1885-1957)',
#  'Roujon, Henry (1853-1914)',
#  'Munroe, Kate (1848-1887)',
#  'Puteaux, Lucien (1832-1896)',
#  'Bouguereau, William (1825-1905)',
#  'Risler, Édouard (1873-1929)',
#  'Bianca (1841?-1912 ; actrice)',
#  'Blondeau, Henri (1841-1925)',
#  'Pène, Henri de (1830-1888)',
#  'Pitre-Chevalier (1812-1863)',
#  'Theresa (1837-1913)',
#  'Douls, Camille (1864-1889)',
#  'Leleux, Armand (1818-1885)',
#  'Laussedat, Aimé (1819-1907)',
#  'Devisme, Louis François (1806-1873)',
#  'Diémer, Louis (1843-1919)',
#  'Nicolle, Henri (1819-1877)',
#  'Roze, Marie (1846-1926)',
#  'Coquerel, Athanase Laurent Charles (1795-1868)',
#  'Poincaré, Raymond (1860-1934)',
#  'Scalini, Marie (1852-1931)',
#  "Villiers de L'Isle-Adam, Auguste de (1838-1889)",
#  'Taskin, Émile-Alexandre (1853-1897)',
#  'Magnin, Joseph (1824-1910)',
#  'Waldeck-Rousseau, Pierre (1846-1904)',
#  'Miss Jenny (1870-1909)',
#  'Buguet, Henry (1845-1920)',
#  'Chojecki, Charles-Edmond (1822-1899)',
#  'Berton, Pierre (1842-1912)',
#  'Alexandre (1856-19..)',
#  'Comte, Charles',
#  'Lesseps, Ferdinand de (1805-1894)',
#  'Landor, Arnold Henry Savage (1867-1924)',
#  'Onimus, Ernest (1840-1915)',
#  'Pandolfini, Francesco (1833-1916)',
#  'Ratisbonne, Louis (1827-1900)',
#  'Petit, Hélène (1852-1880?)',
#  'Nélaton, Auguste (1807-1873)',
#  'Leo, Lucie (18..-19.. ; actrice)',
#  'Peary, Robert Edwin (1856-1920)',
#  'Legrand, Berthe (1850-1910)',
#  'Siraudin, Paul (1813-1883)',
#  'Bonvin, François (1817-1887)',
#  'Duréault, Jean-Jacques Antoine Émile (1824-1890)',
#  'Isnard, Jean, Baptiste, Marie, Félix (1823-1889)',
#  'Périvier, Antonin (1847-1924)',
#  'Thibaud, Anna (1867?-1948)',
#  'Vibert, Jehan Georges (1840-1902)',
#  'Péan, Jules Émile (1830-1898)',
#  'Escoffier, Henri (1837-1891)',
#  'Jackson, Stonewall (1824-1863)',
#  'Le Flo, Adolphe (1804-1887)',
#  'Sainte-Croix, Camille de (1859-1915)',
#  'Labounskaya, Marie',
#  'Mérat, Albert (1840-1909)',
#  'Ratib Pasha, Muhammad (18..-1920)',
#  'Gabet, Charles (1821-1903)',
#  'Samuel, Aimée',
#  "Argis, Jules d' (1814-1882)",
#  'Guyot, Yves (1843-1928)',
#  'Banville, Théodore de (1823-1891)',
#  'Pinart, Hippolyte Alexandre (1808-1871)',
#  'Pauchet, Victor (1869-1936)',
#  'Chaumont, Céline (1848-1926)',
#  'Boutin, René François (1802-1872)',
#  'Reclus, Élie (1827-1904)',
#  'Lemercier de Neuville, Louis (1830-1918)',
#  'Meissonier, Ernest (1815-1891)',
#  'Mahy, François de (1830-1906)',
#  'Martial, Aimée',
#  'Noël, Alphonse-Léon (1807-1884)',
#  'Coëtlogon, Emmanuel de (1814-1886)',
#  'Mircher, Hippolyte (1820-1878)',
#  'Jobert, Antoine-Joseph (1799-1867)',
#  'Peyrat, Alphonse (1812-1890)',
#  'Loewy, Maurice (1833-1907)',
#  'Vaillant, Marguerite (1855-19.. ; artiste lyrique)',
#  'Bernhardt, Sarah (1844-1923)',
#  'Cucheval-Clarigny, Athanase (1821-1895)',
#  'Brémont, Léon (1852-1939)',
#  'Ginet, Paul (18..-19..)',
#  'Bartholdi, Auguste (1834-1904). Le Lion de Belfort',
#  'Prével, Jules (1835-1889)',
#  'Jambon, Marcel (1848-1908)',
#  'Molin, Benoît-Hermogaste (1810-1894)',
#  'Sainte-Claire Deville, Charles (1814-1876)',
#  'Guillaumet, Gustave (1840-1887)',
#  'Godebski, Cyprien (1835-1909)',
#  'Wyld, William (1806-1889)',
#  'Bakunin, Mihail Aleksandrovič (1814-1876)',
#  'Doucet, Camille (1812-1895)',
#  'Girardin, Émile de (1806-1881)',
#  'Perrin, Etienne (1862-1903)',
#  'Kossak, Wojciech (1857-1942)',
#  'Moigno, François (1804-1884)',
#  'Morès, Antoine Manca de Vallombrosa (1858-1896 ; marquis de)',
#  'Pothuau, Alexis (1815-1882)',
#  'Viger, Hector (1819-1879)',
#  'Rod, Édouard (1857-1910)',
#  'Siracusa, Leopoldo Borbone (1813-1860 ; conte di)',
#  'Perdonnet, Auguste (1801-1867)',
#  'Badiali, Cesare (1803-1865 ; artiste lyrique)',
#  'Coédès, Auguste (1835-1884)',
#  "Isabelle II (1830-1904 ; reine d'Espagne)",
#  'Silly, Léa',
#  'Daressy, Henri (1835-18..)',
#  'Böhm, Auguste (1819-1891)',
#  'Lambinet, Emile (1815-1877)',
#  'Monréal, Hector (1839-1910)',
#  'Caristie-Martel, Léa (1865-1934)',
#  'Morlet (18..-19.. ; acteur)',
#  'Forster, François (1790-1872)',
#  'Vallery-Radot, René (1853-1933)',
#  'Vitu, Auguste (1823-1891)',
#  'Dieterle, Amélie (1870-1941)',
#  'Nerval, Gérard de (1808-1855)',
#  'Clerget, Paul-Maurice (1868-1935)',
#  'Dieudonné, Alphonse (1832-1922)',
#  'Lureau, Adrien (1841-1908 ; acteur)',
#  'Bouffar, Zulma (1843-1909)',
#  'Lavertujon, André (1827-1914)',
#  'Taillade (1826-1898)',
#  'Francell, Fernand (1879-1966)',
#  'Hément, Félix (1827-1891)',
#  'Borbón, Elvira de (1871-1929)',
#  'Bourdon, Georges (1868-1938)',
#  'Horeau, Hector (1801-1872)',
#  'Albani, Emma (1847-1930)',
#  'Evans, Jane (18..-19..)',
#  'Beaume, Joseph (1796-1885)',
#  'Delord, Taxile (1815-1877)',
#  'Vigeant, Arsène (1844-1916)',
#  'Naudet, Joseph (1786-1878)',
#  'Engel, Emile (1847-1927)',
#  'Raymond (18..-1842)',
#  'Wilder, Victor (1835-1892)',
#  'Ménier, Paulin (1819-1898)',
#  'Lalanne, Maxime François Antoine (1827-1886)',
#  'Detaille, Édouard (1848-1912)',
#  'Galipaux, Félix (1860-1931)',
#  'Carrey de Bellemare, Adrien Alexandre Adolphe (1824-1905)',
#  'Auber, Daniel-François-Esprit (1782-1871)',
#  'Croisset, Francis de (1877-1937)',
#  'Bazille, Auguste (1828-1891)',
#  "Asco, Léa d' (18..-1906)",
#  'Guéroult, Adolphe (1810-1872)',
#  'Goblet, René (1828-1905)',
#  'Claudin, Gustave (1823-1896)',
#  'Petroz, Pierre (1819-1891)',
#  'Brohan, Augustine (1824-1893)',
#  'Girard, Caroline (1830-18..)',
#  'Duruy, Victor (1811-1894)',
#  'Féraudy, Maurice de (1859-1932)',
#  'Randon, Gilbert (1814-1884)',
#  'Lemaître, Jules (1853-1914)',
#  'Godard, Louis (1829-1885)',
#  'Desmazes, Joseph-Gustave (1806-1882)',
#  'Marchal, Charles François',
#  'Sandeau, Jules (1811-1883)',
#  'Braga, Gaetano (1829-1907)',
#  'Mézières, Alfred (1826-1915)',
#  'Vigny, Alfred de (1797-1863)',
#  'Arral, Blanche (1864-1945)',
#  'Coquelin, Jean (1865-1944)',
#  'Casse, Germain (1837-1900)',
#  'Alphonsine (1829-1883)',
#  'Reine, Alice (18..-19.. ; actrice)',
#  'Musset, Paul de (1804-1880)',
#  'Achard, Amédée (1814-1875)',
#  'Bapst, Jules (1830-1899)',
#  'Kaemmerer, Frederik Hendrik (1839-1902)',
#  'Thiéry, Marie (1870-1918)',
#  'Lefebvre, Charles Victor Eugène (1805-1882)',
#  'Comettant, Oscar (1819-1898)',
#  'Baréty, Henriette (18..-19..? ; actrice)',
#  'Babinet, Jacques (1794-1872)',
#  'Sermet, Mario (1857-19..)',
#  'Daguerre, Louis-Jacques-Mandé (1787-1851)',
#  'Duez, Ernest-Ange (1843-1896)',
#  'Terront, Charles (1857-1932)',
#  'Mêne, Pierre-Jules (1810-1879)',
#  'Kelm, Joseph (1802?-1882)',
#  'Porel, Jacques',
#  'Burty, Mademoiselle (18..-19.. ; actrice)',
#  'Lynnès, Louise (1860?-....)',
#  'Darthy, Gilda (1878-1952)',
#  'Dupont, Léonce (1828-1884)',
#  'Vacherot, Étienne (1809-1897)',
#  'Daumier, Honoré (1808-1879)',
#  'Arago, Emmanuel (1812-1896)',
#  'Guinot, Charles (1827-1893)',
#  'Humberta, Mademoiselle (1860-19..)',
#  'Monnier, Henry (1799-1877)',
#  'Achard, Pierre (18..-19.. ; acteur)',
#  'Delacroix, Eugène (1798-1863)',
#  'Netty, Mademoiselle (18..-19.. ; actrice)',
#  'Carnot, Claire (1816-1897)',
#  'Lanoüe, Félix Hippolyte (1812-1872)',
#  'Heim, François-Joseph (1787-1865)',
#  'Abbatucci, Séverin (1821-1888)',
#  'Chanteclair, Mathurin (1821-1893)',
#  'Saint-Albin, Philippe de (1822-1...)',
#  'Millet, Aimé (1819-1891)',
#  'Blažek, Rosalia (1878-1922)',
#  'Gendrin, Auguste-Nicolas (1796-1890)',
#  'Préault, Auguste (1809-1879)',
#  'Samary, Marie (1848-1941)',
#  'Annenkov, Michel Nicolaïévitch (1835-1899)',
#  'Dantan, Jean-Pierre (1800-1869)',
#  'Crouzet, Mary (18..-1895)',
#  'France, Anatole (1844-1924)',
#  'Albrizio, Charles (1810-1868)',
#  'Béthune, Gaston (1857-1897)',
#  'Dudlay, Adeline (1858-1934)',
#  'Ponroy, Arthur (1816-1876)',
#  'Leroux, Pierre (1797-1871)',
#  'Brierre de Boismont, Alexandre (1797-1881)',
#  'Brasseur, Albert (1862-1932)',
#  'Meryss, Rose (185.-19..)',
#  'Ravaisson, Félix (1813-1900)',
#  'Lazerges, Paul (1845-1902)',
#  'Thierry, Édouard (1813-1894)',
#  'Goncourt, Edmond de (1822-1896)',
#  'Barretta, Blanche (1856-1939)',
#  'Chevreau, Léon (1827-1910)',
#  'Dupuis, Joseph (1833-1900)',
#  'Brettes, Joseph de (1861-1934)',
#  'Baron, Henri-Charles-Antoine (1816-1885)',
#  'Napoléon Ier (1769-1821 ; empereur des Français)',
#  'Chevigné, Louis de (1793-1876)',
#  'Bernaërt, Magdelaine (1861-19.. ; artiste lyrique)',
#  'Monod, Adolphe (1802-1856)',
#  'Bac, Daniel (1831-19..)',
#  'Morand, Eugène (1854-1930)',
#  'Hugo, Charles (1826-1871)',
#  'Fazy, James (1794-1878)',
#  'Provost, Jeanne (1887-1980)',
#  'Invernizzi, Lotta (18..-19.. ; danseuse)',
#  'Feuillet de Conches, Félix-Sébastien (1798-1887)',
#  'Bartholomé, Albert (1848-1928)',
#  'Sellier, Henri (1849-1899)',
#  'Gervais-Courtellemont, Jules (1863-1931)',
#  'Rollinat, Maurice (1846-1903)',
#  'Carnot, Hippolyte (1801-1888)',
#  'Bouhy, Jacques (1848-1929)',
#  'Legrenay, Victor (1826-1889)',
#  'Yvon, Adolphe (1817-1893)',
#  'Croizette, Sophie (1847-1901)',
#  'Boisselot, Paul (1829-1905)',
#  'Aciana (18..-19..)',
#  'Mornand, Félix (1815-1867)',
#  'Arban, Jean-Baptiste (1825-1889)',
#  'Lefort, Jules (1822-1898)',
#  'Lobstein, Désirée (1868-19.. ; danseuse)',
#  'Bray, Yvonne de (1889-1954)',
#  'Patoret, Juliette (1859-1...)',
#  'Gauthier-Villars, Jean Albert (1828-1897)',
#  'Narvaez Campos Poriel y Mateos, Ramon Maria (1800-1868)',
#  'Caraguel, Clément (1819-1882)',
#  'Laporte, Léonie (18..-19.. ; actrice et chanteuse)',
#  'Dauville, Louise (18..-19..)',
#  'Michel, Marc (1812-1868)',
#  'Mourey, Gabriel (1865-1943)',
#  'Bartholdi, Auguste (1834-1904)',
#  'Rougnon, Paul (1846-1934)',
#  'Lecurieux, Jacques-Joseph (1801-188.)',
#  'Yvan, Melchior-Honoré (1806-1873)',
#  'Mangin, Edouard (1837-1907)',
#  'Lefranc, Auguste (1814-1878)',
#  'Caron, Rose (1857-1930)',
#  'Schenck, Robert Cumming (1809-1890)',
#  'Maret, Henry (1837-1917)',
#  'Kretulescu, Nicolae (1812-1900)',
#  'Belin, Édouard (1876-1963)',
#  'Almée (18..-18..)',
#  'Dupuis, Adolphe (1824-1891)',
#  'Obrenović, Milan IV (1854-1901 ; roi de Serbie)',
#  'Bergeron, Georges (1839-1891)',
#  'Garibaldi, Giuseppe (1807-1882)',
#  'Oudiné, Eugène-André (1810-1887)',
#  'Bougaud, Louis-Émile (1824-1888)',
#  'Dupeuty, Adolphe (1828-1884)',
#  'Quidant, Alfred (1815-1893)',
#  'Cassagnac, Paul de (1842-1904)',
#  'Penafiel, Antônio José da Serra Gomes (1819-1891 ; 2e comte et 1er marquis de)',
#  'Denain, Elisabeth (1823-1892)',
#  'Clemenceau, Georges (1841-1929)',
#  'Lambert, Gustave (1814-1871)',
#  'Scipion (18..-19.. ; acteur)',
#  'Sicard, Auguste (1839-19..)',
#  'Candé, Adolphe (1858-1931)',
#  'Debruyère, Louis',
#  'Samuel, Fernand (1862-1914)',
#  'Bade, Eugénie (18..-19..)',
#  'Gosselin, Léon (1815-1887)',
#  'Lysès, Charlotte (1877-1956)',
#  'Christian (1825-18.. ; chanteur-acteur)',
#  'Cassive (1873-1940)',
#  'Roybet, Ferdinand (1840-1920)',
#  'Duquesnel, Félix (1832-1915)',
#  'Mario, Mademoiselle (18..-19.. ; actrice)',
#  'Molins, Mariano Roca de Togores (1812-1889 ; marquis de)',
#  'Gauthier, Louis (18..-19.. ; acteur)',
#  'La Mennais, Félicité de (1782-1854)',
#  'Bilbaut-Vauchelet, Juliette (1855-1924)',
#  'Boucher, Jules-Théophile (1847-1924)',
#  'Usquin, Henri (1815-1886)',
#  'Perret, Mary',
#  'Gueydon, Louis Henri (1809-1886 ; comte de)',
#  'Cousin, Victor (1792-1867)',
#  'Marignan, Jane (1873-1924)',
#  'Bataille, Charles (1831-1868)',
#  'Augier, Émile (1820-1889)',
#  'Augustin (18..-1... ; trappiste)',
#  'Montaut, Henri de (1825-1890?)',
#  'Petitjean, Edmond Marie (1844-1925)',
#  'Cloué, Georges (1817-1889)',
#  'Fargueil, Anaïs (1819-1896)',
#  'Cuvillier-Fleury, Alfred-Auguste (1802-1887)',
#  'Miroir, Blanche (1859-1938)',
#  'Julian van Gelder, Esther Eliza (18..-18.. ; artiste lyrique)',
#  'Woll, Adrien (1795-1875)',
#  'Saint-Victor, Paul de (1825-1881)',
#  'Soltykov, Pierre (1804-1889 ; prince)',
#  'Graziani, Lodovico (1820-1885)',
#  'Lasteyrie, Ferdinand de (1810-1879)',
#  'Synave, Tancrède (1870-1936)',
#  'Bonvalot, Gabriel (1853-1933)',
#  'Taylor, Justin (1789-1879)',
#  'Paillard de Villeneuve, Adolphe-Victor (1804-1874)',
#  'Rolland, Virginie (18..-19.. ; actrice)',
#  'Bérardi, Gaston (1849-1926)',
#  'Depoix, Julia (1861-1898)',
#  'Coquelin, Ernest (1848-1909)',
#  'Lérand, Léon (1864-1920)',
#  'Vauthier, Eugène (1843-1911)',
#  'Bayard, Émile (1868-1937)',
#  "Chaix d'Est-Ange, Gustave (1800-1876)",
#  'Lesseps, Jacques de (1883-1927)',
#  'Colonne, Edouard (1838-1910)',
#  'Lareinty, Clément Gustave Henri Baillardel de (1824-1901)',
#  'Munte, Lina (18..-1909)',
#  'Philippoteaux, Félix (1815-1884)',
#  'Rivière, Henri (1827-1883)',
#  'Blaze de Bury, Henri (1813-1888)',
#  'Marietti, Georges (1852-1902)',
#  'Beraud, Jeanne (18..-1...)',
#  "Caran d'Ache (1858-1909)",
#  'Ginoux-Defermon, César-Auguste (1828-1889)',
#  'Hureau de Villeneuve, Abel (1833-1898)',
#  'Abney, William de Wiveleslie (1843-1920)',
#  'Isabey, Eugène (1803-1886)',
#  'Perret, Aimé (1846-1927)',
#  'Fabry, Félicie (1863?-1...)',
#  'Arago, François (1862-1937)',
#  'Herbert (18..-19.. ; acteur)',
#  'Blanc, Louis (1811-1882)',
#  'Annenkov, Mihail Nikolaevič (1835-1899)',
#  'André, Jules (1807-1869)',
#  'Cohen, Jules (1835-1901)',
#  'Laisant, Charles-Ange (1841-1920)',
#  'Boyer, Léopold (18..-19.. ; directeur de théâtre)',
#  'Grisi, Carlotta (1819-1899)',
#  "Junot, Jean Andoche (1771-1813 ; duc d'Abrantès)",
#  'Fournets, René (1858-1926)',
#  'Plantade, Charles-François (1787-1870)',
#  'Rueil-Malmaison (Hauts-de-Seine)',
#  'Schmidt, Clémentine (185.-1906)',
#  'Grivot, Pierre Antonin François (1834-1912)',
#  'Leleux, Adolphe (1812-1891)',
#  'Mac Mahon, Marie Armand Patrice de (1855-1927)',
#  'Bépoix, Henriette',
#  'Blavet, Émile (1838-1924)',
#  'Charavay, Étienne (1848-1899)',
#  'Churchill, Randolph Henry Spencer (1849-1895)',
#  'Dartois, Camille (1838-1917)',
#  'Michel, Francisque (1809-1887)',
#  'Fauvel, Charles (1830-1895)',
#  'Savenay, Claire de (18..-18..? ; cantatrice)',
#  'Jeanne-Andrée (18..-1896)',
#  'Eyre, Jeanne (18..-1... ; artiste dramatique)',
#  'Nevada, Emma (1859-1940)',
#  'Ducuing, François (1817-1875)',
#  'Asselineau, Charles (1820-1874)',
#  'Massarani, Tullo (1826-1905)',
#  'Barrière, Théodore (1823-1877)',
#  'Guyon, Jean-Casimir-Félix (1831-1920)',
#  'Guitty, Madeleine (1870-1936)',
#  'Delaage, Henri (1825-1882)',
#  'Delaporte, Michel (1806-1872)',
#  'Madier de Montjau, Raoul (1841-1909)',
#  'Frémy, Arnould (1809-189.)',
#  'Chaminade, Cécile (1857-1944)',
#  'Ségur, Sophie de (1799-1874)',
#  'Keçecizâde, Mehmed Fuad Paşa (1815-1869)',
#  'Garnier-Pagès, Louis-Antoine (1803-1878)',
#  'Vanloo, Albert (1846-1920)',
#  'Perronnet, Amélie (18..-1903)',
#  'Lassalle, Jean (1847-1909)',
#  'Charles I (1863-1908 ; roi de Portugal)',
#  'Révillon, Tony (1832-1898)',
#  'Lubert, Albert (1859-1919)',
#  'Mazères, Édouard-Joseph-Ennemond (1796-1866)',
#  'Pérignon, Alexis-Joseph (1806-1882)',
#  'Valerio, Théodore (1819-1879)',
#  'Ferrier, Paul (1843-1920)',
#  'Piccaluga, Albert (1854-1925)',
#  'Faure, Élie (1873-1937)',
#  'Guillard, Léon (1816-1878)',
#  'Frédault, Félix (1822-1897)',
#  'Patry, Pauline (1856-19..)',
#  'Chasles, Philarète (1798-1873)',
#  'Baudelaire, Charles (1821-1867)',
#  'Millet, Jean-François (1814-1875)',
#  'Turgan, Julien (1824-1887)',
#  'Madaune, Jean Michel de (1838-1...)',
#  'Baggers, Joseph (1858-19..)',
#  'Gérôme, Jean-Léon (1824-1904)',
#  'Debriège, Albany (1860-1931)',
#  'Leitner, Jules (1862-1940)',
#  'Grévin, Alfred (1827-1892)',
#  'Vaillant-Couturier, Paul (1892-1937)',
#  'Gémier, Firmin (1869-1933)',
#  'Hamlet (personnage légendaire)',
#  'Vallet de Viriville, Auguste (1815-1868)',
#  'Weill, Alexandre (1811-1899)',
#  'Masson, Michel (1800-1883)',
#  'Soulacroix, Gabriel (1853-1905)',
#  'Jacque, Charles-Émile (1813-1894)',
#  'Pommayrac, Pierre Paul Emmanuel de (1807-1880)',
#  'Trivier, Elisée (1842-1912)',
#  'Étiévant, Henri (1870-1953)',
#  'Feuillet, Octave (1821-1890)',
#  'Joséphine (1763-1814 ; impératrice des Français)',
#  'Dubufe, Édouard (1820-1883)',
#  'Penel, Julien (1843-1908)',
#  'Canrobert, François Certain (1809-1895)',
#  'Labbé, Donatien (1852-1932)',
#  'Leroy, Louis (1812-1885)',
#  'Rothschild, Alphonse de (1827-1905)',
#  'Delvau, Alfred (1825-1867)',
#  'Borbón, Jaime de (1870-1931)',
#  'Cadart, Alfred (1828-1875 ; éditeur)',
#  'Castelar, Emilio (1832-1899)',
#  'Hüe, Georges (1858-1948)',
#  'Marx, Léon (1818-1910)',
#  'Supérieures (religion)',
#  'Thoinnet de La Turmelière, Charles (1824-1887)',
#  'Davis, Jefferson (1808-1889)',
#  'Sibour, Marie-Dominique-Auguste (1792-1857)',
#  'Lagrave, Michel (1870-1956)',
#  'Faure, Jean-Baptiste (1830-1914)',
#  'Fugère, Paul (1851-19..)',
#  'Saint-Germain (1833-1899)',
#  'Janssen, Jules (1824-1907)',
#  'Scholl, Aurélien (1833-1902)',
#  'Gramme, Zénobe Théophile (1826-1901)',
#  'Dumas, Alexandre (1824-1895)',
#  'Thiron, Charles (1830-1891)',
#  'Ploton (1839?-1910)',
#  'Blažek, Josepha (1878-1922)',
#  'Marcilly, Marie (1871-19..)',
#  'Caniche (race canine)',
#  'Granet, Félix (1849-1936)',
#  'Roubaud, Émile (1882-1962)',
#  'Berthier, Alice (186.-1899)',
#  'Riza Khan-Arfa, Mirza (1846-1939)',
#  'Pothey, Alexandre (1820-1897)',
#  'Léveillé, Albert (18..-1911)',
#  'Bignon, Louise (1878-19..)',
#  'Véronge de La Nux, Paul (1853-1928)',
#  'Brindeau, Jeanne (1860-1946)',
#  'Gabrielli, Nicolò (1814-1891)',
#  'Wilson, Daniel (1840-1919)',
#  ...]

# %%
names = []
for n in is_names:
    name_ = n.split('(')[0].strip().lower().split(',')
    names.append(name_)
        
names = list(set(chain.from_iterable(names)))
names = list(set(list(map(lambda x:x.strip(),names))))

# %%
mask_tags = list(map((lambda x: ',' not in x), not_names))
subject_tags = list(compress(not_names, mask_tags))

# %%
subject_tags
# Out:
# ['République',
#  'Ambassadeurs chinois',
#  'Haltérophiles',
#  'Alliance franco-russe',
#  'Singes',
#  'Âne',
#  'Sarb Vijisy',
#  'Chien',
#  "Montreurs d'animaux savants",
#  'Oiseaux parleurs',
#  'Franck-Mel',
#  'Cavalières',
#  'Diplomates russes',
#  'Tournée Brasseur',
#  'Présidents',
#  'Animaux de cirque',
#  'Cyclistes',
#  'Chat domestique',
#  'Scènes historiques',
#  'Poupées',
#  'Casseroles',
#  'Aéronautes',
#  'Avocats',
#  'Escrimeurs',
#  'France. Ministère des finances',
#  "Portraits d'intérieur",
#  'Pianistes',
#  'Hôtels particuliers',
#  'Sculpture de figures humaines',
#  'Cornistes',
#  'Hôpitaux',
#  'Vigne',
#  'Mères et nourrissons',
#  'Trapézistes',
#  'Mandoline',
#  'Autobus',
#  'Chasseurs',
#  'Antonine',
#  'Représentations animalières',
#  'Cravaches',
#  'Autoportraits',
#  'Paysages urbains',
#  'Journaux français',
#  'Scènes',
#  "Indiens d'Amérique",
#  'Piano',
#  'Nourrissons',
#  'Dessin',
#  "Ateliers d'artistes",
#  'Cour et courtisans',
#  'Travestis',
#  'Sang',
#  'Ombre portée',
#  'Géants',
#  'Enfants',
#  'Noirs',
#  'Femmes',
#  'Juges',
#  'Violonistes',
#  'Peinture',
#  "Représentations d'objet",
#  'Nageurs',
#  'Bicyclettes',
#  'Religieux',
#  'Généraux',
#  'Ensembles de musique de chambre',
#  'Décorations militaires',
#  'Minstrel shows',
#  'Ballons',
#  'Phénomènes de cirque',
#  'Clowns',
#  'Ambassadeurs portugais',
#  'Actrices travesties',
#  'Hommes',
#  'Costumes',
#  'Danse orientale',
#  'Scènes théâtrales',
#  'Ambassadeurs uruguayens',
#  'Harpistes',
#  'Enfants acteurs',
#  'Ambassadeurs japonais',
#  'Diplomates danois',
#  "Vues d'architecture",
#  'Roues',
#  'Tricycles',
#  'Prêtres',
#  'Acteurs travestis',
#  'Violoncellistes',
#  'Danseuses',
#  'Jumeaux siamois',
#  'Colonisation',
#  'Appareils photographiques',
#  'Statues']

# %%
mask_names = list(map((lambda x: ',' in x), subject_tags))

subject_names = list(compress(subject_tags, mask_names))
#subject_names

# %%
def exclude_title_name(x):
    temp = []
    for t in x:
        t = re.sub('[\[\] (".,")]', '', t)

        if t.lower() in names:
            pass
        else:
            temp.append(t.lower())
    return temp

# %%
df2['title_broken'] = df2.title.apply(lambda x: re.findall('[\S]+',x))

# %%
df2.title_broken
# Out:
# 7              [Me, Auguez]
# 8              [Me, Auguez]
# 9              [M., Bruant]
# 10             [Me, Auguez]
# 13       [M., A., Brasseur]
#                 ...
# 23528        [M., Hignette]
# 23530             [Brémont]
# 23531               [Caron]
# 23533           [Croizette]
# 23534              [Capoul]
# Name: title_broken, Length: 13936, dtype: object

# %%
tag_df = pd.DataFrame(df2.id)
#tag_df['subjects'] = df2['subjects']
tag_df['title'] = df2['title_broken'].apply(exclude_title_name)
tag_df['subject'] = df2.subjects.apply(name_filter).apply(not_name)

# %%
tag_df
# Out:
#                                                      id          title  \
# 7      https://gallica.bnf.fr/ark:/12148/btv1b53168872x           [me]
# 8      https://gallica.bnf.fr/ark:/12148/btv1b531688701           [me]
# 9      https://gallica.bnf.fr/ark:/12148/btv1b53171770j            [m]
# 10     https://gallica.bnf.fr/ark:/12148/btv1b53168873c           [me]
# 13     https://gallica.bnf.fr/ark:/12148/btv1b531651494            [m]
# ...                                                 ...            ...
# 23528  https://gallica.bnf.fr/ark:/12148/btv1b531203810  [m, hignette]
# 23530  https://gallica.bnf.fr/ark:/12148/btv1b53123957r             []
# 23531  https://gallica.bnf.fr/ark:/12148/btv1b53124037v             []
# 23533  https://gallica.bnf.fr/ark:/12148/btv1b53124131j             []
# 23534  https://gallica.bnf.fr/ark:/12148/btv1b53124259b             []
#
#               subject
# 7                  []
# 8                  []
# 9                  []
# 10                 []
# 13                 []
# ...               ...
# 23528  [Ombre portée]
# 23530              []
# 23531              []
# 23533              []
# 23534              []
#
# [13936 rows x 3 columns]

# %%
def filter_tags(x):
    tag_4 = ['cure', 'chef', 'lord', 'abbé']
    
    if type(x) != str:
        return False
    
    if x.find(',') != -1:
        return False
    
    if len(x) < 3:
        return False
    
    elif len(x) == 3:
        if x == 'roi':
            return True
        else:
            return False
    elif len(x) == 4:
        if x in tag_4:
            return True
        else:
            return False        
    else:
        return True

# %%
tags_title_ = tag_df.title.apply(pd.Series).merge(tag_df, right_index=True, left_index=True) \
        .drop(['title','subject'],axis=1).melt(id_vars=['id'], value_name='tags').drop('variable', axis=1)

# %%
tags_title_ = tags_title_[tags_title_.tags.apply(filter_tags)]

# %%
tags_title_
# Out:
#                                                       id     tags
# 10      https://gallica.bnf.fr/ark:/12148/btv1b53162160w    d'arc
# 19      https://gallica.bnf.fr/ark:/12148/btv1b53162161b    d'arc
# 26      https://gallica.bnf.fr/ark:/12148/btv1b530922119    schah
# 33      https://gallica.bnf.fr/ark:/12148/btv1b530653663   député
# 34      https://gallica.bnf.fr/ark:/12148/btv1b530923448    schah
# ...                                                  ...      ...
# 206335  https://gallica.bnf.fr/ark:/12148/btv1b531595399  majesté
# 207456  https://gallica.bnf.fr/ark:/12148/btv1b530921667    forme
# 220271  https://gallica.bnf.fr/ark:/12148/btv1b531595399    suite
# 262079  https://gallica.bnf.fr/ark:/12148/btv1b531595399    naser
# 276015  https://gallica.bnf.fr/ark:/12148/btv1b531595399   al-din
#
# [20833 rows x 2 columns]

# %%
def get_taglist(df, n=10):
    
    return df[df['tags'].map(df['tags'].value_counts()) > n]

# %%
taglist_title = list(get_taglist(tags_title_).tags.unique())

# %%
#taglist_title

# %%
tags_subject_ = tag_df.subject.apply(pd.Series).merge(tag_df, right_index=True, left_index=True) \
        .drop(['title','subject'],axis=1).melt(id_vars=['id'], value_name='tags').drop('variable', axis=1)

# %%
tags_subject_ = tags_subject_[tags_subject_.tags.apply(filter_tags)]

# %%
taglist_subject = list(get_taglist(tags_subject_, n=1).tags.unique())
#taglist_subject

# %%
#some manual work

taglist_title_final = ['député', 'ambassade', 'ministre', 'bordas',
       'compositeur', 'général', 'chinois', 'journaliste',
       'opéra', 'sculpteur', 'vaudeviliste', 'peintre',
       'colonel', 'auteur', 'historien', 'comédien', 'amiral',
       'baretta', 'prince', 'chimiste', 'avocat',
       'piccolo', 'comédie', 'romancier', 'abbé', 
       'écrivain', 'capitaine', 'navigation', 'vaudeville', 
       'châtelet', 'explorateur', 'aéronaute',
       'critique', 'cantatrice', 'princesse', 'poète', 'violoniste',
       'docteur',  'journal', 'marquis',
       'dessinateur', 'musicien', 'chanteur',
       'publiciste', 'chef', 'couturier', 'lanthelme', 'famille',
       'opéra-comique', 'écuyère', 'actrice',
       'napoléon', 'directeur', 'ecrivain', 'suite', 'anglaise',
       'palais-royal', 'folies', 'cirque', 'ecuyère',
        'théâtre-français', 'gymnase', 'frère',
      'roi', 'folies-dramatiques',
       'mousquetaires', 'bouffes-parisiens', 'professeur', 'groupe',
       'littérateur', 'président', 'maison',
       
       'lyrique', 'cluny', 'reichemberg', 'folies-dramatiques', 'frères',
       
       'chevallier', 'danseuse',  
       'décorateur', 'ambassadeur', 
       'politique', 'saint', 'république',
        'droit',
        'marquise', 
       'sénateur',
       'artiste', 'cloches',
       'majesté', 'japonaise', 'dramatique',
       'comique', 'française', 'aérienne', 'conservatoire', 'bourgeois',
       'italien', 'royal', "l'institut", 
       "d'orchestre", 'comédie-française', 
       'revue', 'bergère', "d'hiver", 'potter', 'dramatiques', 
       'suédoise', "l'académie", 'opéra-comique',
       'orphée',
       
       'folies-dramatiques',
       'vaudevill', 'odéon', 'phèdre', 'assassin', 'décoré',
       'saint-martin', 'trouvère', 'vénus', "l'arlésienne",
       'assommoir', 
       'cantinière', "s'amuse", 'amour', 'opéra', 'serment', 'rouge',
       
       'mascotte', 'gymnase',
       'châtelet', 
       
       'africaine',
        'juanita', 'perse', 'musique',
       'nouveau', 'lettres', 'russe', 'breuil', 'lantelme', 'hanovre',
       'pyrénées', 'parisienne', 'ventre',

       'chevalier', 'séville', 'américaine',  "l'impératrice",
       'commune', 'cigale', 'saturnales', 'cendrillonnette', 'tzigane',
       
       'camarade', 'marchande', 'bicyclistes',
       'sans-gêne', 'cousin-cousine', "d'avignon", 'pilules', 'fétiche',
       'cliquette', 
       'patard', 'patart', 'joyeusetés', 'fantaisies-parisiennes',
       'dramatiques', 'carreau',  'suzette', 'enfers', 'école',
       
       
        'trèfle', 

        'tambour-major', 'couronne',
        'diable',
       'pyrennées', 'christ', 'hussard', 'galles', "l'année", 'chèvres',
       'seigneur', 'clairette']

# %%
tag_df['tags_title'] = tag_df.title.apply(lambda x: list(set(x).intersection(set(taglist_title_final)))) 
tag_df['tags_subject'] = tag_df.subject.apply(lambda x: list(set(x).intersection(set(taglist_subject))))

# %%
tag_df['tags'] = tag_df.tags_title + tag_df.tags_subject

# %%
tag_df['len'] = tag_df.tags.apply(lambda x: len(x))

# %%
tag_df[tag_df.len >0]
# Out:
#                                                      id  \
# 14     https://gallica.bnf.fr/ark:/12148/btv1b53168871g
# 38     https://gallica.bnf.fr/ark:/12148/btv1b53171027z
# 39     https://gallica.bnf.fr/ark:/12148/btv1b53171028d
# 45     https://gallica.bnf.fr/ark:/12148/btv1b53165012c
# 50     https://gallica.bnf.fr/ark:/12148/btv1b53165010g
# ...                                                 ...
# 23516  https://gallica.bnf.fr/ark:/12148/btv1b530506270
# 23517  https://gallica.bnf.fr/ark:/12148/btv1b53065782n
# 23519  https://gallica.bnf.fr/ark:/12148/btv1b53066278c
# 23523  https://gallica.bnf.fr/ark:/12148/btv1b53118792t
# 23528  https://gallica.bnf.fr/ark:/12148/btv1b531203810
#
#                                              title         subject  \
# 14                             [me, opéra-comique]              []
# 38      [me, variétés, les, variétés, de, l'année]              []
# 39     [me, variétés), les, variétés, de, l'année]              []
# 45               [me, folies-dramatiques, juanita]              []
# 50                [m, folies-dramatiques, juanita]              []
# ...                                            ...             ...
# 23516                            [de, journaliste]              []
# 23517                         [homme, de, lettres]              []
# 23519                    [directeur, des, bouffes]              []
# 23523                                    [docteur]              []
# 23528                                [m, hignette]  [Ombre portée]
#
#                           tags_title    tags_subject  \
# 14                   [opéra-comique]              []
# 38                         [l'année]              []
# 39                         [l'année]              []
# 45     [folies-dramatiques, juanita]              []
# 50     [folies-dramatiques, juanita]              []
# ...                              ...             ...
# 23516                  [journaliste]              []
# 23517                      [lettres]              []
# 23519                    [directeur]              []
# 23523                      [docteur]              []
# 23528                             []  [Ombre portée]
#
#                                 tags  len
# 14                   [opéra-comique]    1
# 38                         [l'année]    1
# 39                         [l'année]    1
# 45     [folies-dramatiques, juanita]    2
# 50     [folies-dramatiques, juanita]    2
# ...                              ...  ...
# 23516                  [journaliste]    1
# 23517                      [lettres]    1
# 23519                    [directeur]    1
# 23523                      [docteur]    1
# 23528                 [Ombre portée]    1
#
# [6679 rows x 7 columns]

# %%
tag_id_df = pd.DataFrame(tag_df[['id','tags']], columns=['id','tags'])

# %%
tag_id_df.to_pickle('tag-id.pkl')

# %%
#tag_lists.tags.unique()

# %%
#save for get-article

# %%
wiki_df = pd.DataFrame(df2[['id','subjects']])

# %%
wiki_df['names'] = wiki_df.subjects.apply(is_name)

# %%
wiki_df['names'][wiki_df.names.apply(lambda x:len(x)>2)]
# Out:
# 69       [Georges, Édouard (1829-1903), Armand, Victori...
# 119      [Chevreul, Eugène (1786-1889), Chevreul, Henri...
# 120      [Chevreul, Eugène (1786-1889), Chevreul, Henri...
# 121      [Chevreul, Eugène (1786-1889), Nadar (1820-191...
# 135      [Chevreul, Eugène (1786-1889), Chevreul, Henri...
#                                ...
# 23392    [Hadamar, Zélie (1849-1902 ; actrice), Lambert...
# 23445    [Hamburger, Edouard (18..-1886), Baron, Vincen...
# 23450    [Lavallière, Ève (1866-1929), Dupuis, Joseph (...
# 23468    [Mary-Albert, Madame (1855-....), Duhamel, Bia...
# 23469    [Mary-Albert, Madame (1855-....), Duhamel, Bia...
# Name: names, Length: 65, dtype: object

# %%
re.findall('[\S]+','Auguez, Mathilde (1868-1955)')
# Out:
# ['Auguez,', 'Mathilde', '(1868-1955)']

# %%
wiki_explode = wiki_df.explode('names')

# %%
wiki_explode.groupby(wiki_explode.names).size()
# Out:
# names
# Abbatucci, Séverin (1821-1888)               5
# Abbott, Emma (1850-1891)                    50
# Abbéma, Louise (1858-1927)                  12
# Abney, William de Wiveleslie (1843-1920)     3
# Abott, Bessie (1878-1919)                    1
#                                             ..
# Énault, Louis (1824-1900)                    1
# Éon, Charles de Beaumont d' (1728-1810)      1
# Étex, Antoine (1808-1888)                    2
# Étiévant, Henri (1870-1953)                  1
# Č̌ebyšev, Pafnutij Lʹvovič (1821-1894)       3
# Length: 1963, dtype: int64

# %%
wiki_names = wiki_explode.names.unique()

# %%
import wikipedia

# %%
def hacked_summary(x):
    try:
        x = re.sub('[,(\-)]', ' ', x)
        keywords = re.findall('[\S]+', x.lower())

        s = wikipedia.summary(x, sentences=2)
        mask = list(map(lambda x: s.lower().find(x) != -1 ,keywords))
        se = list(compress(keywords, mask))
        
        #se = set(keywords).intersection(set(s.lower().split()))
        return (s, list(se))
    except:
        return ''

# %%
#

# %%
wikipedia.set_lang('en')


wiki = pd.DataFrame(wiki_names, columns=['name'])

wiki['result'] = wiki.name.apply(hacked_summary)
wiki[['summary','keyword']] = pd.DataFrame(wiki.result.values.tolist(), index= wiki.index)
# Out:
# C:\Users\haeeun\Anaconda3\lib\site-packages\wikipedia\wikipedia.py:389: UserWarning: No parser was explicitly specified, so I'm using the best available HTML parser for this system ("lxml"). This usually isn't a problem, but if you run this code on another system, or in a different virtual environment, it may use a different parser and behave differently.
#
# The code that caused this warning is on line 389 of the file C:\Users\haeeun\Anaconda3\lib\site-packages\wikipedia\wikipedia.py. To get rid of this warning, pass the additional argument 'features="lxml"' to the BeautifulSoup constructor.
#
#   lis = BeautifulSoup(html).find_all('li')

# %%
wiki.to_pickle('wiki_article_en.pkl')
# around 800 people have english wikipedia article

# %%
wiki_notnull = wiki[~wiki.summary.isnull()]
wiki_mismatch = wiki_notnull[['name','summary']][wiki_notnull.keyword.apply(lambda x: len(x)== 0)]
wiki_dict = wiki_mismatch.to_dict(orient='records')

# %%
wikipedia.set_lang('fr')

# %%
wiki['result_fr'] = wiki.name.apply(hacked_summary)

# %%
wiki[['summary_fr','keyword_fr']] = pd.DataFrame(wiki.result_fr.values.tolist(), index= wiki.index)

# %%
wiki[~wiki.summary_fr.isnull()].shape

# %%
wiki_fr = wiki[['summary_fr','keyword_fr']][~wiki.summary_fr.isnull()]

# %%
wiki_fr[wiki.keyword_fr.apply(lambda x: x==[])]

# %%
wiki[wiki.summary_fr.isnull() & ~wiki.summary.isnull()]

# %%
# Out:
# C:\Users\haeeun\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   """Entry point for launching an IPython kernel.
#                                              summary_fr keyword_fr
# 20    La belote est un jeu de cartes qui se pratique...         []
# 69    Anatole France, pour l'état civil François Ana...         []
# 94    Cette liste de peintres français recense les a...         []
# 200   Catherine Jeanne Schneider, dite Hortense Schn...         []
# 231   Le SPF Finances est le service public fédéral ...         []
# ...                                                 ...        ...
# 1866  Bonaparte franchissant le Grand-Saint-Bernard ...         []
# 1882  Régine, de son vrai nom Régina Zylberberg, éga...         []
# 1938  Cette liste de compositeurs de musique festive...         []
# 1961  Le cimetière du Nord, communément appelé cimet...         []
# 1963  La chambre de commerce et d’industrie de régio...         []
#
# [79 rows x 2 columns]

# %%
wiki[['name','summary','summary_fr']][(~wiki.summary.isnull() & wiki.keyword.apply(lambda x: x!=[]))| \
                               (~wiki.summary_fr.isnull() & wiki.keyword_fr.apply(lambda x:x!=[]))].to_pickle('wiki_summaries.pkl')
